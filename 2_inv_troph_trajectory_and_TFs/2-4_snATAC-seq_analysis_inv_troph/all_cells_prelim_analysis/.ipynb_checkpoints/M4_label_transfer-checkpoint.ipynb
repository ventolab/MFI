# %% [markdown]
# ## ATAC + MULTIOME (females september 2021)
#
# ### Label transfer with Seurat

# %%
import numpy as np
import scanpy as sc 
import pandas as pd
import anndata
sc.settings.figdir = '/home/jovyan/notebooks/Vento_Lab/MFI_spatial/MFI_snATAC-seq/MFI_snATAC-seq_202111/figures/'

# %%
sc.settings.set_figure_params(dpi=80)  # low dpi (dots per inch) yields small inline figures

# %%
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42

# %%
import rpy2.rinterface_lib.callbacks
import logging

# %%
# Ignore R warning messages
#Note: this can be commented out to get more verbose R output
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)

# %%
import anndata2ri # needs 'pip install anndata2ri'
anndata2ri.activate()

# %%
# %load_ext rpy2.ipython

# %%
# %%R
#
# sessionInfo()
# Out:
# R version 4.0.4 (2021-02-15)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.1 LTS
#
# Matrix products: default
# BLAS/LAPACK: /opt/conda/lib/libopenblasp-r0.3.12.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] tools     stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# loaded via a namespace (and not attached):
# [1] compiler_4.0.4

# %% [raw]
# %%R
#
# install.packages('Seurat')

# %% [raw]
# %%R
#
# unloadNamespace("Matrix")

# %%
# %%R
#
# .libPaths()
# Out:
# [1] "/home/jovyan/R/x86_64-pc-linux-gnu-library/4.0"
# [2] "/usr/local/lib/R/site-library"
# [3] "/usr/lib/R/site-library"
# [4] "/usr/lib/R/library"

# %%
# %%R
#
# install.packages("https://cran.r-project.org/src/contrib/Matrix_1.3-4.tar.gz", repos=NULL)

# %% [raw]
# %%R
#
# remove.packages('Matrix')

# %%
# %%R
# ## Install dependencies
# #devtools::install_github("aertslab/RcisTarget")
# #devtools::install_github("aertslab/AUCell")
#
# #devtools::install_github("aertslab/cisTopic")
# library(cisTopic)
# library(Seurat)
# library(dplyr)
# library(data.table)
# library(GenomicRanges)
# library(EnsDb.Hsapiens.v86)
# #library(cicero)
# library(Signac)
# #library(clustree)
# library(Matrix)
# library(reticulate)
# #if (!requireNamespace("remotes", quietly = TRUE)) {
# #  install.packages("remotes")
# #}
# #remotes::install_github("mojaveazure/seurat-disk")
#
# library(SeuratDisk)

# %%
# %%R
#
# sessionInfo()
# Out:
# R version 4.0.4 (2021-02-15)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.1 LTS
#
# Matrix products: default
# BLAS/LAPACK: /opt/conda/lib/libopenblasp-r0.3.12.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats4    tools     stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] SeuratDisk_0.0.0.9019     reticulate_1.18
#  [3] Matrix_1.3-4              Signac_1.4.0
#  [5] EnsDb.Hsapiens.v86_2.99.0 ensembldb_2.14.1
#  [7] AnnotationFilter_1.14.0   GenomicFeatures_1.42.2
#  [9] AnnotationDbi_1.52.0      Biobase_2.50.0
# [11] GenomicRanges_1.42.0      GenomeInfoDb_1.31.1
# [13] IRanges_2.24.1            S4Vectors_0.28.1
# [15] BiocGenerics_0.41.1       data.table_1.14.2
# [17] dplyr_1.0.7               SeuratObject_4.0.3
# [19] Seurat_4.0.5              cisTopic_0.3.0
#
# loaded via a namespace (and not attached):
#   [1] utf8_1.2.2                  R.utils_2.11.0
#   [3] tidyselect_1.1.1            RSQLite_2.2.8
#   [5] htmlwidgets_1.5.4           docopt_0.7.1
#   [7] grid_4.0.4                  BiocParallel_1.24.1
#   [9] Rtsne_0.15                  munsell_0.5.0
#  [11] codetools_0.2-18            ica_1.0-2
#  [13] future_1.21.0               miniUI_0.1.1.1
#  [15] withr_2.4.2                 RcisTarget_1.10.0
#  [17] colorspace_2.0-2            ROCR_1.0-11
#  [19] tensor_1.5                  listenv_0.8.0
#  [21] MatrixGenerics_1.2.1        slam_0.1-48
#  [23] GenomeInfoDbData_1.2.4      lgr_0.4.3
#  [25] polyclip_1.10-0             farver_2.1.0
#  [27] bit64_4.0.5                 parallelly_1.24.0
#  [29] vctrs_0.3.8                 generics_0.1.1
#  [31] float_0.2-6                 BiocFileCache_1.14.0
#  [33] lsa_0.73.2                  ggseqlogo_0.1
#  [35] R6_2.5.1                    hdf5r_1.3.3
#  [37] bitops_1.0-7                spatstat.utils_2.1-0
#  [39] cachem_1.0.6                DelayedArray_0.16.3
#  [41] assertthat_0.2.1            promises_1.2.0.1
#  [43] scales_1.1.1                gtable_0.3.0
#  [45] globals_0.14.0              goftest_1.2-2
#  [47] rlang_0.4.12                RcppRoll_0.3.0
#  [49] text2vec_0.6                splines_4.0.4
#  [51] rtracklayer_1.50.0          lazyeval_0.2.2
#  [53] spatstat.geom_2.0-1         reshape2_1.4.4
#  [55] abind_1.4-5                 httpuv_1.6.3
#  [57] feather_0.3.5               ggplot2_3.3.5
#  [59] ellipsis_0.3.2              spatstat.core_2.0-0
#  [61] RColorBrewer_1.1-2          ggridges_0.5.3
#  [63] Rcpp_1.0.7                  plyr_1.8.6
#  [65] progress_1.2.2              zlibbioc_1.36.0
#  [67] purrr_0.3.4                 RCurl_1.98-1.5
#  [69] prettyunits_1.1.1           rpart_4.1-15
#  [71] openssl_1.4.5               deldir_0.2-10
#  [73] pbapply_1.4-3               cowplot_1.1.1
#  [75] zoo_1.8-9                   SummarizedExperiment_1.20.0
#  [77] ggrepel_0.9.1               cluster_2.1.1
#  [79] magrittr_2.0.1              scattermore_0.7
#  [81] lmtest_0.9-38               RANN_2.6.1
#  [83] SnowballC_0.7.0             mlapi_0.1.0
#  [85] ProtGenerics_1.22.0         fitdistrplus_1.1-6
#  [87] matrixStats_0.61.0          hms_1.1.1
#  [89] patchwork_1.1.1             mime_0.12
#  [91] xtable_1.8-4                RhpcBLASctl_0.21-247.1
#  [93] XML_3.99-0.8                sparsesvd_0.2
#  [95] AUCell_1.12.0               gridExtra_2.3
#  [97] compiler_4.0.4              biomaRt_2.46.3
#  [99] tibble_3.1.6                KernSmooth_2.23-18
# [101] crayon_1.4.2                R.oo_1.24.0
# [103] htmltools_0.5.2             mgcv_1.8-34
# [105] later_1.3.0                 snow_0.4-4
# [107] tidyr_1.1.4                 DBI_1.1.1
# [109] tweenr_1.0.2                dbplyr_2.1.0
# [111] MASS_7.3-53.1               rappdirs_0.3.3
# [113] cli_3.1.0                   R.methodsS3_1.8.1
# [115] parallel_4.0.4              igraph_1.2.8
# [117] pkgconfig_2.0.3             GenomicAlignments_1.26.0
# [119] rsparse_0.4.0               plotly_4.9.3
# [121] spatstat.sparse_2.0-0       xml2_1.3.2
# [123] foreach_1.5.1               annotate_1.68.0
# [125] lda_1.4.2                   XVector_0.30.0
# [127] stringr_1.4.0               digest_0.6.28
# [129] sctransform_0.3.2           RcppAnnoy_0.0.18
# [131] graph_1.68.0                spatstat.data_2.1-0
# [133] Biostrings_2.58.0           leiden_0.3.9
# [135] fastmatch_1.1-3             uwot_0.1.10
# [137] GSEABase_1.52.1             curl_4.3.2
# [139] shiny_1.7.1                 Rsamtools_2.6.0
# [141] lifecycle_1.0.1             nlme_3.1-152
# [143] jsonlite_1.7.2              viridisLite_0.4.0
# [145] askpass_1.1                 fansi_0.5.0
# [147] pillar_1.6.4                lattice_0.20-41
# [149] fastmap_1.1.0               httr_1.4.2
# [151] survival_3.2-10             glue_1.5.0
# [153] qlcMatrix_0.9.7             png_0.1-7
# [155] iterators_1.0.13            bit_4.0.4
# [157] ggforce_0.3.3               stringi_1.7.5
# [159] blob_1.2.2                  doSNOW_1.0.19
# [161] memoise_2.0.0               irlba_2.3.3
# [163] future.apply_1.7.0

# %% [markdown]
# **Load data**

# %%
# Define variables

cellatac_outdir = '/lustre/scratch117/cellgen/team292/aa22/with_Stijn/202111_snATAC-seq_data_MFI/results200k/'
outdir = '/lustre/scratch117/cellgen/team292/aa22/with_Stijn/202111_snATAC-seq_data_MFI/downstream_analysis/'
experiment_prefix = 'MFI_prelim_all_cells'

# %% [markdown]
# Try to use the gene accessibility scores computed with Emma's method and integrate with matched scRNAseq samples annotated by Luz

# %%
# %%R -i outdir -i experiment_prefix -o ATAC_geneScores
# Convert(paste0(outdir, experiment_prefix, "_ATAC.geneScores.h5ad"),
#         dest = paste0(outdir, experiment_prefix, "_ATAC.geneScores.h5seurat"), overwrite = TRUE)
# ATAC_geneScores <- LoadH5Seurat(paste0(outdir, experiment_prefix, "_ATAC.geneScores.h5seurat"))
# ATAC_geneScores
# table(ATAC_geneScores@meta.data$individual)
# Out:
# integer(0)

# %%
# %%R
#
# ATAC_geneScores
# Out:
# An object of class Seurat
# 12506 features across 82174 samples within 1 assay
# Active assay: RNA (12506 features, 0 variable features)
#  1 dimensional reduction calculated: cistopic_50

# %%
# %%R -i outdir -i experiment_prefix -o RNAseq
# Convert(paste0("/lustre/scratch117/cellgen/team292/aa22/adata_objects/202111_MFI_sc_sn_new_scVI_analysis/adata_Vento_Tormo_for_logreg_training.h5ad"),
#         dest = paste0(outdir, experiment_prefix, "_adata_Vento_Tormo_for_logreg_training.h5seurat"), overwrite = TRUE, verbose = TRUE)
#
# RNAseq <- LoadH5Seurat(paste0(outdir, experiment_prefix, "_adata_Vento_Tormo_for_logreg_training.h5seurat"))
# RNAseq
# table(RNAseq@meta.data$donor)
# Out:
# [1]  8327  6806 17583 13325 10429  2499  5724

# %%
# %%R
#
# RNAseq
# Out:
# An object of class Seurat
# 30800 features across 64693 samples within 1 assay
# Active assay: RNA (30800 features, 0 variable features)

# %%
# %%R
#
# head(RNAseq@meta.data)
# Out:
#                               n_genes     sample       technology
# ACTGAGTTCGTTTAGG-1_FCA7167231     507 FCA7167231 10X_3'_scRNA-seq
# TTGGCAATCTAACTGG-1_FCA7196231     991 FCA7196231 10X_3'_scRNA-seq
# TCGGGACCACAGACAG-1_FCA7196220    1875 FCA7196220 10X_3'_scRNA-seq
# TGTGGTAAGGTGCTTT-1_FCA7196224    2223 FCA7196224 10X_3'_scRNA-seq
# TAGTTGGAGGTGATTA-1_FCA7167231    1444 FCA7167231 10X_3'_scRNA-seq
# CTAGCCTAGCGATCCC-1_FCA7167222    1703 FCA7167222 10X_3'_scRNA-seq
#                                           tissue dev_age donor      dataset
# TGTGGTAAGGTGCTTT-1_FCA7196224 TGTGGTAAGGTGCTTT-1_FCA7196224     19.1_Endo (m)
# TAGTTGGAGGTGATTA-1_FCA7167231 TAGTTGGAGGTGATTA-1_FCA7167231             17_NK
# CTAGCCTAGCGATCCC-1_FCA7167222 CTAGCCTAGCGATCCC-1_FCA7167222             3_dS2

# %%
# %%R -i RNAseq
#
# print(table(RNAseq@meta.data$annot_Vento.Tormo))
# Out:
#           0_dS1           1_VCT          2_dNK2           3_dS2        4_Tcells
#            7090            7061            5409            4599            3962
#          5_dNK1           6_dM2           7_dM1        8_Tcells           9_VCT
#            3788            2788            2571            1456            2279
#       10_Tcells         11_dNK3           12_F1          13_EVT        14.1_PV1
#            1759            1987            2176            1950            1033
#        14.2_PV2       15_Tcells          16_EVT           17_NK           18_HB
#             805            1590            1552            1451            1301
#   19.1_Endo (m)     19.2_Endo L   19.3_Endo (f)          20_SCT          21_dS3
#             844             345              98            1238             894
#           22_M3           23_MO         24_dNKp       25.1_Epi1       25.2_Epi2
#             887             885             730             219             175
#       26_Plasma          27_DC1          28_DC2           29_MO 30_Granulocytes
#             340             324             316              18             245
#      31_NK CD16         32_ILC3           33_F2
#             230             186             112

# %% [markdown]
# **Try label transfer with major cluster annotations**

# %%
# takes quite a bit of time (1h+) and make sure you have at least 150Gb of RAM
# takes roughly 2-3 hours predicting labels from object with 64693 cells and 3000 genes

# %%
# %%R -i RNAseq -i ATAC_geneScores -o RNA2ATAC
#
# # Normalize both RNA and ATAC data
# RNAseq <- NormalizeData(object = RNAseq, verbose = TRUE)
# ATAC_geneScores <- NormalizeData(object = ATAC_geneScores, verbose = TRUE)
#
# # Find HVGs in both RNA and ATAC data
# RNAseq  <- FindVariableFeatures(object = RNAseq, selection.method = "vst", nfeatures = 3000, verbose = TRUE)
# ATAC_geneScores <- FindVariableFeatures(object = ATAC_geneScores, selection.method = "vst", nfeatures = 3000, verbose = TRUE)
#
# # Find anchors to do integration using RNA as reference and ATAC as query
# transfer_anchors <- FindTransferAnchors(reference = RNAseq, query = ATAC_geneScores,
#     dims = 1:25, reduction = "cca")
#
# # Transfer labels from RNA to ATAC
# RNA2ATAC <- TransferData(anchorset = transfer_anchors, refdata = RNAseq@meta.data$annot_Vento.Tormo, dims = 1:25, weight.reduction = "cca",
#                         prediction.assay = TRUE)
#
# # Add metadata to ATAC
# #ATAC_geneScores_labels <- AddMetaData(object = ATAC_geneScores, metadata = RNA2ATAC)

# %%
# %%R -i RNA2ATAC -o predicted_probabilities -i ATAC_geneScores
#
# ATAC_geneScores[['scores']] <- RNA2ATAC
# ATAC_geneScores
# DefaultAssay(ATAC_geneScores) <- "scores" # Change default assay
# predicted_probabilities <- as.data.frame(t(x = as.matrix(x = GetAssayData(object = ATAC_geneScores))))

# %%
predicted_probabilities
# Out:
#                        10-Tcells  15-Tcells    20-SCT  19.1-Endo (m)  17-NK  \
# 09-AAACAGCCACAATGTT-1        0.0        0.0  0.000000            0.0    0.0
# 09-AAACAGCCACTCGCTC-1        0.0        0.0  0.731425            0.0    0.0
# 04-TTTGTGTTCCGTACGG-1         0.0   0.000000        0.0  0.000000    0.0
# 04-TTTGTGTTCGGAAAGC-1         0.0   0.000000        0.0  0.000000    0.0
# 04-TTTGTGTTCTCCACTG-1         0.0   0.000000        0.0  0.000000    0.0
# 04-TTTGTGTTCTGAGTCA-1         0.0   0.000000        0.0  0.000000    0.0
#
#                             max
# 09-AAACAGCCACAATGTT-1  0.447134
# 09-AAACAGCCACTCGCTC-1  0.731425
# 09-AAACATGCAACCCTCC-1  0.956188
# 09-AAACATGCAATATAGG-1  0.701308
# 09-AAACCAACACTAGCGT-1  0.909688
# ...                         ...
# 04-TTTGTGTGTATTTGCG-1  0.936993
# 04-TTTGTGTTCCGTACGG-1  0.813029
# 04-TTTGTGTTCGGAAAGC-1  1.000000
# 04-TTTGTGTTCTCCACTG-1  0.453323
# 04-TTTGTGTTCTGAGTCA-1  0.822588
#
# [82174 rows x 39 columns]

# %%
predicted_probabilities.columns
# Out:
# Index(['10-Tcells', '15-Tcells', '20-SCT', '19.1-Endo (m)', '17-NK', '3-dS2',
#        '1-VCT', '0-dS1', '4-Tcells', '9-VCT', '7-dM1', '5-dNK1', '14.1-PV1',
#        '12-F1', '2-dNK2', '21-dS3', '27-DC1', '13-EVT', '24-dNKp', '23-MO',
#        '6-dM2', '8-Tcells', '32-ILC3', '18-HB', '11-dNK3', '28-DC2',
#        '19.2-Endo L', '30-Granulocytes', '22-M3', '25.2-Epi2', '16-EVT',
#        '19.3-Endo (f)', '14.2-PV2', '31-NK CD16', '26-Plasma', '25.1-Epi1',
#        '29-MO', '33-F2', 'max'],
#       dtype='object')

# %% [markdown]
# Replace dashes with underscores as stupid R changes them

# %%
predicted_probabilities.columns = [elem.replace('-','_') for elem in predicted_probabilities.columns]

# %%
predicted_probabilities.columns
# Out:
# Index(['10_Tcells', '15_Tcells', '20_SCT', '19.1_Endo (m)', '17_NK', '3_dS2',
#        '1_VCT', '0_dS1', '4_Tcells', '9_VCT', '7_dM1', '5_dNK1', '14.1_PV1',
#        '12_F1', '2_dNK2', '21_dS3', '27_DC1', '13_EVT', '24_dNKp', '23_MO',
#        '6_dM2', '8_Tcells', '32_ILC3', '18_HB', '11_dNK3', '28_DC2',
#        '19.2_Endo L', '30_Granulocytes', '22_M3', '25.2_Epi2', '16_EVT',
#        '19.3_Endo (f)', '14.2_PV2', '31_NK CD16', '26_Plasma', '25.1_Epi1',
#        '29_MO', '33_F2', 'max'],
#       dtype='object')

# %%
predicted_probabilities.columns[np.argmax(predicted_probabilities.loc['09-AAACAGCCACAATGTT-1'])]
# Out:
# '6_dM2'

# %%
# assigning top prediction also
predicted_probabilities['top_prediction'] = [predicted_probabilities.columns[np.argmax(predicted_probabilities.loc[idx])] for idx in predicted_probabilities.index]

# %%
# save these 
predicted_probabilities.to_csv(outdir + '20211123_probabilities_of_ct_predictions_ATAC_all_cells.csv')

# %% [markdown]
# **Save the predicted annotations to the gene activity anndata object for ATAC**

# %%
gene_data = sc.read_h5ad(outdir + experiment_prefix + "_ATAC.geneScores.h5ad")
gene_data
# Out:
# AnnData object with n_obs × n_vars = 82174 × 12506
#     obs: 'cellatac_clusters', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 
# 09-AAACATGCAACCCTCC-1    10X_multiome
# 09-AAACATGCAATATAGG-1    10X_multiome
# 09-AAACCAACACTAGCGT-1    10X_multiome
# ...                               ...
# 04-TTTGTGTGTATTTGCG-1  10X_snATAC-seq
# 04-TTTGTGTTCCGTACGG-1  10X_snATAC-seq
# 04-TTTGTGTTCGGAAAGC-1  10X_snATAC-seq
# 04-TTTGTGTTCTCCACTG-1  10X_snATAC-seq
# 04-TTTGTGTTCTGAGTCA-1  10X_snATAC-seq
#
# [82174 rows x 15 columns]

# %%
#gene_data.obs = gene_data.obs.drop([ 'Mesenchymal_LHX9', 'Supporting', 'CoelEpi', 'Endothelial', 'PV', 'Mesenchymal_GATA2', 'GermCells', 'Epithelial', 'Immune', 'Neural', 'SMCs', 'Erythroid', 'max', 'mean_gene_activity'], axis = 1)

# %%
for pred in predicted_probabilities.columns: 
    print(pred)
    gene_data.obs[pred] = predicted_probabilities[pred]
# Out:
# 10_Tcells
# 15_Tcells
# 20_SCT
# 19.1_Endo (m)
# 17_NK
# 3_dS2
# 1_VCT
# 0_dS1
# 4_Tcells
# 9_VCT
# 7_dM1
# 5_dNK1
# 14.1_PV1
# 12_F1
# 2_dNK2
# 21_dS3
# 27_DC1
# 13_EVT
# 24_dNKp
# 23_MO
# 6_dM2
# 8_Tcells
# 32_ILC3
# 18_HB
# 11_dNK3
# 28_DC2
# 19.2_Endo L
# 30_Granulocytes
# 22_M3
# 25.2_Epi2
# 16_EVT
# 19.3_Endo (f)
# 14.2_PV2
# 31_NK CD16
# 26_Plasma
# 25.1_Epi1
# 29_MO
# 33_F2
# max
# top_prediction

# %%
sc.pl.umap(gene_data, color = ['sample', 'donor', 'age', 'tissue', 'technology','top_prediction'], ncols = 2, wspace = 0.4, 
            #save = "_noharmony.pdf"
          )
# Out:
# ... storing 'top_prediction' as categorical

# %%
# to better distinguish predictions from Vento-Tormo dataset
colors_VT = ['#C1B4A7','#E8D6E0','#40ab5d','#F7B5A4',
                 '#d8e7a4','#2ECCFA','#39728C','#FA5858','#E9A1C7',
                 '#B40486','#004529','#C49A6C','#9255a0', '#58595B', '#A3A8AD',
             
                 '#F6D8CE','#633A6D','#C7E0BD','#49ABC8', '#E7C949', 
             
             #'#F7F297', '#af9e56',
                 '#ED1B64','#E59C24','#C2E8F6','#677EB2',#'#73FDD6', 
             '#BC3122', '#771A15',
                 '#E6C6F7','#CEE3F6','#CECEF6','#677EB2','#6363A5','#63A585',
                 #'#246D66',
             '#9B8579']

# %%
sc.pl.umap(gene_data, color = ['top_prediction'], ncols = 2, wspace = 0.4, 
            #save = "_noharmony.pdf",
           palette = colors_VT
          )

# %%
sc.pl.umap(gene_data, color = predicted_probabilities.columns, ncols = 3, color_map = 'OrRd', #save = "_probs_noharmony.pdf"
          )

# %%
predicted_probabilities.columns
# Out:
# Index(['10_Tcells', '15_Tcells', '20_SCT', '19.1_Endo (m)', '17_NK', '3_dS2',
#        '1_VCT', '0_dS1', '4_Tcells', '9_VCT', '7_dM1', '5_dNK1', '14.1_PV1',
#        '12_F1', '2_dNK2', '21_dS3', '27_DC1', '13_EVT', '24_dNKp', '23_MO',
#        '6_dM2', '8_Tcells', '32_ILC3', '18_HB', '11_dNK3', '28_DC2',
#        '19.2_Endo L', '30_Granulocytes', '22_M3', '25.2_Epi2', '16_EVT',
#        '19.3_Endo (f)', '14.2_PV2', '31_NK CD16', '26_Plasma', '25.1_Epi1',
#        '29_MO', '33_F2', 'max', 'top_prediction'],
#       dtype='object')

# %%
sc.pl.umap(gene_data, color = ['20_SCT','1_VCT','9_VCT','13_EVT','16_EVT'], ncols = 3, color_map = 'OrRd', #save = "_probs_noharmony.pdf"
          )

# %%
# resave the object with these scores 
gene_data.write(outdir + experiment_prefix + "_ATAC.geneScores.h5ad")

# %%
gene_data
# Out:
# AnnData object with n_obs × n_vars = 89929 × 16882
#     obs: 'cellatac_clusters', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'multiome_GermCells', 'multiome_Somatic', 'code', 'sample', 'sex', 'stage', 'individual', 'preGranulosa', 'Mesenchymal_LHX9', 'Supporting', 'CoelEpi', 'Endothelial', 'Mesenchymal_GATA2', 'PV', 'GermCells', 'Epithelial', 'Immune', 'Neural', 'SMCs', 'Erythroid', 'max', 'mean_gene_activity'
#     var: 'gene_id'
#     uns: 'individual_colors', 'neighbors', 'sample_colors', 'stage_colors', 'umap'
#     obsm: 'X_cistopic_46', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# **Save the predicted annotations to the peaks anndata object for ATAC**

# %%
adata = sc.read_h5ad(outdir + experiment_prefix + "_ATAC.wCisTopic.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 82174 × 89411
#     obs: 'cellatac_clusters', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'cellatac_code', 'sample', 'donor', 'age', 'tissue', 'technology'
#     var: 'peak_width', 'exon', 'gene', 'promoter', 'annotation', 'gene_name', 'gene_id', 'tss_distance', 'ENCODE_blacklist', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'age_colors', 'cellatac_clusters_colors', 'donor_colors', 'neighbors', 'sample_colors', 'technology_colors', 'tissue_colors', 'umap'
#     obsm: 'X_cistopic_50', 'X_umap'
#     varm: 'peak2gene'
#     layers: 'binary_raw'
#     obsp: 'connectivities', 'distances'

# %%
for pred in predicted_probabilities.columns: 
    print(pred)
    adata.obs[pred] = predicted_probabilities[pred]
# Out:
# 10_Tcells
# 15_Tcells
# 20_SCT
# 19.1_Endo (m)
# 17_NK
# 3_dS2
# 1_VCT
# 0_dS1
# 4_Tcells
# 9_VCT
# 7_dM1
# 5_dNK1
# 14.1_PV1
# 12_F1
# 2_dNK2
# 21_dS3
# 27_DC1
# 13_EVT
# 24_dNKp
# 23_MO
# 6_dM2
# 8_Tcells
# 32_ILC3
# 18_HB
# 11_dNK3
# 28_DC2
# 19.2_Endo L
# 30_Granulocytes
# 22_M3
# 25.2_Epi2
# 16_EVT
# 19.3_Endo (f)
# 14.2_PV2
# 31_NK CD16
# 26_Plasma
# 25.1_Epi1
# 29_MO
# 33_F2
# max
# top_prediction

# %%
adata.write(outdir + experiment_prefix + "_ATAC.wCisTopic.h5ad")
# Out:
# ... storing 'top_prediction' as categorical

# %% [markdown]
# # batch effects in my data are not horrible, so for subsetting trophoblast I don't need to correct this object so far

# %% [markdown]
# #### End of notebook
