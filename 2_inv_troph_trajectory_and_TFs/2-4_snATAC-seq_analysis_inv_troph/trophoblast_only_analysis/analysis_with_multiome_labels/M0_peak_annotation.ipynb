# %% [markdown]
# # Annotating ATAC peaks with genomic features
#
# ### Multiome ATAC, MFI, trophoblast only, with peak calling based on true labels coming from RNA annotation of multiome
#
# 01.2022

# %%
# %load_ext rpy2.ipython

# %%
# %%R
#
# sessionInfo()
# Out:
# R version 4.0.4 (2021-02-15)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.1 LTS
#
# Matrix products: default
# BLAS/LAPACK: /opt/conda/lib/libopenblasp-r0.3.12.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] tools     stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# loaded via a namespace (and not attached):
# [1] compiler_4.0.4

# %%
# %%R
#
# packageVersion("GenomeInfoDb")
# Out:
# [1] ‘1.31.1’

# %%
# %%R
#
# # necessary for GenomeInfoDb - this I understood once I tried to do devtools::install_github("https://github.com/Bioconductor/GenomeInfoDb/") in command line R and
# # it explicitly complained about needing an update for this BiocGenerics package
# devtools::install_github("https://github.com/Bioconductor/BiocGenerics/")
# Out:
# R[write to console]: Downloading GitHub repo Bioconductor/BiocGenerics@HEAD
# ✔  checking for file ‘/tmp/RtmpXcJMaW/remotes3f946d701389/Bioconductor-BiocGenerics-6689be8/DESCRIPTION’ ...
# ─  preparing ‘BiocGenerics’:
# ✔  checking DESCRIPTION meta-information ...
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘BiocGenerics_0.41.1.tar.gz’
# R[write to console]: Installing package into ‘/home/jovyan/R/x86_64-pc-linux-gnu-library/4.0’
# (as ‘lib’ is unspecified)

# %%
# %%R
#
# #BiocManager::install("GenomeInfoDb")
# # had to install a newer version of ... since was having this issue in the very last command (peaks_gr <- annotate_gr(peaks_gr, EnsDb.genome, blacklist_gr)):
# # https://github.com/Bioconductor/GenomeInfoDb/issues/30
# devtools::install_github("https://github.com/Bioconductor/GenomeInfoDb/")
# Out:
# R[write to console]: Downloading GitHub repo Bioconductor/GenomeInfoDb@HEAD
# ✔  checking for file ‘/tmp/RtmpXcJMaW/remotes3f947b76f52d/Bioconductor-GenomeInfoDb-d4604b1/DESCRIPTION’ ...
# ─  preparing ‘GenomeInfoDb’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘GenomeInfoDb_1.31.1.tar.gz’
# R[write to console]: Installing package into ‘/home/jovyan/R/x86_64-pc-linux-gnu-library/4.0’
# (as ‘lib’ is unspecified)

# %%
# %%R
#
# library('GenomeInfoDb')
# Out:
# R[write to console]: Loading required package: BiocGenerics
#
# R[write to console]:
# Attaching package: ‘BiocGenerics’
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# R[write to console]: Loading required package: S4Vectors
#
# R[write to console]: Loading required package: stats4
#
# R[write to console]:
# Attaching package: ‘S4Vectors’
#
#
# R[write to console]: The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# R[write to console]: Loading required package: IRanges

# %%
# %%R
#
# packageVersion("GenomeInfoDb")
# Out:
# [1] ‘1.31.1’

# %%
# %%R
#
# sessionInfo()
# Out:
# R version 4.0.4 (2021-02-15)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.1 LTS
#
# Matrix products: default
# BLAS/LAPACK: /opt/conda/lib/libopenblasp-r0.3.12.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] tools     stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# loaded via a namespace (and not attached):
# [1] compiler_4.0.4

# %%
# %%R
#
# BiocManager::install("Signac")
# Out:
# R[write to console]: Bioconductor version 3.12 (BiocManager 1.30.10), R 4.0.4 (2021-02-15)
#
# R[write to console]: Installing package(s) 'Signac'
#
# R[write to console]: also installing the dependency ‘GenomeInfoDb’
#
#
# R[write to console]: trying URL 'https://bioconductor.org/packages/3.12/bioc/src/contrib/GenomeInfoDb_1.26.7.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 3454077 bytes (3.3 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 3.3 MB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/Signac_1.4.0.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 754660 bytes (736 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 736 KB
#
#
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/tmp/Rtmpr0wcuZ/downloaded_packages’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: Old packages: 'ape', 'backports', 'batchelor', 'bbmle', 'beeswarm',
#   'BiocGenerics', 'BiocManager', 'bitops', 'blob', 'brio', 'broom', 'bslib',
#   'cachem', 'callr', 'car', 'caTools', 'cli', 'colorspace', 'conquer', 'cpp11',
#   'crayon', 'credentials', 'curl', 'data.table', 'dbplyr', 'deldir',
#   'DEoptimR', 'desc', 'devtools', 'diffobj', 'digest', 'downlit', 'dplyr',
#   'dqrng', 'DT', 'e1071', 'ellipsis', 'fansi', 'fastICA', 'fitdistrplus',
#   'foghorn', 'forecast', 'formatR', 'furrr', 'future', 'future.apply',
#   'gargle', 'generics', 'GenomicFeatures', 'gert', 'ggfortify', 'ggplot2',
#   'gh', 'glmnet', 'goftest', 'gss', 'gtools', 'haven', 'hdf5r', 'highr',
#   'Hmisc', 'hms', 'htmlTable', 'htmltools', 'htmlwidgets', 'httpuv', 'igraph',
#   'IRkernel', 'isoband', 'jpeg', 'jquerylib', 'KFAS', 'knitr', 'laeken',
#   'later', 'leiden', 'lifecycle', 'lme4', 'lubridate', 'manipulateWidget',
#   'maps', 'maptools', 'matrixStats', 'mime', 'MSwM', 'multcomp', 'mvtnorm',
#   'openssl', 'openxlsx', 'optparse', 'parallelly', 'parsedate', 'pbapply',
#   'pbdZMQ', 'pcaPP', 'pillar', 'pkgload', 'plotly', 'plotrix', 'processx',
#   'proxy', 'quantreg', 'R.utils', 'R6', 'ragg', 'ranger', 'raster',
#   'rbibutils', 'rcmdcheck', 'Rcpp', 'RcppAnnoy', 'RcppArmadillo', 'RcppGSL',
#   'RCurl', 'Rdpack', 'readr', 'remotes', 'reprex', 'reticulate', 'Rfast',
#   'Rfast2', 'rgeos', 'rgl', 'rhdf5filters', 'RhpcBLASctl', 'rio', 'rlang',
#   'rmarkdown', 'rngtools', 'robustbase', 'roxygen2', 'rrcov', 'rsample',
#   'RSQLite', 'rsvd', 'rversions', 'rvest', 'sandwich', 'sass', 'scran',
#   'segmented', 'sessioninfo', 'Seurat', 'SeuratObject', 'sf', 'shape', 'shiny',
#   'sitmo', 'slider', 'sn', 'snow', 'softImpute', 'spatstat.core',
#   'spatstat.geom', 'spatstat.utils', 'spData', 'spdep', 'statmod', 'stringi',
#   'systemfonts', 'testthat', 'textshaping', 'TH.data', 'tibble', 'tidyr',
#   'tidyselect', 'tidyverse', 'tinytex', 'units', 'usethis', 'utf8', 'uuid',
#   'vars', 'vcd', 'vctrs', 'vdiffr', 'VIM', 'viridis', 'viridisLite', 'waldo',
#   'withr', 'WriteXLS', 'xfun', 'XML', 'zip', 'boot', 'class', 'cluster',
#   'KernSmooth', 'lattice', 'MASS', 'Matrix', 'mgcv', 'nlme', 'nnet', 'spatial',
#   'survival'
# Update all/some/none? [a/s/n]:
#  a
# R[write to console]: also installing the dependencies ‘progressr’, ‘SQUAREM’, ‘lava’, ‘prodlim’, ‘gower’, ‘ipred’, ‘ModelMetrics’, ‘pROC’, ‘recipes’, ‘ids’, ‘caret’, ‘shinyjs’, ‘terra’, ‘vroom’, ‘tzdb’, ‘here’, ‘Matrix’, ‘dtplyr’, ‘googledrive’, ‘googlesheets4’
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/progressr_0.9.0.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 106817 bytes (104 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 104 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/SQUAREM_2021.1.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 242772 bytes (237 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 237 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/lava_1.6.10.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 1636454 bytes (1.6 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.6 MB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/prodlim_2019.11.13.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 126527 bytes (123 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 123 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/gower_0.2.2.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 138998 bytes (135 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 135 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/ipred_0.9-12.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 177301 bytes (173 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 173 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/ModelMetrics_1.2.2.2.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 17441 bytes (17 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 17 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/pROC_1.18.0.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 687952 bytes (671 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 671 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/recipes_0.1.17.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 685580 bytes (669 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 669 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/ids_1.0.1.tar.gz'
#
# R[write to console]: Content type 'application/x-tar'
# R[write to console]:  length 89920 bytes (87 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 87 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/caret_6.0-90.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 2332392 bytes (2.2 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.2 MB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/shinyjs_2.0.0.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 1046455 bytes (1021 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1021 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/terra_1.4-11.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 545094 bytes (532 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 532 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/vroom_1.5.5.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 722003 bytes (705 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 705 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/tzdb_0.2.0.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 566071 bytes (552 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 552 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/here_1.0.1.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 32828 bytes (32 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 32 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/Matrix_1.3-4.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 2053378 bytes (2.0 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.0 MB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/dtplyr_1.1.0.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 113010 bytes (110 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 110 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/googledrive_2.0.0.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 1593592 bytes (1.5 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.5 MB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/googlesheets4_1.0.0.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 218547 bytes (213 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 213 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/ape_5.5.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 1756604 bytes (1.7 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.7 MB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/backports_1.3.0.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 23254 bytes (22 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 22 KB
#
#
# R[write to console]: trying URL 'https://bioconductor.org/packages/3.12/bioc/src/contrib/batchelor_1.6.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1976299 bytes (1.9 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.9 MB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/bbmle_1.0.24.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 508496 bytes (496 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 496 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/beeswarm_0.4.0.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 24720 bytes (24 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 24 KB
#
#
# R[write to console]: trying URL 'https://bioconductor.org/packages/3.12/bioc/src/contrib/BiocGenerics_0.36.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 47539 bytes (46 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 46 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/BiocManager_1.30.16.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 262160 bytes (256 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 256 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/bitops_1.0-7.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 10887 bytes (10 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 10 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/blob_1.2.2.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 10234 bytes
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 10234 bytes
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/brio_1.1.2.tar.gz'
#
# ...
#
# R[write to console]: downloaded 808 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/vctrs_0.3.8.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 784938 bytes (766 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 766 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/vdiffr_1.0.2.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 100892 bytes (98 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 98 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/VIM_6.1.1.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 2196776 bytes (2.1 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.1 MB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/viridis_0.6.2.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 3025492 bytes (2.9 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.9 MB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/viridisLite_0.4.0.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 1267617 bytes (1.2 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.2 MB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/waldo_0.3.1.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 33936 bytes (33 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 33 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/withr_2.4.2.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 95150 bytes (92 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 92 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/WriteXLS_6.3.0.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 738953 bytes (721 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 721 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/xfun_0.27.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 119229 bytes (116 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 116 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/XML_3.99-0.8.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 973603 bytes (950 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 950 KB
#
#
# R[write to console]: trying URL 'https://packagemanager.rstudio.com/all/__linux__/focal/latest/src/contrib/zip_2.2.0.tar.gz'
#
# R[write to console]: Content type 'binary/octet-stream'
# R[write to console]:  length 114668 bytes (111 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 111 KB

# %%
# %%R
#
# BiocManager::install("EnsDb.Hsapiens.v86")

# %% [raw]
# %%R
#
# if (!requireNamespace("BiocManager", quietly = TRUE))
#     install.packages("BiocManager", version="3.14")

# %%
# %%R
#
# packageVersion("BiocManager")
# Out:
# [1] ‘1.30.10’

# %%
# %%R
#
# sessionInfo()
# Out:
# R version 4.0.4 (2021-02-15)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.1 LTS
#
# Matrix products: default
# BLAS/LAPACK: /opt/conda/lib/libopenblasp-r0.3.12.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] tools     stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# loaded via a namespace (and not attached):
# [1] compiler_4.0.4

# %%
# %%R
#
# .libPaths()
# Out:
# [1] "/home/jovyan/R/x86_64-pc-linux-gnu-library/4.0"
# [2] "/usr/local/lib/R/site-library"
# [3] "/usr/lib/R/site-library"
# [4] "/usr/lib/R/library"

# %%
# %%R
# #library(argparse)
# library(Signac) # BiocManager::install("Signac"), then manually install missing packages, updating none (otherwise I get errors)
# library(GenomicRanges)
# library(data.table)
# #   library(cellatacUtils)
# library(EnsDb.Hsapiens.v86) # BiocManager::install("EnsDb.Hsapiens.v86")
# library(tidyverse)
# #library(EnsDb.Mmusculus.v79)
# Out:
# R[write to console]: Loading required package: stats4
#
# R[write to console]: Loading required package: BiocGenerics
#
# R[write to console]:
# Attaching package: ‘BiocGenerics’
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# R[write to console]: Loading required package: S4Vectors
#
# R[write to console]:
# Attaching package: ‘S4Vectors’
#
#
# R[write to console]: The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# R[write to console]: Loading required package: IRanges
#
# R[write to console]: Loading required package: GenomeInfoDb
#
# R[write to console]: data.table 1.14.2 using 30 threads (see ?getDTthreads).  Latest news: r-datatable.com
#
# R[write to console]:
# Attaching package: ‘data.table’
#
#
# R[write to console]: The following object is masked from ‘package:GenomicRanges’:
#
#     shift
#
#
# R[write to console]: The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# R[write to console]: The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
# R[write to console]: Loading required package: ensembldb
#
# R[write to console]: Loading required package: GenomicFeatures
#
# R[write to console]: Loading required package: AnnotationDbi
#
# R[write to console]: Loading required package: Biobase
#
# R[write to console]: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# R[write to console]: Loading required package: AnnotationFilter
#
# R[write to console]:
# Attaching package: 'ensembldb'
#
#
# R[write to console]: The following object is masked from 'package:stats':
#
#     filter
#
#
# R[write to console]: Registered S3 method overwritten by 'cli':
#   method     from
#   print.boxx spatstat.geom
#
# R[write to console]: ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# R[write to console]: ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.1     ✔ forcats 0.5.1
#
# R[write to console]: ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::between()    masks data.table::between()
# ✖ dplyr::collapse()   masks IRanges::collapse()
# ✖ dplyr::combine()    masks Biobase::combine(), BiocGenerics::combine()
# ✖ dplyr::desc()       masks IRanges::desc()
# ✖ tidyr::expand()     masks S4Vectors::expand()
# ✖ dplyr::filter()     masks ensembldb::filter(), stats::filter()
# ✖ dplyr::first()      masks data.table::first(), S4Vectors::first()
# ✖ dplyr::lag()        masks stats::lag()
# ✖ dplyr::last()       masks data.table::last()
# ✖ ggplot2::Position() masks BiocGenerics::Position(), base::Position()
# ✖ purrr::reduce()     masks GenomicRanges::reduce(), IRanges::reduce(), Signac::reduce()
# ✖ dplyr::rename()     masks S4Vectors::rename()
# ✖ dplyr::select()     masks ensembldb::select(), AnnotationDbi::select()
# ✖ dplyr::slice()      masks IRanges::slice()
# ✖ purrr::transpose()  masks data.table::transpose()

# %%
# %%R
#
# sessionInfo()
# Out:
# R version 4.0.4 (2021-02-15)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.1 LTS
#
# Matrix products: default
# BLAS/LAPACK: /opt/conda/lib/libopenblasp-r0.3.12.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats4    tools     stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] forcats_0.5.1             stringr_1.4.0
#  [3] dplyr_1.0.7               purrr_0.3.4
#  [5] readr_2.1.1               tidyr_1.1.4
#  [7] tibble_3.1.6              ggplot2_3.3.5
#  [9] tidyverse_1.3.0           EnsDb.Hsapiens.v86_2.99.0
# [11] ensembldb_2.14.1          AnnotationFilter_1.14.0
# [13] GenomicFeatures_1.42.2    AnnotationDbi_1.52.0
# [15] Biobase_2.50.0            data.table_1.14.2
# [17] GenomicRanges_1.42.0      GenomeInfoDb_1.31.1
# [19] IRanges_2.24.1            S4Vectors_0.28.1
# [21] BiocGenerics_0.41.2       Signac_1.5.0
#
# loaded via a namespace (and not attached):
#   [1] utf8_1.2.2                  reticulate_1.18
#   [3] tidyselect_1.1.1            RSQLite_2.2.9
#   [5] htmlwidgets_1.5.4           grid_4.0.4
#   [7] docopt_0.7.1                BiocParallel_1.24.1
#   [9] Rtsne_0.15                  munsell_0.5.0
#  [11] codetools_0.2-18            ica_1.0-2
#  [13] future_1.21.0               miniUI_0.1.1.1
#  [15] withr_2.4.3                 colorspace_2.0-2
#  [17] rstudioapi_0.13             Seurat_4.0.6
#  [19] ROCR_1.0-11                 tensor_1.5
#  [21] listenv_0.8.0               MatrixGenerics_1.2.1
#  [23] slam_0.1-48                 GenomeInfoDbData_1.2.4
#  [25] polyclip_1.10-0             bit64_4.0.5
#  [27] farver_2.1.0                parallelly_1.30.0
#  [29] vctrs_0.3.8                 generics_0.1.1
#  [31] BiocFileCache_1.14.0        lsa_0.73.2
#  [33] ggseqlogo_0.1               R6_2.5.1
#  [35] bitops_1.0-7                spatstat.utils_2.1-0
#  [37] cachem_1.0.6                DelayedArray_0.16.3
#  [39] assertthat_0.2.1            promises_1.2.0.1
#  [41] scales_1.1.1                gtable_0.3.0
#  [43] globals_0.14.0              goftest_1.2-2
#  [45] rlang_0.4.12                RcppRoll_0.3.0
#  [47] splines_4.0.4               rtracklayer_1.50.0
#  [49] lazyeval_0.2.2              spatstat.geom_2.0-1
#  [51] broom_0.7.5                 reshape2_1.4.4
#  [53] abind_1.4-5                 modelr_0.1.8
#  [55] backports_1.2.1             httpuv_1.6.5
#  [57] ellipsis_0.3.2              spatstat.core_2.0-0
#  [59] RColorBrewer_1.1-2          ggridges_0.5.3
#  [61] Rcpp_1.0.7                  plyr_1.8.6
#  [63] progress_1.2.2              zlibbioc_1.36.0
#  [65] RCurl_1.98-1.5              prettyunits_1.1.1
#  [67] rpart_4.1-15                openssl_1.4.6
#  [69] deldir_0.2-10               pbapply_1.4-3
#  [71] cowplot_1.1.1               zoo_1.8-9
#  [73] SeuratObject_4.0.4          SummarizedExperiment_1.20.0
#  [75] haven_2.3.1                 ggrepel_0.9.1
#  [77] cluster_2.1.1               fs_1.5.2
#  [79] magrittr_2.0.1              scattermore_0.7
#  [81] reprex_1.0.0                lmtest_0.9-38
#  [83] RANN_2.6.1                  SnowballC_0.7.0
#  [85] ProtGenerics_1.22.0         fitdistrplus_1.1-6
#  [87] matrixStats_0.61.0          hms_1.1.1
#  [89] patchwork_1.1.1             mime_0.12
#  [91] xtable_1.8-4                XML_3.99-0.8
#  [93] sparsesvd_0.2               readxl_1.3.1
#  [95] gridExtra_2.3               compiler_4.0.4
#  [97] biomaRt_2.46.3              KernSmooth_2.23-18
#  [99] crayon_1.4.2                htmltools_0.5.2
# [101] mgcv_1.8-34                 later_1.3.0
# [103] tzdb_0.2.0                  lubridate_1.7.10
# [105] DBI_1.1.2                   tweenr_1.0.2
# [107] dbplyr_2.1.0                MASS_7.3-53.1
# [109] rappdirs_0.3.3              Matrix_1.4-0
# [111] cli_3.1.0                   parallel_4.0.4
# [113] igraph_1.2.8                pkgconfig_2.0.3
# [115] GenomicAlignments_1.26.0    plotly_4.10.0
# [117] spatstat.sparse_2.1-0       xml2_1.3.2
# [119] XVector_0.30.0              rvest_1.0.0
# [121] digest_0.6.29               sctransform_0.3.2
# [123] RcppAnnoy_0.0.19            spatstat.data_2.1-2
# [125] Biostrings_2.58.0           cellranger_1.1.0
# [127] leiden_0.3.9                fastmatch_1.1-3
# [129] uwot_0.1.11                 curl_4.3.2
# [131] shiny_1.7.1                 Rsamtools_2.6.0
# [133] lifecycle_1.0.1             nlme_3.1-152
# [135] jsonlite_1.7.2              viridisLite_0.4.0
# [137] askpass_1.1                 fansi_1.0.0
# [139] pillar_1.6.4                lattice_0.20-41
# [141] fastmap_1.1.0               httr_1.4.2
# [143] survival_3.2-10             glue_1.6.0
# [145] qlcMatrix_0.9.7             png_0.1-7
# [147] bit_4.0.4                   ggforce_0.3.3
# [149] stringi_1.7.6               blob_1.2.2
# [151] memoise_2.0.1               irlba_2.3.5
# [153] future.apply_1.7.0

# %%
# %%R
#
# ### Annotate peaks w GenomicRanges ###
#
# peak_file <- '/lustre/scratch117/cellgen/team292/aa22/with_Stijn/202111_snATAC-seq_data_MFI/multiome_ATAC_samples_analysis/trophoblast_only_analysis/results200k_customcls4/peak_matrix/peaks.txt'
# outdir <- '/lustre/scratch117/cellgen/team292/aa22/with_Stijn/202111_snATAC-seq_data_MFI/multiome_ATAC_samples_analysis/trophoblast_only_analysis/downstream_analysis_custom_clust/'
# genome <- 'hg38'
#
#
# #' Get annotation overlap
# #'
# #' Computes overlap between GenomicRanges object and annotation coordinates
# #'
# #' @param gr GenomicRanges object
# #' @param anno_gr GenomicRanges object of annotations (usually loaded from ensembldb package)
# #' @param anno_name character of name of annotation (e.g. genes, exons, promoters ...)
# #' @param minoverlap minimum no of overlapping bps to call an overlap
# #'
# #' @return GenomicRanges object with overlap stored in metadata column
# #'
# get_annotation_overlap <- function(gr, anno_gr, anno_name, minoverlap = 10){
#   ## Clean annotation object
#   seqlevelsStyle(anno_gr) <- 'UCSC'
#   anno_gr <- keepStandardChromosomes(anno_gr, pruning.mode = 'coarse')
#   ## Find overlaps
#   overlaps <- findOverlaps(gr, anno_gr, minoverlap = minoverlap)
#   gr@elementMetadata[anno_name] <- 0
#   gr@elementMetadata[anno_name][queryHits(overlaps),] <- 1
#   return(gr)
# }

# %%
# %%R
#
# #' Annotate GenomicRanges
# #'
# #' add width and overlap with annotations to metadata columns of GenomicRanges object
# #'
# #' @param gr GenomicRanges object to annotate
# #' @param EnsDb.genome Ensembl annotation package to use for annotation. See details for installation (default = EnsDb.Hsapiens.v86, for hg38).
# #' @param blacklist_gr GenomicRanges object of ENCODE blacklist regions (default: blacklist_hg38 from Signac package)
# #' @param minoverlap minimum no of overlapping bps to call an overlap
# #'
# #' @details You can install EnsDb annotation packages by running
# #' \code{BiocManager::install("EnsDb.Hsapiens.v86")}
# #'
# #' @import ensembldb
# #' @import dplyr
# #' @import GenomicRanges
# #' @import GenomeInfoDb
# #' @import Signac
# #' @import ensembldb
# #' @importFrom stats setNames
# #'
# #' @export
# annotate_gr <- function(gr, EnsDb.genome = EnsDb.Hsapiens.v86, blacklist_gr = Signac::blacklist_hg38, minoverlap=10){
#   ## Compute width
#   gr$peak_width <- width(gr)
#
#   ## Compute overlap with annotations
#   exon_coords <- ensembldb::exons(EnsDb.genome, filter = ~ gene_biotype == "protein_coding")
#   genes_coords <- ensembldb::genes(EnsDb.genome, filter = ~ gene_biotype == "protein_coding")
#   promoter_coords <- ensembldb::promoters(EnsDb.genome, filter = ~ gene_biotype == "protein_coding", upstream=2000, downstream = 100)
#   anno_list <- list(exon=exon_coords, gene=genes_coords, promoter=promoter_coords)
#   for (i in seq_along(anno_list)) {
#     gr <- get_annotation_overlap(gr, anno_gr = anno_list[[i]], anno_name = names(anno_list)[i], minoverlap=minoverlap)
#   }
#   gr$annotation <- data.frame(gr@elementMetadata) %>%
#     mutate(annotation = case_when(exon==1 ~ "exon",
#                                   promoter==1 ~ "promoter",
#                                   gene==1 & exon==0 ~ "intron",
#                                   TRUE ~ "intergenic"
#     )) %>%
#     pull(annotation)
#
#   ## Overlapping gene
#   seqlevelsStyle(genes_coords) <- 'UCSC'
#   genes_coords <- keepStandardChromosomes(genes_coords, pruning.mode = 'coarse')
#   genespromoters_coords <- Extend(genes_coords, upstream = 2000)
#   overlap <- findOverlaps(gr, genespromoters_coords, minoverlap = minoverlap)
#   gr$gene_name <- NA
#   gr$gene_id <- NA
#   gr$gene_name[queryHits(overlap)] <- genespromoters_coords$gene_name[subjectHits(overlap)]
#   gr$gene_id[queryHits(overlap)] <- genespromoters_coords$gene_id[subjectHits(overlap)]
#
#   ## Distance to nearest TSS
#   transcript_coords <- ensembldb::transcripts(EnsDb.genome, filter = ~ gene_biotype == "protein_coding")
#   seqlevelsStyle(transcript_coords) <- 'UCSC'
#   transcript_coords <- keepStandardChromosomes(transcript_coords, pruning.mode = 'coarse')
#   tss_coords <- resize(unlist(range(split(transcript_coords, ~ tx_id))), width=1)
#   tss_distance <- distanceToNearest(gr, tss_coords)
#   gr$tss_distance <- tss_distance@elementMetadata$distance
#
#   ## Overlap with blacklist
#   gr <- get_annotation_overlap(gr, anno_gr = blacklist_gr, anno_name = "ENCODE_blacklist")
#
#   return(gr)
# }

# %%
# %%R
#
# # prefix <- "GSE126074_P0_BrainCortex_SNAREseq_"
# # atac.id <- "chromatin"
# # peak_file <- paste0(data.dir, "ATAC_raw/", prefix, atac.id, ".peaks.tsv.gz")
# # genome = "mm10"
#
# if (genome=="hg38") {
#   EnsDb.genome = EnsDb.Hsapiens.v86
#   blacklist_gr = blacklist_hg38
# } else if (genome=="mm10"){
#   EnsDb.genome = EnsDb.Mmusculus.v79
#   blacklist_gr = blacklist_mm10
# } else {
#   stop("Unrecognized genome ID. Supported genomes: hg38, mm10")
# }

# %%
# %%R
#
# peak_ids <- fread(peak_file, header = F)[["V1"]]
# peaks_gr <- StringToGRanges(peak_ids, sep=c(":","-"))

# %%
# %%R
#
# peaks_gr <- annotate_gr(peaks_gr, EnsDb.genome, blacklist_gr)

# %%
# %%R
#
# peaks_df <- data.frame(peaks_gr@elementMetadata)
# peaks_df["peak_id"] <- peak_ids
#
# write.csv(peaks_df, paste0(outdir, "/","ATACpeaks_annotation_20220119.csv" ))
