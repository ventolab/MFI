# %% [markdown]
# # Preparation for scVI:
#
# - subsetting data to non-doublet droplets as identified in M1 notebook
# - excluding soupy genes as defined and calculated in notebook M2
# - calculating cell cycle-associated genes
# - calculating optimal number of PCs to then guide n_latent variables in scVI

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import seaborn as sns
import scanpy as sc
import glob
import anndata
import bbknn
import scrublet as scr
import os
import sklearn
from sklearn.linear_model import LogisticRegression
import matplotlib as mpl
import scipy
import matplotlib.pyplot as plt
import pickle

# %%
np.random.seed(0)

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80)  # low dpi (dots per inch) yields small inline figures
# Out:
# WARNING: If you miss a compact list, please try `print_header`!
# -----
# anndata     0.7.5
# scanpy      1.7.1
# sinfo       0.3.1
# -----
# PIL                 8.1.2
# anndata             0.7.5
# annoy               NA
# anyio               NA
# attr                20.3.0
# babel               2.9.0
# backcall            0.2.0
# bbknn               NA
# brotli              NA
# cairo               1.20.0
# certifi             2020.12.05
# cffi                1.14.5
# chardet             4.0.0
# cloudpickle         1.6.0
# colorama            0.4.4
# cycler              0.10.0
# cython_runtime      NA
# cytoolz             0.11.0
# dask                2021.03.1
# dateutil            2.8.1
# decorator           4.4.2
# fsspec              0.8.7
# get_version         2.1
# google              NA
# h5py                3.1.0
# idna                2.10
# igraph              0.8.3
# ipykernel           5.5.0
# ipython_genutils    0.2.0
# ipywidgets          7.6.3
# jedi                0.18.0
# jinja2              2.11.3
# joblib              1.0.1
# json5               NA
# jsonschema          3.2.0
# jupyter_server      1.4.1
# jupyterlab_server   2.3.0
# kiwisolver          1.3.1
# legacy_api_wrap     0.0.0
# leidenalg           0.8.3
# llvmlite            0.34.0
# louvain             0.7.0
# markupsafe          1.1.1
# matplotlib          3.3.4
# mpl_toolkits        NA
# natsort             7.1.1
# nbclassic           NA
# nbformat            5.1.2
# numba               0.51.2
# numexpr             2.7.3
# numpy               1.20.1
# packaging           20.9
# pandas              1.2.3
# parso               0.8.1
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# prometheus_client   NA
# prompt_toolkit      3.0.16
# psutil              5.8.0
# ptyprocess          0.7.0
# pvectorc            NA
# pyarrow             0.16.0
# pycparser           2.20
# pygments            2.8.0
# pynndescent         0.5.2
# pyparsing           2.4.7
# pyrsistent          NA
# pytoml              NA
# pytz                2021.1
# requests            2.25.1
# ruamel              NA
# scanpy              1.7.1
# scipy               1.6.1
# scrublet            NA
# seaborn             0.11.1
# send2trash          NA
# setuptools_scm      NA
# sinfo               0.3.1
# six                 1.15.0
# sklearn             0.24.1
# sniffio             1.2.0
# socks               1.7.1
# sphinxcontrib       NA
# statsmodels         0.12.2
# storemagic          NA
# tables              3.6.1
# tblib               1.7.0
# texttable           1.6.3
# tlz                 0.11.0
# toolz               0.11.1
# tornado             6.1
# traitlets           5.0.5
# typing_extensions   NA
# umap                0.4.6
# urllib3             1.26.3
# wcwidth             0.2.5
# yaml                5.3.1
# zmq                 22.0.3
# -----
# IPython             7.21.0
# jupyter_client      6.1.11
# jupyter_core        4.7.1
# jupyterlab          3.0.9
# notebook            6.2.0
# -----
# Python 3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:22:27) [GCC 9.3.0]
# Linux-4.15.0-158-generic-x86_64-with-glibc2.10
# 60 logical CPU cores, x86_64
# -----
# Session information updated at 2021-11-12 14:19

# %%
save_path = '/lustre/scratch117/cellgen/team292/aa22/adata_objects/202111_MFI_sc_sn_new_scVI_analysis/'

# %% [markdown]
# ## Reading in raw filtered test data
#
# As produced in M0 notebook

# %%
# takes a few minutes
adata = sc.read(save_path + 'adata_raw_filtered.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 430136 × 30800
#     obs: 'n_genes', 'sample', 'technology', 'tissue', 'dev_age', 'donor', 'dataset', 'run', 'number_of_individuals_multiplexed', 'batch', 'percent_mito', 'n_counts', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'is_doublet'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-10', 'feature_types-10', 'genome-10', 'n_cells-10', 'gene_ids-11', 'feature_types-11', 'genome-11', 'n_cells-11', 'gene_ids-12', 'feature_types-12', 'genome-12', 'n_cells-12', 'gene_ids-13', 'feature_types-13', 'genome-13', 'n_cells-13', 'gene_ids-14', 'feature_types-14', 'genome-14', 'n_cells-14', 'gene_ids-15', 'feature_types-15', 'genome-15', 'n_cells-15', 'gene_ids-16', 'feature_types-16', 'genome-16', 'n_cells-16', 'gene_ids-17', 'feature_types-17', 'genome-17', 'n_cells-17', 'gene_ids-18', 'feature_types-18', 'genome-18', 'n_cells-18', 'gene_ids-19', 'feature_types-19', 'genome-19', 'n_cells-19', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-20', 'feature_types-20', 'genome-20', 'n_cells-20', 'gene_ids-21', 'feature_types-21', 'genome-21', 'n_cells-21', 'gene_ids-22', 'feature_types-22', 'genome-22', 'n_cells-22', 'gene_ids-23', 'feature_types-23', 'genome-23', 'n_cells-23', 'gene_ids-24', 'feature_types-24', 'genome-24', 'n_cells-24', 'gene_ids-25', 'feature_types-25', 'genome-25', 'n_cells-25', 'gene_ids-26', 'feature_types-26', 'genome-26', 'n_cells-26', 'gene_ids-27', 'feature_types-27', 'genome-27', 'n_cells-27', 'gene_ids-28', 'feature_types-28', 'genome-28', 'n_cells-28', 'gene_ids-29', 'feature_types-29', 'genome-29', 'n_cells-29', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-30', 'feature_types-30', 'genome-30', 'n_cells-30', 'gene_ids-31', 'feature_types-31', 'genome-31', 'n_cells-31', 'gene_ids-32', 'feature_types-32', 'genome-32', 'n_cells-32', 'gene_ids-33', 'feature_types-33', 'genome-33', 'n_cells-33', 'gene_ids-34', 'feature_types-34', 'genome-34', 'n_cells-34', 'gene_ids-35', 'feature_types-35', 'genome-35', 'n_cells-35', 'gene_ids-36', 'feature_types-36', 'genome-36', 'n_cells-36', 'gene_ids-37', 'feature_types-37', 'genome-37', 'n_cells-37', 'gene_ids-38', 'feature_types-38', 'genome-38', 'n_cells-38', 'gene_ids-39', 'feature_types-39', 'genome-39', 'n_cells-39', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-40', 'feature_types-40', 'genome-40', 'n_cells-40', 'gene_ids-41', 'feature_types-41', 'genome-41', 'n_cells-41', 'gene_ids-42', 'feature_types-42', 'genome-42', 'n_cells-42', 'gene_ids-43', 'feature_types-43', 'genome-43', 'n_cells-43', 'gene_ids-44', 'feature_types-44', 'genome-44', 'n_cells-44', 'gene_ids-45', 'feature_types-45', 'genome-45', 'n_cells-45', 'gene_ids-46', 'feature_types-46', 'genome-46', 'n_cells-46', 'gene_ids-47', 'feature_types-47', 'genome-47', 'n_cells-47', 'gene_ids-48', 'feature_types-48', 'genome-48', 'n_cells-48', 'gene_ids-49', 'feature_types-49', 'genome-49', 'n_cells-49', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-50', 'feature_types-50', 'genome-50', 'n_cells-50', 'gene_ids-51', 'feature_types-51', 'genome-51', 'n_cells-51', 'gene_ids-52', 'feature_types-52', 'genome-52', 'n_cells-52', 'gene_ids-53', 'feature_types-53', 'genome-53', 'n_cells-53', 'gene_ids-54', 'feature_types-54', 'genome-54', 'n_cells-54', 'gene_ids-55', 'feature_types-55', 'genome-55', 'n_cells-55', 'gene_ids-56', 'feature_types-56', 'genome-56', 'n_cells-56', 'gene_ids-57', 'feature_types-57', 'genome-57', 'n_cells-57', 'gene_ids-58', 'feature_types-58', 'genome-58', 'n_cells-58', 'gene_ids-59', 'feature_types-59', 'genome-59', 'n_cells-59', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-60', 'feature_types-60', 'genome-60', 'n_cells-60', 'gene_ids-61', 'feature_types-61', 'genome-61', 'n_cells-61', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7', 'gene_ids-8', 'feature_types-8', 'genome-8', 'n_cells-8', 'gene_ids-9', 'feature_types-9', 'genome-9', 'n_cells-9'

# %%
# read in table without GEX and genotype doublets
no_doublets_table = pd.read_csv(save_path + 'selected_droplets_no_doublets_in_M1_prelim_analysis.csv',
                               index_col=0)
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# subset data
adata = adata[no_doublets_table.index,:].copy()
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
# add other metadata
for col in no_doublets_table.columns:
    print(col)
    adata.obs[col] = no_doublets_table.loc[adata.obs_names,col]
# Out:
# n_genes
# sample
# technology
# tissue
# dev_age
# donor
# dataset
# run
# number_of_individuals_multiplexed
# batch
# percent_mito
# n_counts
# scrublet_score
# scrublet_cluster_score
# bh_pval
# is_doublet
# celltype_predictions
# probabilities
# barcode_sample_copy
# souporcell_assignment
# inter_ind_doublet
# S_score
# G2M_score
# phase
# origin_M_F
# is_doublet_0.05
# is_doublet_0.01

# %% [markdown]
# _______

# %% [markdown]
# Carrying on to
# - Normalise and log transform
# - Save raw attribute to then be able to plot all genes on the HVG-subsetted dataset
# - Make cell names (obs) and gene names (var) unique

# %%
# normalise and log transform
sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)
sc.pp.log1p(adata)

# saving the raw attribute
adata.raw = adata.copy()

adata.var_names_make_unique()
adata.obs_names_make_unique()
# Out:
# normalizing by total count per cell
#     finished (0:00:13): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 378558 × 30800
#     obs: 'n_genes', 'sample', 'technology', 'tissue', 'dev_age', 'donor', 'dataset', 'run', 'number_of_individuals_multiplexed', 'batch', 'percent_mito', 'n_counts', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'is_doublet', 'celltype_predictions', 'probabilities', 'barcode_sample_copy', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'origin_M_F', 'is_doublet_0.05', 'is_doublet_0.01'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-10', 'feature_types-10', 'genome-10', 'n_cells-10', 'gene_ids-11', 'feature_types-11', 'genome-11', 'n_cells-11', 'gene_ids-12', 'feature_types-12', 'genome-12', 'n_cells-12', 'gene_ids-13', 'feature_types-13', 'genome-13', 'n_cells-13', 'gene_ids-14', 'feature_types-14', 'genome-14', 'n_cells-14', 'gene_ids-15', 'feature_types-15', 'genome-15', 'n_cells-15', 'gene_ids-16', 'feature_types-16', 'genome-16', 'n_cells-16', 'gene_ids-17', 'feature_types-17', 'genome-17', 'n_cells-17', 'gene_ids-18', 'feature_types-18', 'genome-18', 'n_cells-18', 'gene_ids-19', 'feature_types-19', 'genome-19', 'n_cells-19', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-20', 'feature_types-20', 'genome-20', 'n_cells-20', 'gene_ids-21', 'feature_types-21', 'genome-21', 'n_cells-21', 'gene_ids-22', 'feature_types-22', 'genome-22', 'n_cells-22', 'gene_ids-23', 'feature_types-23', 'genome-23', 'n_cells-23', 'gene_ids-24', 'feature_types-24', 'genome-24', 'n_cells-24', 'gene_ids-25', 'feature_types-25', 'genome-25', 'n_cells-25', 'gene_ids-26', 'feature_types-26', 'genome-26', 'n_cells-26', 'gene_ids-27', 'feature_types-27', 'genome-27', 'n_cells-27', 'gene_ids-28', 'feature_types-28', 'genome-28', 'n_cells-28', 'gene_ids-29', 'feature_types-29', 'genome-29', 'n_cells-29', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-30', 'feature_types-30', 'genome-30', 'n_cells-30', 'gene_ids-31', 'feature_types-31', 'genome-31', 'n_cells-31', 'gene_ids-32', 'feature_types-32', 'genome-32', 'n_cells-32', 'gene_ids-33', 'feature_types-33', 'genome-33', 'n_cells-33', 'gene_ids-34', 'feature_types-34', 'genome-34', 'n_cells-34', 'gene_ids-35', 'feature_types-35', 'genome-35', 'n_cells-35', 'gene_ids-36', 'feature_types-36', 'genome-36', 'n_cells-36', 'gene_ids-37', 'feature_types-37', 'genome-37', 'n_cells-37', 'gene_ids-38', 'feature_types-38', 'genome-38', 'n_cells-38', 'gene_ids-39', 'feature_types-39', 'genome-39', 'n_cells-39', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-40', 'feature_types-40', 'genome-40', 'n_cells-40', 'gene_ids-41', 'feature_types-41', 'genome-41', 'n_cells-41', 'gene_ids-42', 'feature_types-42', 'genome-42', 'n_cells-42', 'gene_ids-43', 'feature_types-43', 'genome-43', 'n_cells-43', 'gene_ids-44', 'feature_types-44', 'genome-44', 'n_cells-44', 'gene_ids-45', 'feature_types-45', 'genome-45', 'n_cells-45', 'gene_ids-46', 'feature_types-46', 'genome-46', 'n_cells-46', 'gene_ids-47', 'feature_types-47', 'genome-47', 'n_cells-47', 'gene_ids-48', 'feature_types-48', 'genome-48', 'n_cells-48', 'gene_ids-49', 'feature_types-49', 'genome-49', 'n_cells-49', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-50', 'feature_types-50', 'genome-50', 'n_cells-50', 'gene_ids-51', 'feature_types-51', 'genome-51', 'n_cells-51', 'gene_ids-52', 'feature_types-52', 'genome-52', 'n_cells-52', 'gene_ids-53', 'feature_types-53', 'genome-53', 'n_cells-53', 'gene_ids-54', 'feature_types-54', 'genome-54', 'n_cells-54', 'gene_ids-55', 'feature_types-55', 'genome-55', 'n_cells-55', 'gene_ids-56', 'feature_types-56', 'genome-56', 'n_cells-56', 'gene_ids-57', 'feature_types-57', 'genome-57', 'n_cells-57', 'gene_ids-58', 'feature_types-58', 'genome-58', 'n_cells-58', 'gene_ids-59', 'feature_types-59', 'genome-59', 'n_cells-59', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-60', 'feature_types-60', 'genome-60', 'n_cells-60', 'gene_ids-61', 'feature_types-61', 'genome-61', 'n_cells-61', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7', 'gene_ids-8', 'feature_types-8', 'genome-8', 'n_cells-8', 'gene_ids-9', 'feature_types-9', 'genome-9', 'n_cells-9'
#     uns: 'log1p'

# %%
gene_stats_sc = pd.read_csv(save_path + 'gene_filter_cells_upd_20211111.csv', index_col=0)
gene_stats_sn = pd.read_csv(save_path + 'gene_filter_nuclei_upd_20211111.csv', index_col=0)

# %%
gene_stats_sc
# Out:
#              Empty_droplet_sum  Cell_sum  Soup_probability  Selected
# MIR1302-2HG                1.0       0.0          1.000000     False
# AL627309.1                14.0      29.0          0.325581      True
# AL732372.1                 6.0       0.0          1.000000     False
# AL669831.5               180.0     352.0          0.338346      True
# FAM87B                    16.0      45.0          0.262295      True
# ...                        ...       ...               ...       ...
# AC007325.4               402.0     583.0          0.408122      True
# AC007325.2                13.0      38.0          0.254902      True
# AL354822.1                60.0     272.0          0.180723      True
# AC004556.1                25.0      35.0          0.416667      True
# AC240274.1                72.0     500.0          0.125874      True
#
# [24164 rows x 4 columns]

# %%
list(gene_stats_sc[gene_stats_sc['Selected'] == True].index)
# Out:
# ['AL627309.1',
#  'AL669831.5',
#  'FAM87B',
#  'LINC00115',
#  'FAM41C',
#  'AL645608.3',
#  'AL645608.5',
#  'AL645608.1',
#  'SAMD11',
#  'NOC2L',
#  'PLEKHN1',
#  'PERM1',
#  'AL645608.8',
#  'HES4',
#  'AGRN',
#  'AL645608.9',
#  'C1orf159',
#  'AL390719.2',
#  'TTLL10',
#  'TNFRSF18',
#  'TNFRSF4',
#  'SDF4',
#  'B3GALT6',
#  'C1QTNF12',
#  'UBE2J2',
#  'LINC01786',
#  'SCNN1D',
#  'ACAP3',
#  'PUSL1',
#  'INTS11',
#  'CPTP',
#  'TAS1R3',
#  'DVL1',
#  'MXRA8',
#  'CCNL2',
#  'AL391244.3',
#  'ANKRD65',
#  'LINC01770',
#  'VWA1',
#  'ATAD3C',
#  'ATAD3A',
#  'TMEM240',
#  'SSU72',
#  'AL645728.1',
#  'AL691432.2',
#  'MIB2',
#  'MMP23B',
#  'CDK11B',
#  'SLC35E2B',
#  'CDK11A',
#  'SLC35E2A',
#  'NADK',
#  'GNB1',
#  'AL109917.1',
#  'TMEM52',
#  'CFAP74',
#  'AL391845.2',
#  'GABRD',
#  'PRKCZ',
#  'AL590822.2',
#  'PRKCZ-AS1',
#  'FAAP20',
#  'SKI',
#  'MORN1',
#  'RER1',
#  'PEX10',
#  'PLCH2',
#  'PANK4',
#  'HES5',
#  'TNFRSF14-AS1',
#  'AL139246.3',
#  'FAM213B',
#  'MMEL1',
#  'MEGF6',
#  'TPRG1L',
#  'WRAP73',
#  'LRRC47',
#  'CEP104',
#  'DFFB',
#  'C1orf174',
#  'AL805961.2',
#  'AJAP1',
#  'NPHP4',
#  'KCNAB2',
#  'CHD5',
#  'RNF207',
#  'ICMT',
#  'GPR153',
#  'ACOT7',
#  'AL031848.2',
#  'HES2',
#  'PLEKHG5',
#  'NOL9',
#  'ZBTB48',
#  'KLHL21',
#  'PHF13',
#  'THAP3',
#  'LINC01672',
#  'AL591163.1',
#  'VAMP3',
#  'PER3',
#  'TNFRSF9',
#  'AL034417.4',
#  'AL034417.3',
#  'ERRFI1',
#  'AL034417.2',
#  'SLC45A1',
#  'RERE',
#  'ENO1',
#  'ENO1-AS1',
#  'GPR157',
#  'MIR34AHG',
#  'LINC01759',
#  'H6PD',
#  'SPSB1',
#  'BX323043.1',
#  'AL928921.2',
#  'SLC25A33',
#  'TMEM201',
#  'PIK3CD-AS2',
#  'CLSTN1',
#  'CTNNBIP1',
#  'NMNAT1',
#  'UBE4B',
#  'KIF1B',
#  'AL139424.3',
#  'PGD',
#  'CENPS-CORT',
#  'CENPS',
#  'DFFA',
#  'PEX14',
#  'CASZ1',
#  'TARDBP',
#  'MASP2',
#  'AL109811.3',
#  'SRM',
#  'EXOSC10',
#  'AL109811.1',
#  'AL109811.2',
#  'MTOR',
#  'UBIAD1',
#  'AL031731.1',
#  'FBXO2',
#  'FBXO44',
#  'FBXO6',
#  'MAD2L2',
#  'DRAXIN',
#  'AGTRAP',
#  'C1orf167',
#  'MTHFR',
#  'CLCN6',
#  'NPPA',
#  'NPPB',
#  'KIAA2013',
#  'PLOD1',
#  'MFN2',
#  'MIIP',
#  'TNFRSF8',
#  'TNFRSF1B',
#  'VPS13D',
#  'DHRS3',
#  'AADACL4',
#  'AADACL3',
#  'C1orf158',
#  'LRRC38',
#  'PDPN',
#  'PRDM2',
#  'KAZN',
#  'TMEM51',
#  'FHAD1',
#  'AL031283.2',
#  'CTRC',
#  'CELA2A',
#  'CASP9',
#  'DNAJC16',
#  'AGMAT',
#  'DDI2',
#  'AL121992.2',
#  'PLEKHM2',
#  'SLC25A34',
#  'FBLIM1',
#  'AL450998.2',
#  'SPEN',
#  'ZBTB17',
#  'HSPB7',
#  'FAM131C',
#  'EPHA2',
#  'ARHGEF19',
#  'CPLANE2',
#  'FBXO42',
#  'SZRD1',
#  'SPATA21',
#  'NECAP2',
#  'LINC01772',
#  'AL137802.2',
#  'LINC01783',
#  'NBPF1',
#  'CROCC',
#  'BX284668.6',
#  'MFAP2',
#  'ATP13A2',
#  'RCC2',
#  'ARHGEF10L',
#  'ALDH4A1',
#  'IFFO2',
#  'UBR4',
#  'EMC1',
#  'MRTO4',
#  'AKR7A3',
#  'AKR7A2',
#  'PQLC2',
#  'CAPZB',
#  'NBL1',
#  'TMCO4',
#  'OTUD3',
#  'PLA2G2A',
#  'PLA2G5',
#  'UBXN10',
#  'CAMK2N1',
#  'MUL1',
#  'FAM43B',
#  'PINK1',
#  'PINK1-AS',
#  'DDOST',
#  'KIF17',
#  'SH2D5',
#  'HP1BP3',
#  'EIF4G3',
#  'ECE1',
#  'AL031728.1',
#  'NBPF3',
#  'ALPL',
#  'USP48',
#  'HSPG2',
#  'CDC42',
#  'WNT4',
#  'ZBTB40',
#  'EPHB2',
#  'KDM1A',
#  'LUZP1',
#  'HTR1D',
#  'LINC01355',
#  'AL109936.6',
#  'HNRNPR',
#  'ZNF436',
#  'ZNF436-AS1',
#  'TCEA3',
#  'ASAP3',
#  'ID3',
#  'ELOA',
#  'ELOA-AS1',
#  'PITHD1',
#  'LYPLA2',
#  'GALE',
#  'HMGCL',
#  'FUCA1',
#  'CNR2',
#  'PNRC2',
#  'SRSF10',
#  'IL22RA1',
#  'STPG1',
#  'NIPAL3',
#  'AL445686.2',
#  'NCMAP',
#  'SRRM1',
#  'CLIC4',
#  'RUNX3',
#  'AL031432.1',
#  'SYF2',
#  'RSRP1',
#  'AL031432.3',
#  'TMEM50A',
#  'RHCE',
#  'MACO1',
#  'LDLRAP1',
#  'MAN1C1',
#  'AL031280.1',
#  'SELENON',
#  'MTFR1L',
#  'PAQR7',
#  'PAFAH2',
#  'EXTL1',
#  'SLC30A2',
#  'PDIK1L',
#  'FAM110D',
#  'AL391650.1',
#  'CNKSR1',
#  'CEP85',
#  'SH3BGRL3',
#  'ZNF683',
#  'DHDDS',
#  'AL512408.1',
#  'ARID1A',
#  'PIGV',
#  'ZDHHC18',
#  'SFN',
#  'GPN2',
#  'GPATCH3',
#  'NUDC',
#  'TRNP1',
#  'TENT5B',
#  'SLC9A1',
#  'WDTC1',
#  'TMEM222',
#  'SYTL1',
#  'MAP3K6',
#  'FCN3',
#  'CD164L2',
#  'GPR3',
#  'WASF2',
#  'AHDC1',
#  'FGR',
#  'FAM76A',
#  'STX12',
#  'PPP1R8',
#  'RPA2',
#  'SMPDL3B',
#  'XKR8',
#  'EYA3',
#  'DNAJC8',
#  'AL353622.1',
#  'SESN2',
#  'MED18',
#  'PHACTR4',
#  'RCC1',
#  'TRNAU1AP',
#  'TAF12',
#  'RAB42',
#  'GMEB1',
#  'YTHDF2',
#  'TMEM200B',
#  'SRSF4',
#  'MECR',
#  'PTPRU',
#  'MATN1',
#  'MATN1-AS1',
#  'LINC01778',
#  'SDC3',
#  'PUM1',
#  'NKAIN1',
#  'SNRNP40',
#  'ZCCHC17',
#  'SERINC2',
#  'TINAGL1',
#  'PEF1',
#  'AC114488.2',
#  'COL16A1',
#  'SPOCD1',
#  'AL354919.1',
#  'AL136115.2',
#  'PTP4A2',
#  'KHDRBS1',
#  'AL445248.1',
#  'TMEM39B',
#  'KPNA6',
#  'TXLNA',
#  'CCDC28B',
#  'IQCC',
#  'DCDC2B',
#  'TMEM234',
#  'EIF3I',
#  'FAM167B',
#  'LCK',
#  'HDAC1',
#  'MARCKSL1',
#  'TSSK3',
#  'FAM229A',
#  'BSDC1',
#  'ZBTB8B',
#  'ZBTB8A',
#  'RBBP4',
#  'SYNC',
#  'KIAA1522',
#  'YARS',
#  'S100PBP',
#  'FNDC5',
#  'HPCA',
#  'TMEM54',
#  'AK2',
#  'AZIN2',
#  'TRIM62',
#  'AL662907.3',
#  'ZNF362',
#  'AL513327.1',
#  'PHC2',
#  'ZSCAN20',
#  'CSMD2',
#  'SMIM12',
#  'GJA4',
#  'AC114490.3',
#  'TMEM35B',
#  'ZMYM6',
#  'ZMYM1',
#  'SFPQ',
#  'ZMYM4',
#  'KIAA0319L',
#  'NCDN',
#  'TFAP2E',
#  'PSMB2',
#  'C1orf216',
#  'CLSPN',
#  'AGO1',
#  'AL139286.2',
#  'AGO3',
#  'TEKT2',
#  'ADPRHL2',
#  'COL8A2',
#  'TRAPPC3',
#  'MAP7D1',
#  'THRAP3',
#  'EVA1B',
#  'AL591845.1',
#  'STK40',
#  'OSCP1',
#  'GRIK3',
#  'LINC01137',
#  'ZC3H12A',
#  'MEAF6',
#  'SNIP1',
#  'DNALI1',
#  'GNL2',
#  'RSPO1',
#  'C1orf109',
#  'CDCA8',
#  'MANEAL',
#  'YRDC',
#  'C1orf122',
#  'MTF1',
#  'AL929472.2',
#  'INPP5B',
#  'SF3A3',
#  'FHL3',
#  'UTP11',
#  'POU3F1',
#  'RRAGC',
#  'AL139260.1',
#  'MYCBP',
#  'RHBDL2',
#  'AKIRIN1',
#  'MACF1',
#  'BMP8A',
#  'PABPC4',
#  'HEYL',
#  'PPIE',
#  'BMP8B',
#  'OXCT2',
#  'TRIT1',
#  'AL033527.2',
#  'MFSD2A',
#  'CAP1',
#  'PPT1',
#  'RLF',
#  'AL050341.2',
#  'ZMPSTE24',
#  'COL9A2',
#  'SMAP2',
#  'ZFP69B',
#  'ZFP69',
#  'EXO5',
#  'ZNF684',
#  'NFYC-AS1',
#  'NFYC',
#  'CITED4',
#  'CTPS1',
#  'SLFNL1-AS1',
#  'SCMH1',
#  'AC093151.3',
#  'FOXO6',
#  'EDN2',
#  'HIVEP3',
#  'FOXJ3',
#  'ZMYND12',
#  'PPCS',
#  'CCDC30',
#  'P3H1',
#  'C1orf50',
#  'ERMAP',
#  'ZNF691',
#  'SLC2A1',
#  'SLC2A1-AS1',
#  'EBNA1BP2',
#  'CFAP57',
#  'TMEM125',
#  'C1orf210',
#  'TIE1',
#  'AL139289.2',
#  'CDC20',
#  'ELOVL1',
#  'SZT2',
#  'HYI',
#  'PTPRF',
#  'KDM4A',
#  'KDM4A-AS1',
#  'ST3GAL3',
#  'ARTN',
#  'AL357079.1',
#  'IPO13',
#  'DPH2',
#  'B4GALT2',
#  'CCDC24',
#  'SLC6A9',
#  'AL139220.2',
#  'DMAP1',
#  'ERI3',
#  'RNF220',
#  'TMEM53',
#  'KIF2C',
#  'RPS8',
#  'BEST4',
#  'PLK3',
#  'BTBD19',
#  'EIF2B3',
#  'HECTD3',
#  'UROD',
#  'ZSWIM5',
#  'LINC01144',
#  'HPDL',
#  'MUTYH',
#  'TOE1',
#  'TESK2',
#  'CCDC163',
#  'MMACHC',
#  'PRDX1',
#  'AKR1A1',
#  'NASP',
#  'CCDC17',
#  'GPBP1L1',
#  'TMEM69',
#  'IPP',
#  'MAST2',
#  'PIK3R3',
#  'AL358075.1',
#  'TSPAN1',
#  'POMGNT1',
#  'LURAP1',
#  'RAD54L',
#  'LRRC41',
#  'NSUN4',
#  'FAAH',
#  'MKNK1',
#  'MOB3C',
#  'ATPAF1',
#  'EFCAB14',
#  'CYP4B1',
#  'CYP4X1',
#  'CYP4Z1',
#  'LINC00853',
#  'PDZK1IP1',
#  'TAL1',
#  'AL135960.1',
#  'STIL',
#  'CMPK1',
#  'FOXD2-AS1',
#  'FOXD2',
#  'TRABD2B',
#  'SPATA6',
#  'AGBL4',
#  'BEND5',
#  'FAF1',
#  'CDKN2C',
#  'LINC01562',
#  'RNF11',
#  'AL162430.2',
#  'TTC39A',
#  'TTC39A-AS1',
#  'EPS15',
#  'OSBPL9',
#  'NRDC',
#  'AL050343.1',
#  'RAB3B',
#  'TXNDC12',
#  'KTI12',
#  'AL445685.1',
#  'BTF3L4',
#  'ZFYVE9',
#  'CC2D1B',
#  'PRPF38A',
#  'TUT4',
#  'GPX7',
#  'SHISAL2A',
#  'COA7',
#  'ZYG11B',
#  'ZYG11A',
#  'ECHDC2',
#  'PODN',
#  'CPT2',
#  'AL606760.2',
#  'C1orf123',
#  'AL606760.3',
#  'AL606760.1',
#  'LRP8',
#  'AC119428.2',
#  'GLIS1',
#  'NDC1',
#  'YIPF1',
#  'LRRC42',
#  'LDLRAD1',
#  'TMEM59',
#  'TCEANC2',
#  'AL357673.1',
#  'CYB5RL',
#  'MRPL37',
#  'SSBP3',
#  'ACOT11',
#  'TTC4',
#  'PARS2',
#  'LEXM',
#  'DHCR24',
#  'TMEM61',
#  'PCSK9',
#  'USP24',
#  'MIR4422HG',
#  'AL603840.1',
#  'AC119674.1',
#  'AC119674.2',
#  'PLPP3',
#  'PRKAA2',
#  'FYB2',
#  'C8B',
#  'DAB1',
#  'OMA1',
#  'TACSTD2',
#  'MYSM1',
#  'JUN',
#  'LINC01135',
#  'AC105277.1',
#  'FGGY',
#  'HOOK1',
#  'CYP2J2',
#  'NFIA',
#  'TM2D1',
#  'AC099791.2',
#  'PATJ',
#  'L1TD1',
#  'KANK4',
#  'USP1',
#  'DOCK7',
#  'AC103923.1',
#  'ATG4C',
#  'AC096543.1',
#  'ALG6',
#  'ITGB3BP',
#  'EFCAB7',
#  'PGM1',
#  'ROR1',
#  'CACHD1',
#  'RAVER2',
#  'JAK1',
#  'AK4',
#  'DNAJC6',
#  'LEPROT',
#  'LEPR',
#  'PDE4B',
#  'SGIP1',
#  'AL139147.1',
#  'TCTEX1D1',
#  'WDR78',
#  'MIER1',
#  'SLC35D1',
#  'C1orf141',
#  'IL23R',
#  'IL12RB2',
#  'SERBP1',
#  'GADD45A',
#  'GNG12',
#  'GNG12-AS1',
#  'DIRAS3',
#  'WLS',
#  'DEPDC1',
#  'DEPDC1-AS1',
#  'LRRC7',
#  'LRRC40',
#  'SRSF11',
#  'ANKRD13C',
#  'HHLA3',
#  'CTH',
#  'PTGER3',
#  'AL031429.1',
#  'ZRANB2-AS1',
#  'ZRANB2',
#  'NEGR1',
#  'AL354949.1',
#  'FPGT',
#  'FPGT-TNNI3K',
#  'TNNI3K',
#  'ERICH3',
#  'CRYZ',
#  'TYW3',
#  'ACADM',
#  'RABGGTB',
#  'ST6GALNAC3',
#  'AC104458.1',
#  'ST6GALNAC5',
#  'PIGK',
#  'AC118549.1',
#  'USP33',
#  'MIGA1',
#  'NEXN-AS1',
#  'NEXN',
#  'FUBP1',
#  'DNAJB4',
#  'GIPC2',
#  'PTGFR',
#  'IFI44L',
#  'IFI44',
#  'ADGRL4',
#  'LINC01781',
#  'ADGRL2',
#  'LINC01725',
#  'TTLL7',
#  'AL359504.2',
#  'PRKACB',
#  'SAMD13',
#  'RPF1',
#  'GNG5',
#  'SPATA1',
#  'CTBS',
#  'SSX2IP',
#  'MCOLN2',
#  'WDR63',
#  'MCOLN3',
#  'SYDE2',
#  'C1orf52',
#  'BCL10',
#  'AL078459.1',
#  'DDAH1',
#  'AL360219.1',
#  'AC092807.3',
#  'CYR61',
#  'AC092807.1',
#  'ZNHIT6',
#  'COL24A1',
#  'ODF2L',
#  'AL049597.2',
#  'SH3GLB1',
#  'HS2ST1',
#  'AC093155.3',
#  'LINC01140',
#  'AC099062.1',
#  'LMO4',
#  'PKN2',
#  'GTF2B',
#  'KYAT3',
#  'RBMXL1',
#  'GBP3',
#  'GBP1',
#  'GBP2',
#  'GBP7',
#  'GBP4',
#  'AC099063.4',
#  'GBP6',
#  'LRRC8B',
#  'AC099568.2',
#  'ZNF326',
#  'ZNF644',
#  'HFM1',
#  'CDC7',
#  'TGFBR3',
#  'BRDT',
#  'EPHX4',
#  'BTBD8',
#  'GLMN',
#  'RPAP2',
#  'GFI1',
#  'EVI5',
#  'FAM69A',
#  'MTF2',
#  'TMED5',
#  'CCDC18',
#  'DR1',
#  'FNBP1L',
#  'BCAR3',
#  'AL109613.1',
#  'DNTTIP2',
#  'GCLM',
#  'ABCA4',
#  'ARHGAP29',
#  'ABCD3',
#  'F3',
#  'SLC44A3',
#  'CNN3',
#  'AC105942.1',
#  'ALG14',
#  'TMEM56',
#  'AC092802.1',
#  'RWDD3',
#  'PTBP2',
#  'DPYD',
#  'SNX7',
#  'PLPPR4',
#  'PALMD',
#  'FRRS1',
#  'AGL',
#  'SLC35A3',
#  'AC118553.2',
#  'MFSD14A',
#  'SASS6',
#  'TRMT13',
#  'DBT',
#  'RTCA',
#  'CDC14A',
#  'VCAM1',
#  'EXTL2',
#  'AC104506.1',
#  'SLC30A7',
#  'DPH5',
#  'AC093157.2',
#  'AC093157.1',
#  'AL109741.1',
#  'S1PR1',
#  'COL11A1',
#  'RNPC3',
#  'AMY2B',
#  'AL355306.2',
#  'PRMT6',
#  'NTNG1',
#  'VAV3',
#  'SLC25A24',
#  'AL359258.2',
#  'FAM102B',
#  'HENMT1',
#  'PRPF38B',
#  'STXBP3',
#  'AKNAD1',
#  'AL449266.1',
#  'GPSM2',
#  'CLCC1',
#  'WDR47',
#  'TAF13',
#  'AL356488.3',
#  'TMEM167B',
#  'AL356488.2',
#  'C1orf194',
#  'KIAA1324',
#  'SARS',
#  'CELSR2',
#  'PSRC1',
#  'SORT1',
#  'PSMA5',
#  'SYPL2',
#  'ATXN7L2',
#  'CYB561D1',
#  'AMIGO1',
#  'GNAI3',
#  'AMPD2',
#  'GSTM4',
#  'GSTM2',
#  'GSTM5',
#  'EPS8L3',
#  'AL450468.2',
#  'CSF1',
#  'AHCYL1',
#  'STRIP1',
#  'AL160006.1',
#  'ALX3',
#  'SLC6A17',
#  'KCNC4',
#  'RBM15',
#  'SLC16A4',
#  'KCNA2',
#  'KCNA3',
#  'CD53',
#  'AL360270.1',
#  'LRIF1',
#  'AL360270.3',
#  'DRAM2',
#  'CEPT1',
#  'AL355816.2',
#  'DENND2D',
#  'PIFO',
#  'OVGP1',
#  'WDR77',
#  'ATP5PB',
#  'RAP1A',
#  'DDX20',
#  'KCND3',
#  'LINC01750',
#  'AL445426.1',
#  'CTTNBP2NL',
#  'WNT2B',
#  'AL354760.1',
#  'ST7L',
#  'CAPZA1',
#  'MOV10',
#  'AL603832.1',
#  'RHOC',
#  'PPM1J',
#  'FAM19A3',
#  'SLC16A1',
#  'SLC16A1-AS1',
#  'AL357055.3',
#  'LRIG2',
#  'MAGI3',
#  'PHTF1',
#  'RSBN1',
#  'PTPN22',
#  'AP4B1-AS1',
#  'BCL2L15',
#  'AP4B1',
#  'DCLRE1B',
#  'HIPK1-AS1',
#  'HIPK1',
#  'OLFML3',
#  'TRIM33',
#  'BCAS2',
#  'DENND2C',
#  'NRAS',
#  'CSDE1',
#  'SIKE1',
#  'TSPAN2',
#  'NGF',
#  'VANGL1',
#  'CASQ2',
#  'MAB21L3',
#  'ATP1A1',
#  'CD58',
#  'IGSF3',
#  'CD2',
#  'PTGFRN',
#  'CD101',
#  'TTF2',
#  'TRIM45',
#  'VTCN1',
#  'AL358072.1',
#  'MAN1A2',
#  'TENT5C',
#  'GDAP2',
#  'WDR3',
#  'SPAG17',
#  'TBX15',
#  'AL139420.1',
#  'WARS2',
#  'AL359915.2',
#  'ZNF697',
#  'PHGDH',
#  'NOTCH2',
#  'SEC22B',
#  'NBPF26',
#  'LINC00623',
#  'FAM72B',
#  'SRGAP2C',
#  'AC239800.2',
#  'AC239800.3',
#  'NBPF15',
#  'SRGAP2B',
#  'FAM72D',
#  'AC245014.3',
#  'AC245014.1',
#  'NBPF20',
#  'GPR89A',
#  'PDZK1',
#  'CD160',
#  'RNF115',
#  'POLR3C',
#  'PIAS3',
#  'ANKRD35',
#  'ITGA10',
#  'PEX11B',
#  'LIX1L-AS1',
#  'LIX1L',
#  'ANKRD34A',
#  'POLR3GL',
#  'TXNIP',
#  'LINC01719',
#  'NBPF10',
#  'NOTCH2NL',
#  'AC239799.2',
#  'AC245407.2',
#  'NBPF12',
#  'PRKAB2',
#  'AC242426.2',
#  'FMO5',
#  'CHD1L',
#  'LINC00624',
#  'BCL9',
#  'GPR89B',
#  'AC239803.2',
#  'NBPF11',
#  'AC239809.3',
#  'PPIAL4G',
#  'NBPF14',
#  'NUDT4B',
#  'PDE4DIP',
#  'AC239804.1',
#  'NBPF9',
#  'AC245297.3',
#  'AC245297.2',
#  'NBPF19',
#  'AC243772.2',
#  'HIST2H4A',
#  'HIST2H2AA3',
#  'AC239868.3',
#  'HIST2H2AA4',
#  'AC239868.2',
#  'HIST2H2BE',
#  'HIST2H2AC',
#  'HIST2H2AB',
#  'BOLA1',
#  'SV2A',
#  'SF3B4',
#  ...]

# %%
# excluding soupy genes as per notebook M3a-1

# gene stats for cells
gene_stats_sc = pd.read_csv(save_path + 'gene_filter_cells_upd_20211111.csv', index_col=0)

# gene stats for nuclei
gene_stats_sn = pd.read_csv(save_path + 'gene_filter_nuclei_upd_20211111.csv', index_col=0)

genes2keep_sc = list(gene_stats_sc[gene_stats_sc['Selected'] == True].index)
genes2keep_sn = list(gene_stats_sn[gene_stats_sn['Selected'] == True].index)

# overlap
genes2keep = list(set(genes2keep_sc) & set(genes2keep_sn))

len(genes2keep)
# Out:
# 7849

# %%
adata = adata[:,list(set(genes2keep) & set(adata.var_names))].copy()
adata
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# AnnData object with n_obs × n_vars = 378558 × 7848
#     obs: 'n_genes', 'sample', 'technology', 'tissue', 'dev_age', 'donor', 'dataset', 'run', 'number_of_individuals_multiplexed', 'batch', 'percent_mito', 'n_counts', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'is_doublet', 'celltype_predictions', 'probabilities', 'barcode_sample_copy', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'origin_M_F', 'is_doublet_0.05', 'is_doublet_0.01'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-10', 'feature_types-10', 'genome-10', 'n_cells-10', 'gene_ids-11', 'feature_types-11', 'genome-11', 'n_cells-11', 'gene_ids-12', 'feature_types-12', 'genome-12', 'n_cells-12', 'gene_ids-13', 'feature_types-13', 'genome-13', 'n_cells-13', 'gene_ids-14', 'feature_types-14', 'genome-14', 'n_cells-14', 'gene_ids-15', 'feature_types-15', 'genome-15', 'n_cells-15', 'gene_ids-16', 'feature_types-16', 'genome-16', 'n_cells-16', 'gene_ids-17', 'feature_types-17', 'genome-17', 'n_cells-17', 'gene_ids-18', 'feature_types-18', 'genome-18', 'n_cells-18', 'gene_ids-19', 'feature_types-19', 'genome-19', 'n_cells-19', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-20', 'feature_types-20', 'genome-20', 'n_cells-20', 'gene_ids-21', 'feature_types-21', 'genome-21', 'n_cells-21', 'gene_ids-22', 'feature_types-22', 'genome-22', 'n_cells-22', 'gene_ids-23', 'feature_types-23', 'genome-23', 'n_cells-23', 'gene_ids-24', 'feature_types-24', 'genome-24', 'n_cells-24', 'gene_ids-25', 'feature_types-25', 'genome-25', 'n_cells-25', 'gene_ids-26', 'feature_types-26', 'genome-26', 'n_cells-26', 'gene_ids-27', 'feature_types-27', 'genome-27', 'n_cells-27', 'gene_ids-28', 'feature_types-28', 'genome-28', 'n_cells-28', 'gene_ids-29', 'feature_types-29', 'genome-29', 'n_cells-29', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-30', 'feature_types-30', 'genome-30', 'n_cells-30', 'gene_ids-31', 'feature_types-31', 'genome-31', 'n_cells-31', 'gene_ids-32', 'feature_types-32', 'genome-32', 'n_cells-32', 'gene_ids-33', 'feature_types-33', 'genome-33', 'n_cells-33', 'gene_ids-34', 'feature_types-34', 'genome-34', 'n_cells-34', 'gene_ids-35', 'feature_types-35', 'genome-35', 'n_cells-35', 'gene_ids-36', 'feature_types-36', 'genome-36', 'n_cells-36', 'gene_ids-37', 'feature_types-37', 'genome-37', 'n_cells-37', 'gene_ids-38', 'feature_types-38', 'genome-38', 'n_cells-38', 'gene_ids-39', 'feature_types-39', 'genome-39', 'n_cells-39', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-40', 'feature_types-40', 'genome-40', 'n_cells-40', 'gene_ids-41', 'feature_types-41', 'genome-41', 'n_cells-41', 'gene_ids-42', 'feature_types-42', 'genome-42', 'n_cells-42', 'gene_ids-43', 'feature_types-43', 'genome-43', 'n_cells-43', 'gene_ids-44', 'feature_types-44', 'genome-44', 'n_cells-44', 'gene_ids-45', 'feature_types-45', 'genome-45', 'n_cells-45', 'gene_ids-46', 'feature_types-46', 'genome-46', 'n_cells-46', 'gene_ids-47', 'feature_types-47', 'genome-47', 'n_cells-47', 'gene_ids-48', 'feature_types-48', 'genome-48', 'n_cells-48', 'gene_ids-49', 'feature_types-49', 'genome-49', 'n_cells-49', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-50', 'feature_types-50', 'genome-50', 'n_cells-50', 'gene_ids-51', 'feature_types-51', 'genome-51', 'n_cells-51', 'gene_ids-52', 'feature_types-52', 'genome-52', 'n_cells-52', 'gene_ids-53', 'feature_types-53', 'genome-53', 'n_cells-53', 'gene_ids-54', 'feature_types-54', 'genome-54', 'n_cells-54', 'gene_ids-55', 'feature_types-55', 'genome-55', 'n_cells-55', 'gene_ids-56', 'feature_types-56', 'genome-56', 'n_cells-56', 'gene_ids-57', 'feature_types-57', 'genome-57', 'n_cells-57', 'gene_ids-58', 'feature_types-58', 'genome-58', 'n_cells-58', 'gene_ids-59', 'feature_types-59', 'genome-59', 'n_cells-59', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-60', 'feature_types-60', 'genome-60', 'n_cells-60', 'gene_ids-61', 'feature_types-61', 'genome-61', 'n_cells-61', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7', 'gene_ids-8', 'feature_types-8', 'genome-8', 'n_cells-8', 'gene_ids-9', 'feature_types-9', 'genome-9', 'n_cells-9'
#     uns: 'log1p'

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ### Filter Cell cycle genes
# Per genes analysis: identify genes behaving like known cell cycle genes

# %%
cellcycle_adata = adata.copy()
# Extract highly variable genes
filter_result = sc.pp.filter_genes_dispersion(
    cellcycle_adata.X, min_mean=0.0125, max_mean=3, min_disp=0.5)
sc.pl.filter_genes_dispersion(filter_result,save='_ccg_identification.pdf')
# Out:
# extracting highly variable genes
#     finished (0:00:01)
# WARNING: saving figure to file figures/filter_genes_dispersion_ccg_identification.pdf

# %%
# Traspose matrix for a GENE-centered analysis
cellcycle_adata = cellcycle_adata.T
cellcycle_adata = cellcycle_adata[filter_result.gene_subset,:]
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
# Scale data to unit variance and zero mean
sc.pp.scale(cellcycle_adata, max_value=10)
# PCA
sc.tl.pca(cellcycle_adata, svd_solver='arpack')
# Out:
# /opt/conda/lib/python3.8/site-packages/scanpy/preprocessing/_simple.py:810: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# computing PCA
#     with n_comps=50
#     finished (0:00:54)

# %%
# Plot the variance ratio
sc.pl.pca_variance_ratio(cellcycle_adata, log=True, save='_ccg_identification.pdf')
# Out:
# WARNING: saving figure to file figures/pca_variance_ratio_ccg_identification.pdf

# %%
# Identify genes behaving like cc genes
num_pcs = 7
# Compute a neighborhood graph of observations
sc.pp.neighbors(cellcycle_adata,n_pcs=num_pcs)
# Embed the neighborhood graph using UMAP
sc.tl.umap(cellcycle_adata)
cellcycle_adata.obs['known_cyclers'] = [1 if gene in ['CDK1','MKI67','CCNB2','PCNA'] else 0 for gene in cellcycle_adata.obs_names]
# Scatter plot in UMAP basis
sc.pl.umap(cellcycle_adata,color=['known_cyclers'],color_map='OrRd',save='_ccg_identification.pdf')
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 7
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:02)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:03)
# ... storing 'sample' as categorical
# ... storing 'technology' as categorical
# ... storing 'tissue' as categorical
# ... storing 'dev_age' as categorical
# ... storing 'donor' as categorical
# ... storing 'dataset' as categorical
# ... storing 'celltype_predictions' as categorical
# ... storing 'souporcell_assignment' as categorical
# ... storing 'phase' as categorical
# ... storing 'origin_M_F' as categorical
# WARNING: saving figure to file figures/umap_ccg_identification.pdf

# %%
# Cluster GENES into subgroups using louvain
sc.tl.louvain(cellcycle_adata, resolution=1.0)
# Scatter plot in UMAP basis
sc.pl.umap(cellcycle_adata,color=['known_cyclers',
                                  'louvain'],color_map='OrRd',save='_ccg_identification.pdf')
# Out:
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 12 clusters and added
#     'louvain', the cluster labels (adata.obs, categorical) (0:00:00)
# WARNING: saving figure to file figures/umap_ccg_identification.pdf

# %%
for gene in ['CDK1','MKI67','CCNB2','PCNA']:
    print(gene, 'in current features:', gene in cellcycle_adata.obs_names)
# Out:
# CDK1 in current features: False
# MKI67 in current features: False
# CCNB2 in current features: False
# PCNA in current features: False

# %%
# Locate genes of interests' cluster
print(cellcycle_adata.obs.loc[['CDK1','MKI67',
                               #'CCNB2','PCNA',
                              ],'louvain'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-4cec50203a1e> in <module>
#       1 # Locate genes of interests' cluster
# ----> 2 print(cellcycle_adata.obs.loc[['CDK1','MKI67',
#       3                                #'CCNB2','PCNA',
#       4                               ],'louvain'])
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
#    1061
#    1062         # no multi-index, so validate all of the indexers
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     829                     return section
#     830                 # This is an elided recursive call to iloc/loc
# --> 831                 return getattr(section, self.name)[new_key]
#     832
#     833         raise IndexingError("not applicable")
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
# -> 1113                 return self._getitem_iterable(key, axis=axis)
#    1114
#    1115             # nested tuple slicing
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1051
#    1052         # A collection of keys
# -> 1053         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1054         return self.obj._reindex_with_indexers(
#    1055             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['CDK1', 'MKI67'], dtype='object')] are in the [index]"

# %%
cellcycle_adata.obs['louvain'].value_counts()
# Out:
# 0     211
# 1     194
# 2     173
# 3     156
# 4     144
# 5     110
# 6     104
# 7     104
# 8      91
# 9      85
# 10     82
# 11     34
# Name: louvain, dtype: int64

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 378558 × 7848
#     obs: 'n_genes', 'sample', 'technology', 'tissue', 'dev_age', 'donor', 'dataset', 'run', 'number_of_individuals_multiplexed', 'batch', 'percent_mito', 'n_counts', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'is_doublet', 'celltype_predictions', 'probabilities', 'barcode_sample_copy', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'origin_M_F', 'is_doublet_0.05', 'is_doublet_0.01'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-10', 'feature_types-10', 'genome-10', 'n_cells-10', 'gene_ids-11', 'feature_types-11', 'genome-11', 'n_cells-11', 'gene_ids-12', 'feature_types-12', 'genome-12', 'n_cells-12', 'gene_ids-13', 'feature_types-13', 'genome-13', 'n_cells-13', 'gene_ids-14', 'feature_types-14', 'genome-14', 'n_cells-14', 'gene_ids-15', 'feature_types-15', 'genome-15', 'n_cells-15', 'gene_ids-16', 'feature_types-16', 'genome-16', 'n_cells-16', 'gene_ids-17', 'feature_types-17', 'genome-17', 'n_cells-17', 'gene_ids-18', 'feature_types-18', 'genome-18', 'n_cells-18', 'gene_ids-19', 'feature_types-19', 'genome-19', 'n_cells-19', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-20', 'feature_types-20', 'genome-20', 'n_cells-20', 'gene_ids-21', 'feature_types-21', 'genome-21', 'n_cells-21', 'gene_ids-22', 'feature_types-22', 'genome-22', 'n_cells-22', 'gene_ids-23', 'feature_types-23', 'genome-23', 'n_cells-23', 'gene_ids-24', 'feature_types-24', 'genome-24', 'n_cells-24', 'gene_ids-25', 'feature_types-25', 'genome-25', 'n_cells-25', 'gene_ids-26', 'feature_types-26', 'genome-26', 'n_cells-26', 'gene_ids-27', 'feature_types-27', 'genome-27', 'n_cells-27', 'gene_ids-28', 'feature_types-28', 'genome-28', 'n_cells-28', 'gene_ids-29', 'feature_types-29', 'genome-29', 'n_cells-29', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-30', 'feature_types-30', 'genome-30', 'n_cells-30', 'gene_ids-31', 'feature_types-31', 'genome-31', 'n_cells-31', 'gene_ids-32', 'feature_types-32', 'genome-32', 'n_cells-32', 'gene_ids-33', 'feature_types-33', 'genome-33', 'n_cells-33', 'gene_ids-34', 'feature_types-34', 'genome-34', 'n_cells-34', 'gene_ids-35', 'feature_types-35', 'genome-35', 'n_cells-35', 'gene_ids-36', 'feature_types-36', 'genome-36', 'n_cells-36', 'gene_ids-37', 'feature_types-37', 'genome-37', 'n_cells-37', 'gene_ids-38', 'feature_types-38', 'genome-38', 'n_cells-38', 'gene_ids-39', 'feature_types-39', 'genome-39', 'n_cells-39', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-40', 'feature_types-40', 'genome-40', 'n_cells-40', 'gene_ids-41', 'feature_types-41', 'genome-41', 'n_cells-41', 'gene_ids-42', 'feature_types-42', 'genome-42', 'n_cells-42', 'gene_ids-43', 'feature_types-43', 'genome-43', 'n_cells-43', 'gene_ids-44', 'feature_types-44', 'genome-44', 'n_cells-44', 'gene_ids-45', 'feature_types-45', 'genome-45', 'n_cells-45', 'gene_ids-46', 'feature_types-46', 'genome-46', 'n_cells-46', 'gene_ids-47', 'feature_types-47', 'genome-47', 'n_cells-47', 'gene_ids-48', 'feature_types-48', 'genome-48', 'n_cells-48', 'gene_ids-49', 'feature_types-49', 'genome-49', 'n_cells-49', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-50', 'feature_types-50', 'genome-50', 'n_cells-50', 'gene_ids-51', 'feature_types-51', 'genome-51', 'n_cells-51', 'gene_ids-52', 'feature_types-52', 'genome-52', 'n_cells-52', 'gene_ids-53', 'feature_types-53', 'genome-53', 'n_cells-53', 'gene_ids-54', 'feature_types-54', 'genome-54', 'n_cells-54', 'gene_ids-55', 'feature_types-55', 'genome-55', 'n_cells-55', 'gene_ids-56', 'feature_types-56', 'genome-56', 'n_cells-56', 'gene_ids-57', 'feature_types-57', 'genome-57', 'n_cells-57', 'gene_ids-58', 'feature_types-58', 'genome-58', 'n_cells-58', 'gene_ids-59', 'feature_types-59', 'genome-59', 'n_cells-59', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-60', 'feature_types-60', 'genome-60', 'n_cells-60', 'gene_ids-61', 'feature_types-61', 'genome-61', 'n_cells-61', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7', 'gene_ids-8', 'feature_types-8', 'genome-8', 'n_cells-8', 'gene_ids-9', 'feature_types-9', 'genome-9', 'n_cells-9'
#     uns: 'log1p'

# %% [markdown]
# Not removing any genes here - seems like all CC-assoc genes have been removed with the soupy genes prior to this

# %% [raw]
# # Add unstructured dict-like annotation for ccgs
# adata.uns['ccgs'] = list(cellcycle_adata.obs[(cellcycle_adata.obs['louvain']=='16')].index)
# # Remove cc genes
# adata = adata[:,[i not in adata.uns['ccgs'] for i in adata.var_names]]

# %% [raw]
# adata

# %% [raw]
# # save this table to use in scVI analysis
# adata.var.to_csv(save_path + 'cleaned_up_genes_in_M2_notebook_all_cells_and_nuclei_20211111.csv')

# %% [markdown]
# # Subsetting to HVGs & scaling

# %%
# %%time
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
# Out:
# extracting highly variable genes
#     finished (0:00:24)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)
# CPU times: user 23.8 s, sys: 503 ms, total: 24.3 s
# Wall time: 24.3 s

# %%
# %%time
sc.pl.highly_variable_genes(adata)
# Out:
# CPU times: user 285 ms, sys: 8.98 ms, total: 294 ms
# Wall time: 293 ms

# %%
adata_hvg = adata[:, adata.var['highly_variable']]
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
adata_hvg
# Out:
# View of AnnData object with n_obs × n_vars = 378558 × 1374
#     obs: 'n_genes', 'sample', 'technology', 'tissue', 'dev_age', 'donor', 'dataset', 'run', 'number_of_individuals_multiplexed', 'batch', 'percent_mito', 'n_counts', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'is_doublet', 'celltype_predictions', 'probabilities', 'barcode_sample_copy', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'origin_M_F', 'is_doublet_0.05', 'is_doublet_0.01'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-10', 'feature_types-10', 'genome-10', 'n_cells-10', 'gene_ids-11', 'feature_types-11', 'genome-11', 'n_cells-11', 'gene_ids-12', 'feature_types-12', 'genome-12', 'n_cells-12', 'gene_ids-13', 'feature_types-13', 'genome-13', 'n_cells-13', 'gene_ids-14', 'feature_types-14', 'genome-14', 'n_cells-14', 'gene_ids-15', 'feature_types-15', 'genome-15', 'n_cells-15', 'gene_ids-16', 'feature_types-16', 'genome-16', 'n_cells-16', 'gene_ids-17', 'feature_types-17', 'genome-17', 'n_cells-17', 'gene_ids-18', 'feature_types-18', 'genome-18', 'n_cells-18', 'gene_ids-19', 'feature_types-19', 'genome-19', 'n_cells-19', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-20', 'feature_types-20', 'genome-20', 'n_cells-20', 'gene_ids-21', 'feature_types-21', 'genome-21', 'n_cells-21', 'gene_ids-22', 'feature_types-22', 'genome-22', 'n_cells-22', 'gene_ids-23', 'feature_types-23', 'genome-23', 'n_cells-23', 'gene_ids-24', 'feature_types-24', 'genome-24', 'n_cells-24', 'gene_ids-25', 'feature_types-25', 'genome-25', 'n_cells-25', 'gene_ids-26', 'feature_types-26', 'genome-26', 'n_cells-26', 'gene_ids-27', 'feature_types-27', 'genome-27', 'n_cells-27', 'gene_ids-28', 'feature_types-28', 'genome-28', 'n_cells-28', 'gene_ids-29', 'feature_types-29', 'genome-29', 'n_cells-29', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-30', 'feature_types-30', 'genome-30', 'n_cells-30', 'gene_ids-31', 'feature_types-31', 'genome-31', 'n_cells-31', 'gene_ids-32', 'feature_types-32', 'genome-32', 'n_cells-32', 'gene_ids-33', 'feature_types-33', 'genome-33', 'n_cells-33', 'gene_ids-34', 'feature_types-34', 'genome-34', 'n_cells-34', 'gene_ids-35', 'feature_types-35', 'genome-35', 'n_cells-35', 'gene_ids-36', 'feature_types-36', 'genome-36', 'n_cells-36', 'gene_ids-37', 'feature_types-37', 'genome-37', 'n_cells-37', 'gene_ids-38', 'feature_types-38', 'genome-38', 'n_cells-38', 'gene_ids-39', 'feature_types-39', 'genome-39', 'n_cells-39', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-40', 'feature_types-40', 'genome-40', 'n_cells-40', 'gene_ids-41', 'feature_types-41', 'genome-41', 'n_cells-41', 'gene_ids-42', 'feature_types-42', 'genome-42', 'n_cells-42', 'gene_ids-43', 'feature_types-43', 'genome-43', 'n_cells-43', 'gene_ids-44', 'feature_types-44', 'genome-44', 'n_cells-44', 'gene_ids-45', 'feature_types-45', 'genome-45', 'n_cells-45', 'gene_ids-46', 'feature_types-46', 'genome-46', 'n_cells-46', 'gene_ids-47', 'feature_types-47', 'genome-47', 'n_cells-47', 'gene_ids-48', 'feature_types-48', 'genome-48', 'n_cells-48', 'gene_ids-49', 'feature_types-49', 'genome-49', 'n_cells-49', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-50', 'feature_types-50', 'genome-50', 'n_cells-50', 'gene_ids-51', 'feature_types-51', 'genome-51', 'n_cells-51', 'gene_ids-52', 'feature_types-52', 'genome-52', 'n_cells-52', 'gene_ids-53', 'feature_types-53', 'genome-53', 'n_cells-53', 'gene_ids-54', 'feature_types-54', 'genome-54', 'n_cells-54', 'gene_ids-55', 'feature_types-55', 'genome-55', 'n_cells-55', 'gene_ids-56', 'feature_types-56', 'genome-56', 'n_cells-56', 'gene_ids-57', 'feature_types-57', 'genome-57', 'n_cells-57', 'gene_ids-58', 'feature_types-58', 'genome-58', 'n_cells-58', 'gene_ids-59', 'feature_types-59', 'genome-59', 'n_cells-59', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-60', 'feature_types-60', 'genome-60', 'n_cells-60', 'gene_ids-61', 'feature_types-61', 'genome-61', 'n_cells-61', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7', 'gene_ids-8', 'feature_types-8', 'genome-8', 'n_cells-8', 'gene_ids-9', 'feature_types-9', 'genome-9', 'n_cells-9', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p', 'hvg'

# %%
# %%time
sc.pp.scale(adata_hvg, max_value=10)
# Out:
# /opt/conda/lib/python3.8/site-packages/scanpy/preprocessing/_simple.py:810: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# CPU times: user 7.12 s, sys: 3.65 s, total: 10.8 s
# Wall time: 10.8 s

# %% [markdown]
# ________

# %% [markdown]
# ### PCA

# %%
# %%time
sc.tl.pca(adata_hvg, svd_solver='arpack', n_comps=50)
# Out:
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:01:18)
# CPU times: user 8min 43s, sys: 2min, total: 10min 43s
# Wall time: 1min 18s

# %%
sc.pl.pca_variance_ratio(adata_hvg, n_pcs=50)

# %%
# decision: using n_latent = 16 in scVI

# %% [markdown]
# From here following to run scVI in: `/nfs/team292/aa22/scVI_related/202111_upd_in_vivo_analysis/all_donors_analysis/scVI_integration.ipynb`
