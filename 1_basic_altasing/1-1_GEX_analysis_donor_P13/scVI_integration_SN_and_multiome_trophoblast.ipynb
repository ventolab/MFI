# %% [markdown]
# # Running scVI on donor P13 data:
#
# - SN (all) + multiome, only trophoblast nuclei states (all)
#
# Correcting by `sample`

# %%
from __future__ import print_function
import torch

# %%
import sys, os
data_type = 'float32'
os.environ["THEANO_FLAGS"] = 'device=cuda,floatX=' + data_type + ',force_device=True'
#sys.path.insert(1, '/nfs/team292/aa22/scVI_related/202105_troph_organoids/')

# %% [markdown]
# **Set up scVI environment**

# %%
import scvi
import scanpy as sc

sc.set_figure_params(figsize=(4, 4))

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# **Read in raw counts of the trophoblast organoids**

# %%
save_path = '/lustre/scratch117/cellgen/team292/aa22/adata_objects/202007_snRNA-seq_MFI/snRNA_seq_MFI_202007_adatas/202012_FINAL_reanalysis_with_souporcell_deconvolution_common_variants/donor_P13_all_samples_analysis_202110/'

# Loading object with raw counts, filtered cells and genes object
# before any doublet exclusion
adata = sc.read(save_path + 'adata_raw_filtered.h5ad')

# %%
# reading IDs of final cells to keep (after also excluding doublets by GEX, done in notebook M3)
nodoublet_cell_IDs = pd.read_csv(save_path + 'obs_table_nodoublets.csv', index_col=0)
nodoublet_cell_IDs
# Out:
#                                                     n_genes donor  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                     1253   P13
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                     1279   P13
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                      473   P13
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                     1360   P13
# AAACCCACATAACCCA-1_WSSS_PLA8764121                     1891   P13
# ...                                                     ...   ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...     2409   P13
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...     4129   P13
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...     3116   P13
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...     3696   P13
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...     2130   P13
#
#                                                    tissue_block      age  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACATAACCCA-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# ...                                                         ...      ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
#
#                                                                                          sample  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# ...                                                                                         ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
#
#                                                     percent_mito  n_counts  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                      0.000000    1820.0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                      0.000535    1868.0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                      0.000000     556.0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                      0.000473    2116.0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                      0.000305    3274.0
# ...                                                          ...       ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...      0.007270    5227.0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...      0.002532   17379.0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...      0.004499    7779.0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...      0.001992   20078.0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...      0.012930    5259.0
#
#                                                       dataset technique  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACATAACCCA-1_WSSS_PLA8764121                  snRNA-seq       10X
# ...                                                       ...       ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
#
#                                                     scrublet_score  ...  \
# barcode_sample                                                      ...
# AAACCCAAGATACATG-1_WSSS_PLA8764121                        0.191617  ...
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                        0.032895  ...
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                        0.091892  ...
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                        0.012335  ...
# AAACCCACATAACCCA-1_WSSS_PLA8764121                        0.073634  ...
# ...                                                            ...  ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...        0.013699  ...
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...        0.102190  ...
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...        0.036876  ...
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...        0.109137  ...
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...        0.109137  ...
#
#                                                                                               barcode  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                 AAACCCAAGATACATG-1_WSSS_PLA8764121
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                 AAACCCACAAATCCCA-1_WSSS_PLA8764121
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                 AAACCCACAACTGTGT-1_WSSS_PLA8764121
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                 AAACCCACAAGCTGCC-1_WSSS_PLA8764121
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                 AAACCCACATAACCCA-1_WSSS_PLA8764121
# ...                                                                                               ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_...
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_...
#
#                                                                             souporcell_assignment  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                              WSSS_PLA8764121_0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# ...                                                                                           ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
#
#                                                     inter_ind_doublet  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                  0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                  0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                  0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                  0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                  0
# ...                                                               ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...                  0
#
#                                                      S_score G2M_score phase  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                  0.053412  0.056947   G2M
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                 -0.120729 -0.113529    G1
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                  0.042173 -0.027934     S
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                 -0.121624  0.050396   G2M
# AAACCCACATAACCCA-1_WSSS_PLA8764121                 -0.125064 -0.066023    G1
# ...                                                      ...       ...   ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  0.033632 -0.079893     S
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P... -0.059688 -0.098701    G1
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  0.066281 -0.038885     S
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P... -0.031627 -0.068024    G1
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P... -0.110820 -0.058170    G1
#
#                                                    annotation_prev  louvain  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                          0_none       16
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                             dM2       10
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                          0_none       14
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                            dNK1       14
# AAACCCACATAACCCA-1_WSSS_PLA8764121                             dS1        8
# ...                                                            ...      ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...          0_none        7
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...          0_none        2
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...          0_none       30
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...          0_none        2
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...          0_none        2
#
#                                                     is_doublet_propagate  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                     0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                     0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                     0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                     0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                     0
# ...                                                                  ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...                     0
#
#                                                     origin_M_F
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                           F
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                           M
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                           M
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                           M
# AAACCCACATAACCCA-1_WSSS_PLA8764121                           M
# ...                                                        ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...           M
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...           F
#
# [74244 rows x 25 columns]

# %%
# subsetting the adata object to final cells
adata = adata[list(nodoublet_cell_IDs.index), :].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 74244 × 29058
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# adding metadata
for col in nodoublet_cell_IDs.columns:
    print(col)
    adata.obs[col] = nodoublet_cell_IDs.loc[adata.obs_names,col]
# Out:
# n_genes
# donor
# tissue_block
# age
# sample
# percent_mito
# n_counts
# dataset
# technique
# scrublet_score
# scrublet_cluster_score
# bh_pval
# batch
# is_doublet
# barcode_sample_copy
# barcode
# souporcell_assignment
# inter_ind_doublet
# S_score
# G2M_score
# phase
# annotation_prev
# louvain
# is_doublet_propagate
# origin_M_F

# %%
# addition - subsetting to genes after cell cycle-associated gene removal
# read in cleaned up genes, after all doublet exclusion
cleaned_up_genes = pd.read_csv(save_path + 'genes_without_CC_assoc_genes_for_scVI_SN_and_multiome_trophoblast_20211110.csv', 
                              index_col=0)
cleaned_up_genes
# Out:
#                gene_ids-0  feature_types-0              genome-0  n_cells-0  \
# A1BG      ENSG00000121410  Gene Expression  GRCh38-3.0.0_premrna      105.0
# A1BG-AS1  ENSG00000268895  Gene Expression  GRCh38-3.0.0_premrna      162.0
# A1CF      ENSG00000148584  Gene Expression  GRCh38-3.0.0_premrna       12.0
# A2M       ENSG00000175899  Gene Expression  GRCh38-3.0.0_premrna     1302.0
# A2M-AS1   ENSG00000245105  Gene Expression  GRCh38-3.0.0_premrna       20.0
# ...                   ...              ...                   ...        ...
# ZXDB      ENSG00000198455  Gene Expression  GRCh38-3.0.0_premrna       97.0
# ZXDC      ENSG00000070476  Gene Expression  GRCh38-3.0.0_premrna     1994.0
# ZYG11B    ENSG00000162378  Gene Expression  GRCh38-3.0.0_premrna     2320.0
# ZYX       ENSG00000159840  Gene Expression  GRCh38-3.0.0_premrna     1274.0
# ZZEF1     ENSG00000074755  Gene Expression  GRCh38-3.0.0_premrna     3292.0
#
#                gene_ids-1  feature_types-1              genome-1  n_cells-1  \
# A1BG      ENSG00000121410  Gene Expression  GRCh38-3.0.0_premrna      119.0
# A1BG-AS1  ENSG00000268895  Gene Expression  GRCh38-3.0.0_premrna      211.0
# A1CF      ENSG00000148584  Gene Expression  GRCh38-3.0.0_premrna       11.0
# A2M       ENSG00000175899  Gene Expression  GRCh38-3.0.0_premrna     1356.0
# A2M-AS1   ENSG00000245105  Gene Expression  GRCh38-3.0.0_premrna       18.0
# ...                   ...              ...                   ...        ...
# ZXDB      ENSG00000198455  Gene Expression  GRCh38-3.0.0_premrna      103.0
# ZXDC      ENSG00000070476  Gene Expression  GRCh38-3.0.0_premrna     2274.0
# ZYG11B    ENSG00000162378  Gene Expression  GRCh38-3.0.0_premrna     2526.0
# ZYX       ENSG00000159840  Gene Expression  GRCh38-3.0.0_premrna     1402.0
# ZZEF1     ENSG00000074755  Gene Expression  GRCh38-3.0.0_premrna     3535.0
#
#                gene_ids-2  feature_types-2  ...              genome-5  \
# A1BG      ENSG00000121410  Gene Expression  ...  GRCh38-3.0.0_premrna
# A1BG-AS1  ENSG00000268895  Gene Expression  ...  GRCh38-3.0.0_premrna
# A1CF      ENSG00000148584  Gene Expression  ...  GRCh38-3.0.0_premrna
# A2M       ENSG00000175899  Gene Expression  ...  GRCh38-3.0.0_premrna
# A2M-AS1   ENSG00000245105  Gene Expression  ...  GRCh38-3.0.0_premrna
# ...                   ...              ...  ...                   ...
# ZXDB      ENSG00000198455  Gene Expression  ...  GRCh38-3.0.0_premrna
# ZXDC      ENSG00000070476  Gene Expression  ...  GRCh38-3.0.0_premrna
# ZYG11B    ENSG00000162378  Gene Expression  ...  GRCh38-3.0.0_premrna
# ZYX       ENSG00000159840  Gene Expression  ...  GRCh38-3.0.0_premrna
# ZZEF1     ENSG00000074755  Gene Expression  ...  GRCh38-3.0.0_premrna
#
#           n_cells-5       gene_ids-6  feature_types-6 genome-6  n_cells-6  \
# A1BG          101.0  ENSG00000121410  Gene Expression   GRCh38      159.0
# A1BG-AS1      152.0  ENSG00000268895  Gene Expression   GRCh38      223.0
# A1CF            9.0  ENSG00000148584  Gene Expression   GRCh38       12.0
# A2M          1074.0  ENSG00000175899  Gene Expression   GRCh38     1429.0
# A2M-AS1        10.0  ENSG00000245105  Gene Expression   GRCh38       36.0
# ...             ...              ...              ...      ...        ...
# ZXDB          104.0  ENSG00000198455  Gene Expression   GRCh38      231.0
# ZXDC         2410.0  ENSG00000070476  Gene Expression   GRCh38     2541.0
# ZYG11B       2920.0  ENSG00000162378  Gene Expression   GRCh38     2735.0
# ZYX          1124.0  ENSG00000159840  Gene Expression   GRCh38     1795.0
# ZZEF1        4151.0  ENSG00000074755  Gene Expression   GRCh38     3701.0
#
#                gene_ids-7  feature_types-7 genome-7  n_cells-7
# A1BG      ENSG00000121410  Gene Expression   GRCh38      160.0
# A1BG-AS1  ENSG00000268895  Gene Expression   GRCh38      217.0
# A1CF      ENSG00000148584  Gene Expression   GRCh38       15.0
# A2M       ENSG00000175899  Gene Expression   GRCh38     1333.0
# A2M-AS1   ENSG00000245105  Gene Expression   GRCh38       25.0
# ...                   ...              ...      ...        ...
# ZXDB      ENSG00000198455  Gene Expression   GRCh38      239.0
# ZXDC      ENSG00000070476  Gene Expression   GRCh38     2641.0
# ZYG11B    ENSG00000162378  Gene Expression   GRCh38     2810.0
# ZYX       ENSG00000159840  Gene Expression   GRCh38     1690.0
# ZZEF1     ENSG00000074755  Gene Expression   GRCh38     3752.0
#
# [28458 rows x 32 columns]

# %%
# subsetting to only cleamed up genes
adata = adata[:, list(cleaned_up_genes.index)].copy()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 74244 × 28458
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# subsetting to only trophoblast
obs_table_with_louvain = pd.read_csv(save_path + 'obs_table_adata_scvi_SN_and_multiome_with_trophoblast_labels.csv', index_col=0)

adata.obs['trophoblast_or_rest'] = obs_table_with_louvain.loc[list(set(adata.obs_names) & set(obs_table_with_louvain.index)), 'trophoblast_or_rest']
adata = adata[adata.obs['trophoblast_or_rest'] == 'trophoblast'].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 49361 × 28458
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F', 'trophoblast_or_rest'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# going to correct by sample here
np.unique(adata.obs['sample'], return_counts=True)
# Out:
# (array(['Pla_Camb10691970', 'Pla_Camb10691971',
#         'Pla_Camb10714919_and_40110_Pla_Camb10687915',
#         'Pla_Camb10714920_and_40110_Pla_Camb10687916', 'WSSS_PLA8764121',
#         'WSSS_PLA8764122', 'WSSS_PLA8810750', 'WSSS_PLA8810751'],
#        dtype=object),
#  array([ 6406,  6102,  3827,  3896,  4113,  4106, 10980,  9931]))

# %%
# do some basic preprocessing
adata.layers["raw_counts"] = adata.X.copy() # preserve counts
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata.copy()

# %%
# here we subset to HVGs, accounting for donor batch
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    subset=True,
    #layer="raw_counts",
    flavor="seurat",
    batch_key="sample",
    #batch_key="donor"
)
# Out:
# ... storing 'donor' as categorical
# ... storing 'tissue_block' as categorical
# ... storing 'age' as categorical
# ... storing 'sample' as categorical
# ... storing 'dataset' as categorical
# ... storing 'technique' as categorical
# ... storing 'souporcell_assignment' as categorical
# ... storing 'phase' as categorical
# ... storing 'annotation_prev' as categorical
# ... storing 'origin_M_F' as categorical
# ... storing 'trophoblast_or_rest' as categorical
# /opt/conda/envs/scvi-singularity/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 49361 × 2000
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F', 'trophoblast_or_rest'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'log1p', 'hvg'
#     layers: 'raw_counts'

# %% [markdown]
# #### Here you can specify your covariates you want to correct for (categorical or continuous)

# %%
scvi.data.setup_anndata(
    adata,
    layer="raw_counts",
    categorical_covariate_keys=["sample"],
    #continuous_covariate_keys=[""] # could try and regress n_genes in the future? not for now
)
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["raw_counts"]
# INFO     Computing library size prior per batch
# INFO     Successfully registered anndata object containing 49361 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 1 extra categorical covariates and 0 extra
#          continuous covariates.
# INFO     Please do not further modify adata until model is trained.

# %% [markdown]
# ### 10.11.2021 Running scVI on all trophoblast after:
#
# - removing cell cycle-associated genes (calculated in S4 notebook)
# - exclusion of all doublets (scrublet and souporcell, done in S2 notebook)

# %%
models = {}

# just a few values here, it was 6 or 16 PCs that look optimal the conventional analysis
n_latent_values = [6, 16, 20]

for n_latent_value in n_latent_values:
    print('n_latent_value', n_latent_value)
    models[n_latent_value] = scvi.model.SCVI(adata, n_latent = n_latent_value)
# Out:
# n_latent_value 6
# n_latent_value 16
# n_latent_value 20

# %%
models[6]
# Out:
# SCVI Model with the following params:
# n_hidden: 128, n_latent: 6, n_layers: 1, dropout_rate: 0.1, dispersion: gene,
# gene_likelihood: zinb, latent_distribution: normal
# Training status: Not Trained
# To print summary of associated AnnData, use: scvi.data.view_anndata_setup(model.adata)

# %%
latent_representations = {}

for n_latent_value in n_latent_values:
    print('training model for n_latent_value:', n_latent_value)
    models[n_latent_value].train()
    
    # get latent representation as a dataframe
    latent_representations[n_latent_value] = models[n_latent_value].get_latent_representation()
    
    # add it to the adata object
    adata.obsm["X_scVI_n_latent_" + str(n_latent_value)] = latent_representations[n_latent_value]
    curr_df = pd.DataFrame(adata.obsm["X_scVI_n_latent_" + str(n_latent_value)])
    
    # save the latent representation
    curr_df.to_csv('./results/20211110_obsm_with_scVI_latent_representation_n_' + str(n_latent_value) + '_after_CCG_removal_and_all_doublet_exclusion_by_sample_donor_P13_SN_and_multiome_trophoblast.csv')
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 6
# Epoch 162/162: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 162/162 [08:54<00:00,  3.30s/it, loss=718, v_num=1]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 16
# Epoch 162/162: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 162/162 [08:55<00:00,  3.31s/it, loss=696, v_num=1]

# %%
latent_representations = {}
# for additional n_latent=20
for n_latent_value in [20]:
    print('training model for n_latent_value:', n_latent_value)
    models[n_latent_value].train()
    
    # get latent representation as a dataframe
    latent_representations[n_latent_value] = models[n_latent_value].get_latent_representation()
    
    # add it to the adata object
    adata.obsm["X_scVI_n_latent_" + str(n_latent_value)] = latent_representations[n_latent_value]
    curr_df = pd.DataFrame(adata.obsm["X_scVI_n_latent_" + str(n_latent_value)])
    
    # save the latent representation
    curr_df.to_csv('./results/20211110_obsm_with_scVI_latent_representation_n_' + str(n_latent_value) + '_after_CCG_removal_and_all_doublet_exclusion_by_sample_donor_P13_SN_and_multiome_trophoblast.csv')
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 20
# Epoch 162/162: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 162/162 [07:05<00:00,  2.63s/it, loss=700, v_num=1]

# %% [markdown]
# # Running on all trophoblast again after cleanup in notebook S5-1
#
#
# Subsetted by unbiased clusteing of the manifold with all trophoblast states

# %%
save_path = '/lustre/scratch117/cellgen/team292/aa22/adata_objects/202007_snRNA-seq_MFI/snRNA_seq_MFI_202007_adatas/202012_FINAL_reanalysis_with_souporcell_deconvolution_common_variants/donor_P13_all_samples_analysis_202110/'

# Loading object with raw counts, filtered cells and genes object
# before any doublet exclusion
adata = sc.read(save_path + 'adata_raw_filtered.h5ad')

# %%
# reading IDs of final cells to keep (after also excluding doublets by GEX, done in notebook M3)
nodoublet_cell_IDs = pd.read_csv(save_path + 'obs_table_nodoublets.csv', index_col=0)
nodoublet_cell_IDs
# Out:
#                                                     n_genes donor  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                     1253   P13
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                     1279   P13
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                      473   P13
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                     1360   P13
# AAACCCACATAACCCA-1_WSSS_PLA8764121                     1891   P13
# ...                                                     ...   ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...     2409   P13
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...     4129   P13
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...     3116   P13
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...     3696   P13
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...     2130   P13
#
#                                                    tissue_block      age  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACATAACCCA-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# ...                                                         ...      ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
#
#                                                                                          sample  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# ...                                                                                         ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
#
#                                                     percent_mito  n_counts  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                      0.000000    1820.0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                      0.000535    1868.0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                      0.000000     556.0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                      0.000473    2116.0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                      0.000305    3274.0
# ...                                                          ...       ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...      0.007270    5227.0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...      0.002532   17379.0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...      0.004499    7779.0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...      0.001992   20078.0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...      0.012930    5259.0
#
#                                                       dataset technique  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACATAACCCA-1_WSSS_PLA8764121                  snRNA-seq       10X
# ...                                                       ...       ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
#
#                                                     scrublet_score  ...  \
# barcode_sample                                                      ...
# AAACCCAAGATACATG-1_WSSS_PLA8764121                        0.191617  ...
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                        0.032895  ...
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                        0.091892  ...
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                        0.012335  ...
# AAACCCACATAACCCA-1_WSSS_PLA8764121                        0.073634  ...
# ...                                                            ...  ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...        0.013699  ...
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...        0.102190  ...
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...        0.036876  ...
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...        0.109137  ...
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...        0.109137  ...
#
#                                                                                               barcode  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                 AAACCCAAGATACATG-1_WSSS_PLA8764121
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                 AAACCCACAAATCCCA-1_WSSS_PLA8764121
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                 AAACCCACAACTGTGT-1_WSSS_PLA8764121
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                 AAACCCACAAGCTGCC-1_WSSS_PLA8764121
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                 AAACCCACATAACCCA-1_WSSS_PLA8764121
# ...                                                                                               ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_...
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_...
#
#                                                                             souporcell_assignment  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                              WSSS_PLA8764121_0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# ...                                                                                           ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
#
#                                                     inter_ind_doublet  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                  0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                  0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                  0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                  0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                  0
# ...                                                               ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...                  0
#
#                                                      S_score G2M_score phase  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                  0.053412  0.056947   G2M
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                 -0.120729 -0.113529    G1
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                  0.042173 -0.027934     S
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                 -0.121624  0.050396   G2M
# AAACCCACATAACCCA-1_WSSS_PLA8764121                 -0.125064 -0.066023    G1
# ...                                                      ...       ...   ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  0.033632 -0.079893     S
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P... -0.059688 -0.098701    G1
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  0.066281 -0.038885     S
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P... -0.031627 -0.068024    G1
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P... -0.110820 -0.058170    G1
#
#                                                    annotation_prev  louvain  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                          0_none       16
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                             dM2       10
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                          0_none       14
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                            dNK1       14
# AAACCCACATAACCCA-1_WSSS_PLA8764121                             dS1        8
# ...                                                            ...      ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...          0_none        7
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...          0_none        2
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...          0_none       30
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...          0_none        2
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...          0_none        2
#
#                                                     is_doublet_propagate  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                     0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                     0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                     0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                     0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                     0
# ...                                                                  ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...                     0
#
#                                                     origin_M_F
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                           F
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                           M
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                           M
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                           M
# AAACCCACATAACCCA-1_WSSS_PLA8764121                           M
# ...                                                        ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...           M
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...           F
#
# [74244 rows x 25 columns]

# %%
# subsetting the adata object to final cells
adata = adata[list(nodoublet_cell_IDs.index), :].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 74244 × 29058
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# adding metadata
for col in nodoublet_cell_IDs.columns:
    print(col)
    adata.obs[col] = nodoublet_cell_IDs.loc[adata.obs_names,col]
# Out:
# n_genes
# donor
# tissue_block
# age
# sample
# percent_mito
# n_counts
# dataset
# technique
# scrublet_score
# scrublet_cluster_score
# bh_pval
# batch
# is_doublet
# barcode_sample_copy
# barcode
# souporcell_assignment
# inter_ind_doublet
# S_score
# G2M_score
# phase
# annotation_prev
# louvain
# is_doublet_propagate
# origin_M_F

# %%
# subset to only selected trophoblast (after cleanup)
# read in obs table with louvain labels from notebook S3-1 and subset to only cleaned up troph
obs_table_with_labels = pd.read_csv(save_path + 'obs_table_adata_scvi_SN_and_multiome_with_trophoblast_contaminant_v1_labels.csv', index_col=0)

adata.obs['cleanup_v1_contaminant'] = obs_table_with_labels.loc[list(set(adata.obs_names) & set(obs_table_with_labels.index)), 'cleanup_v1_contaminant']
adata = adata[adata.obs['cleanup_v1_contaminant'] == 'keeping'].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 41166 × 29058
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F', 'cleanup_v1_contaminant'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# read in CCGs recalc in notebook S3-1 and using 8 and 16 PCs?
cleaned_up_genes = pd.read_csv(save_path + 'genes_without_CC_assoc_genes_for_scVI_SN_and_multiome_trophoblast_cleanup_v1_20211110.csv', 
                              index_col=0)
adata = adata[:,cleaned_up_genes.index].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 41166 × 28847
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F', 'cleanup_v1_contaminant'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# do some basic preprocessing
adata.layers["raw_counts"] = adata.X.copy() # preserve counts
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata.copy()

# %%
# here we subset to HVGs, accounting for donor batch
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    subset=True,
    #layer="raw_counts",
    flavor="seurat",
    batch_key="sample",
    #batch_key="donor"
)
# Out:
# ... storing 'donor' as categorical
# ... storing 'tissue_block' as categorical
# ... storing 'age' as categorical
# ... storing 'sample' as categorical
# ... storing 'dataset' as categorical
# ... storing 'technique' as categorical
# ... storing 'souporcell_assignment' as categorical
# ... storing 'phase' as categorical
# ... storing 'annotation_prev' as categorical
# ... storing 'origin_M_F' as categorical
# ... storing 'cleanup_v1_contaminant' as categorical
# /opt/conda/envs/scvi-singularity/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# #### Here you can specify your covariates you want to correct for (categorical or continuous)

# %%
scvi.data.setup_anndata(
    adata,
    layer="raw_counts",
    categorical_covariate_keys=["sample"],
    #continuous_covariate_keys=[""] # could try and regress n_genes in the future? not for now
)
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["raw_counts"]
# INFO     Computing library size prior per batch
# INFO     Successfully registered anndata object containing 41166 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 1 extra categorical covariates and 0 extra
#          continuous covariates.
# INFO     Please do not further modify adata until model is trained.

# %% [markdown]
# ### 10.11.2021 Running scVI on all trophoblast after:
#
# - removing cell cycle-associated genes (calculated in S5-1 notebook)
# - exclusion of all doublets (scrublet and souporcell, done in S2 notebook)

# %%
models = {}

# just a few values here, it was 18 PCs I used in the conventional analysis
n_latent_values = [8, 16, 19]

for n_latent_value in n_latent_values:
    print('n_latent_value', n_latent_value)
    models[n_latent_value] = scvi.model.SCVI(adata, n_latent = n_latent_value)
# Out:
# n_latent_value 8
# n_latent_value 16
# n_latent_value 19

# %%
models[8]
# Out:
# SCVI Model with the following params:
# n_hidden: 128, n_latent: 8, n_layers: 1, dropout_rate: 0.1, dispersion: gene,
# gene_likelihood: zinb, latent_distribution: normal
# Training status: Not Trained
# To print summary of associated AnnData, use: scvi.data.view_anndata_setup(model.adata)

# %%
latent_representations = {}

for n_latent_value in n_latent_values:
    print('training model for n_latent_value:', n_latent_value)
    models[n_latent_value].train()
    
    # get latent representation as a dataframe
    latent_representations[n_latent_value] = models[n_latent_value].get_latent_representation()
    
    # add it to the adata object
    adata.obsm["X_scVI_n_latent_" + str(n_latent_value)] = latent_representations[n_latent_value]
    curr_df = pd.DataFrame(adata.obsm["X_scVI_n_latent_" + str(n_latent_value)])
    
    # save the latent representation
    curr_df.to_csv('./results/20211110_obsm_with_scVI_latent_representation_n_' + str(n_latent_value) + '_after_CCG_removal_and_all_doublet_exclusion_by_sample_donor_P13_SN_and_multiome_trophoblast_cleanup_v1.csv')
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 8
# Epoch 194/194: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 194/194 [08:55<00:00,  2.76s/it, loss=889, v_num=1]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 16
# Epoch 194/194: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 194/194 [08:56<00:00,  2.76s/it, loss=880, v_num=1]

# %%
latent_representations = {}

for n_latent_value in [19]:
    print('training model for n_latent_value:', n_latent_value)
    models[n_latent_value].train()
    
    # get latent representation as a dataframe
    latent_representations[n_latent_value] = models[n_latent_value].get_latent_representation()
    
    # add it to the adata object
    adata.obsm["X_scVI_n_latent_" + str(n_latent_value)] = latent_representations[n_latent_value]
    curr_df = pd.DataFrame(adata.obsm["X_scVI_n_latent_" + str(n_latent_value)])
    
    # save the latent representation
    curr_df.to_csv('./results/20211110_obsm_with_scVI_latent_representation_n_' + str(n_latent_value) + '_after_CCG_removal_and_all_doublet_exclusion_by_sample_donor_P13_SN_and_multiome_trophoblast_cleanup_v1.csv')
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 19
# Epoch 145/194:  74%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████                                      | 144/194 [05:15<01:51,  2.23s/it, loss=881, v_num=1]

# %% [markdown]
# # Running on all trophoblast again after cleanup in notebook S5-2
#
#
# Subsetted by unbiased clusteing of the manifold with all trophoblast states

# %%
save_path = '/lustre/scratch117/cellgen/team292/aa22/adata_objects/202007_snRNA-seq_MFI/snRNA_seq_MFI_202007_adatas/202012_FINAL_reanalysis_with_souporcell_deconvolution_common_variants/donor_P13_all_samples_analysis_202110/'

# Loading object with raw counts, filtered cells and genes object
# before any doublet exclusion
adata = sc.read(save_path + 'adata_raw_filtered.h5ad')

# %%
# reading IDs of final cells to keep (after also excluding doublets by GEX, done in notebook M3)
nodoublet_cell_IDs = pd.read_csv(save_path + 'obs_table_nodoublets.csv', index_col=0)
nodoublet_cell_IDs
# Out:
#                                                     n_genes donor  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                     1253   P13
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                     1279   P13
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                      473   P13
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                     1360   P13
# AAACCCACATAACCCA-1_WSSS_PLA8764121                     1891   P13
# ...                                                     ...   ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...     2409   P13
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...     4129   P13
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...     3116   P13
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...     3696   P13
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...     2130   P13
#
#                                                    tissue_block      age  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACATAACCCA-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# ...                                                         ...      ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
#
#                                                                                          sample  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# ...                                                                                         ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
#
#                                                     percent_mito  n_counts  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                      0.000000    1820.0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                      0.000535    1868.0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                      0.000000     556.0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                      0.000473    2116.0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                      0.000305    3274.0
# ...                                                          ...       ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...      0.007270    5227.0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...      0.002532   17379.0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...      0.004499    7779.0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...      0.001992   20078.0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...      0.012930    5259.0
#
#                                                       dataset technique  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACATAACCCA-1_WSSS_PLA8764121                  snRNA-seq       10X
# ...                                                       ...       ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
#
#                                                     scrublet_score  ...  \
# barcode_sample                                                      ...
# AAACCCAAGATACATG-1_WSSS_PLA8764121                        0.191617  ...
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                        0.032895  ...
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                        0.091892  ...
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                        0.012335  ...
# AAACCCACATAACCCA-1_WSSS_PLA8764121                        0.073634  ...
# ...                                                            ...  ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...        0.013699  ...
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...        0.102190  ...
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...        0.036876  ...
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...        0.109137  ...
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...        0.109137  ...
#
#                                                                                               barcode  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                 AAACCCAAGATACATG-1_WSSS_PLA8764121
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                 AAACCCACAAATCCCA-1_WSSS_PLA8764121
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                 AAACCCACAACTGTGT-1_WSSS_PLA8764121
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                 AAACCCACAAGCTGCC-1_WSSS_PLA8764121
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                 AAACCCACATAACCCA-1_WSSS_PLA8764121
# ...                                                                                               ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_...
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_...
#
#                                                                             souporcell_assignment  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                              WSSS_PLA8764121_0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# ...                                                                                           ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
#
#                                                     inter_ind_doublet  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                  0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                  0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                  0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                  0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                  0
# ...                                                               ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...                  0
#
#                                                      S_score G2M_score phase  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                  0.053412  0.056947   G2M
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                 -0.120729 -0.113529    G1
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                  0.042173 -0.027934     S
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                 -0.121624  0.050396   G2M
# AAACCCACATAACCCA-1_WSSS_PLA8764121                 -0.125064 -0.066023    G1
# ...                                                      ...       ...   ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  0.033632 -0.079893     S
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P... -0.059688 -0.098701    G1
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  0.066281 -0.038885     S
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P... -0.031627 -0.068024    G1
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P... -0.110820 -0.058170    G1
#
#                                                    annotation_prev  louvain  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                          0_none       16
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                             dM2       10
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                          0_none       14
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                            dNK1       14
# AAACCCACATAACCCA-1_WSSS_PLA8764121                             dS1        8
# ...                                                            ...      ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...          0_none        7
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...          0_none        2
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...          0_none       30
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...          0_none        2
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...          0_none        2
#
#                                                     is_doublet_propagate  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                     0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                     0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                     0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                     0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                     0
# ...                                                                  ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...                     0
#
#                                                     origin_M_F
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                           F
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                           M
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                           M
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                           M
# AAACCCACATAACCCA-1_WSSS_PLA8764121                           M
# ...                                                        ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...           M
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...           F
#
# [74244 rows x 25 columns]

# %%
# subsetting the adata object to final cells
adata = adata[list(nodoublet_cell_IDs.index), :].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 74244 × 29058
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# adding metadata
for col in nodoublet_cell_IDs.columns:
    print(col)
    adata.obs[col] = nodoublet_cell_IDs.loc[adata.obs_names,col]
# Out:
# n_genes
# donor
# tissue_block
# age
# sample
# percent_mito
# n_counts
# dataset
# technique
# scrublet_score
# scrublet_cluster_score
# bh_pval
# batch
# is_doublet
# barcode_sample_copy
# barcode
# souporcell_assignment
# inter_ind_doublet
# S_score
# G2M_score
# phase
# annotation_prev
# louvain
# is_doublet_propagate
# origin_M_F

# %%
# subset to only selected trophoblast (after cleanup)
# read in obs table with louvain labels from notebook S3-1 and subset to only cleaned up troph
obs_table_with_labels = pd.read_csv(save_path + 'obs_table_adata_scvi_SN_and_multiome_with_trophoblast_contaminant_v2_labels.csv', index_col=0)

adata.obs['cleanup_v2_contaminant'] = obs_table_with_labels.loc[list(set(adata.obs_names) & set(obs_table_with_labels.index)), 'cleanup_v2_contaminant']
adata = adata[adata.obs['cleanup_v2_contaminant'] == 'keeping'].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 40198 × 29058
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F', 'cleanup_v2_contaminant'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# read in CCGs recalc in notebook S3-1 and using 8 and 18 PCs
cleaned_up_genes = pd.read_csv(save_path + 'genes_without_CC_assoc_genes_for_scVI_SN_and_multiome_trophoblast_cleanup_v2_20211110.csv', 
                              index_col=0)
adata = adata[:,cleaned_up_genes.index].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 40198 × 28022
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F', 'cleanup_v2_contaminant'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# do some basic preprocessing
adata.layers["raw_counts"] = adata.X.copy() # preserve counts
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata.copy()

# %%
# here we subset to HVGs, accounting for donor batch
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    subset=True,
    #layer="raw_counts",
    flavor="seurat",
    batch_key="sample",
    #batch_key="donor"
)
# Out:
# ... storing 'donor' as categorical
# ... storing 'tissue_block' as categorical
# ... storing 'age' as categorical
# ... storing 'sample' as categorical
# ... storing 'dataset' as categorical
# ... storing 'technique' as categorical
# ... storing 'souporcell_assignment' as categorical
# ... storing 'phase' as categorical
# ... storing 'annotation_prev' as categorical
# ... storing 'origin_M_F' as categorical
# ... storing 'cleanup_v2_contaminant' as categorical
# /opt/conda/envs/scvi-singularity/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# #### Here you can specify your covariates you want to correct for (categorical or continuous)

# %%
scvi.data.setup_anndata(
    adata,
    layer="raw_counts",
    categorical_covariate_keys=["sample"],
    #continuous_covariate_keys=[""] # could try and regress n_genes in the future? not for now
)
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["raw_counts"]
# INFO     Computing library size prior per batch
# INFO     Successfully registered anndata object containing 40198 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 1 extra categorical covariates and 0 extra
#          continuous covariates.
# INFO     Please do not further modify adata until model is trained.

# %% [markdown]
# ### 10.11.2021 Running scVI on all trophoblast after:
#
# - removing cell cycle-associated genes (calculated in S5-1 notebook)
# - exclusion of all doublets (scrublet and souporcell, done in S2 notebook)

# %%
models = {}

# just a few values here, it was 18 PCs I used in the conventional analysis
n_latent_values = [8, 19]

for n_latent_value in n_latent_values:
    print('n_latent_value', n_latent_value)
    models[n_latent_value] = scvi.model.SCVI(adata, n_latent = n_latent_value)
# Out:
# n_latent_value 8
# n_latent_value 19

# %%
models[8]
# Out:
# SCVI Model with the following params:
# n_hidden: 128, n_latent: 8, n_layers: 1, dropout_rate: 0.1, dispersion: gene,
# gene_likelihood: zinb, latent_distribution: normal
# Training status: Not Trained
# To print summary of associated AnnData, use: scvi.data.view_anndata_setup(model.adata)

# %%
latent_representations = {}

for n_latent_value in n_latent_values:
    print('training model for n_latent_value:', n_latent_value)
    models[n_latent_value].train()
    
    # get latent representation as a dataframe
    latent_representations[n_latent_value] = models[n_latent_value].get_latent_representation()
    
    # add it to the adata object
    adata.obsm["X_scVI_n_latent_" + str(n_latent_value)] = latent_representations[n_latent_value]
    curr_df = pd.DataFrame(adata.obsm["X_scVI_n_latent_" + str(n_latent_value)])
    
    # save the latent representation
    curr_df.to_csv('./results/20211110_obsm_with_scVI_latent_representation_n_' + str(n_latent_value) + '_after_CCG_removal_and_all_doublet_exclusion_by_sample_donor_P13_SN_and_multiome_trophoblast_cleanup_v2.csv')
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 8
# Epoch 199/199: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 199/199 [08:56<00:00,  2.70s/it, loss=868, v_num=1]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 19
# Epoch 199/199: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 199/199 [08:56<00:00,  2.70s/it, loss=871, v_num=1]

# %% [markdown]
# # Running on all trophoblast again after cleanup in notebook S5-3
#
#
# Subsetted by unbiased clusteing of the manifold with all trophoblast states

# %%
save_path = '/lustre/scratch117/cellgen/team292/aa22/adata_objects/202007_snRNA-seq_MFI/snRNA_seq_MFI_202007_adatas/202012_FINAL_reanalysis_with_souporcell_deconvolution_common_variants/donor_P13_all_samples_analysis_202110/'

# Loading object with raw counts, filtered cells and genes object
# before any doublet exclusion
adata = sc.read(save_path + 'adata_raw_filtered.h5ad')

# %%
# reading IDs of final cells to keep (after also excluding doublets by GEX, done in notebook M3)
nodoublet_cell_IDs = pd.read_csv(save_path + 'obs_table_nodoublets.csv', index_col=0)
nodoublet_cell_IDs
# Out:
#                                                     n_genes donor  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                     1253   P13
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                     1279   P13
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                      473   P13
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                     1360   P13
# AAACCCACATAACCCA-1_WSSS_PLA8764121                     1891   P13
# ...                                                     ...   ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...     2409   P13
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...     4129   P13
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...     3116   P13
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...     3696   P13
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...     2130   P13
#
#                                                    tissue_block      age  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACATAACCCA-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# ...                                                         ...      ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
#
#                                                                                          sample  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# ...                                                                                         ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
#
#                                                     percent_mito  n_counts  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                      0.000000    1820.0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                      0.000535    1868.0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                      0.000000     556.0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                      0.000473    2116.0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                      0.000305    3274.0
# ...                                                          ...       ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...      0.007270    5227.0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...      0.002532   17379.0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...      0.004499    7779.0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...      0.001992   20078.0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...      0.012930    5259.0
#
#                                                       dataset technique  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACATAACCCA-1_WSSS_PLA8764121                  snRNA-seq       10X
# ...                                                       ...       ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
#
#                                                     scrublet_score  ...  \
# barcode_sample                                                      ...
# AAACCCAAGATACATG-1_WSSS_PLA8764121                        0.191617  ...
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                        0.032895  ...
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                        0.091892  ...
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                        0.012335  ...
# AAACCCACATAACCCA-1_WSSS_PLA8764121                        0.073634  ...
# ...                                                            ...  ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...        0.013699  ...
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...        0.102190  ...
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...        0.036876  ...
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...        0.109137  ...
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...        0.109137  ...
#
#                                                                                               barcode  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                 AAACCCAAGATACATG-1_WSSS_PLA8764121
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                 AAACCCACAAATCCCA-1_WSSS_PLA8764121
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                 AAACCCACAACTGTGT-1_WSSS_PLA8764121
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                 AAACCCACAAGCTGCC-1_WSSS_PLA8764121
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                 AAACCCACATAACCCA-1_WSSS_PLA8764121
# ...                                                                                               ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_...
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_...
#
#                                                                             souporcell_assignment  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                              WSSS_PLA8764121_0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# ...                                                                                           ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
#
#                                                     inter_ind_doublet  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                  0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                  0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                  0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                  0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                  0
# ...                                                               ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...                  0
#
#                                                      S_score G2M_score phase  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                  0.053412  0.056947   G2M
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                 -0.120729 -0.113529    G1
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                  0.042173 -0.027934     S
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                 -0.121624  0.050396   G2M
# AAACCCACATAACCCA-1_WSSS_PLA8764121                 -0.125064 -0.066023    G1
# ...                                                      ...       ...   ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  0.033632 -0.079893     S
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P... -0.059688 -0.098701    G1
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  0.066281 -0.038885     S
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P... -0.031627 -0.068024    G1
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P... -0.110820 -0.058170    G1
#
#                                                    annotation_prev  louvain  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                          0_none       16
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                             dM2       10
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                          0_none       14
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                            dNK1       14
# AAACCCACATAACCCA-1_WSSS_PLA8764121                             dS1        8
# ...                                                            ...      ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...          0_none        7
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...          0_none        2
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...          0_none       30
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...          0_none        2
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...          0_none        2
#
#                                                     is_doublet_propagate  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                     0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                     0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                     0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                     0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                     0
# ...                                                                  ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...                     0
#
#                                                     origin_M_F
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                           F
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                           M
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                           M
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                           M
# AAACCCACATAACCCA-1_WSSS_PLA8764121                           M
# ...                                                        ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...           M
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...           F
#
# [74244 rows x 25 columns]

# %%
# subsetting the adata object to final cells
adata = adata[list(nodoublet_cell_IDs.index), :].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 74244 × 29058
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# adding metadata
for col in nodoublet_cell_IDs.columns:
    print(col)
    adata.obs[col] = nodoublet_cell_IDs.loc[adata.obs_names,col]
# Out:
# n_genes
# donor
# tissue_block
# age
# sample
# percent_mito
# n_counts
# dataset
# technique
# scrublet_score
# scrublet_cluster_score
# bh_pval
# batch
# is_doublet
# barcode_sample_copy
# barcode
# souporcell_assignment
# inter_ind_doublet
# S_score
# G2M_score
# phase
# annotation_prev
# louvain
# is_doublet_propagate
# origin_M_F

# %%
# subset to only selected trophoblast (after cleanup)
# read in obs table with louvain labels from notebook S3-1 and subset to only cleaned up troph
obs_table_with_labels = pd.read_csv(save_path + 'obs_table_adata_scvi_SN_and_multiome_with_trophoblast_contaminant_v3_labels.csv', index_col=0)

adata.obs['cleanup_v3_contaminant'] = obs_table_with_labels.loc[list(set(adata.obs_names) & set(obs_table_with_labels.index)), 'cleanup_v3_contaminant']
adata = adata[adata.obs['cleanup_v3_contaminant'] == 'keeping'].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 39298 × 29058
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F', 'cleanup_v3_contaminant'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# read in CCGs recalc in notebook S3-1 and using X? PCs
cleaned_up_genes = pd.read_csv(save_path + 'genes_without_CC_assoc_genes_for_scVI_SN_and_multiome_trophoblast_cleanup_v3_20211110.csv', 
                              index_col=0)
adata = adata[:,cleaned_up_genes.index].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 39298 × 28040
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F', 'cleanup_v3_contaminant'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# do some basic preprocessing
adata.layers["raw_counts"] = adata.X.copy() # preserve counts
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata.copy()

# %%
# here we subset to HVGs, accounting for donor batch
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    subset=True,
    #layer="raw_counts",
    flavor="seurat",
    batch_key="sample",
    #batch_key="donor"
)
# Out:
# ... storing 'donor' as categorical
# ... storing 'tissue_block' as categorical
# ... storing 'age' as categorical
# ... storing 'sample' as categorical
# ... storing 'dataset' as categorical
# ... storing 'technique' as categorical
# ... storing 'souporcell_assignment' as categorical
# ... storing 'phase' as categorical
# ... storing 'annotation_prev' as categorical
# ... storing 'origin_M_F' as categorical
# ... storing 'cleanup_v3_contaminant' as categorical
# /opt/conda/envs/scvi-singularity/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# #### Here you can specify your covariates you want to correct for (categorical or continuous)

# %%
scvi.data.setup_anndata(
    adata,
    layer="raw_counts",
    categorical_covariate_keys=["sample"],
    #continuous_covariate_keys=[""] # could try and regress n_genes in the future? not for now
)
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["raw_counts"]
# INFO     Computing library size prior per batch
# INFO     Successfully registered anndata object containing 39298 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 1 extra categorical covariates and 0 extra
#          continuous covariates.
# INFO     Please do not further modify adata until model is trained.

# %% [markdown]
# ### 10.11.2021 Running scVI on all trophoblast after:
#
# - removing cell cycle-associated genes (calculated in S3-1 notebook)
# - exclusion of all doublets (scrublet and souporcell)

# %%
models = {}

# just a few values here, it was 18 PCs I used in the conventional analysis
n_latent_values = [8, 18]

for n_latent_value in n_latent_values:
    print('n_latent_value', n_latent_value)
    models[n_latent_value] = scvi.model.SCVI(adata, n_latent = n_latent_value)
# Out:
# n_latent_value 8
# n_latent_value 18

# %%
models[8]
# Out:
# SCVI Model with the following params:
# n_hidden: 128, n_latent: 8, n_layers: 1, dropout_rate: 0.1, dispersion: gene,
# gene_likelihood: zinb, latent_distribution: normal
# Training status: Not Trained
# To print summary of associated AnnData, use: scvi.data.view_anndata_setup(model.adata)

# %%
latent_representations = {}

for n_latent_value in n_latent_values:
    print('training model for n_latent_value:', n_latent_value)
    models[n_latent_value].train()
    
    # get latent representation as a dataframe
    latent_representations[n_latent_value] = models[n_latent_value].get_latent_representation()
    
    # add it to the adata object
    adata.obsm["X_scVI_n_latent_" + str(n_latent_value)] = latent_representations[n_latent_value]
    curr_df = pd.DataFrame(adata.obsm["X_scVI_n_latent_" + str(n_latent_value)])
    
    # save the latent representation
    curr_df.to_csv('./results/20211110_obsm_with_scVI_latent_representation_n_' + str(n_latent_value) + '_after_CCG_removal_and_all_doublet_exclusion_by_sample_donor_P13_SN_and_multiome_trophoblast_cleanup_v3.csv')
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 8
# Epoch 204/204: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 204/204 [08:59<00:00,  2.64s/it, loss=873, v_num=1]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 18
# Epoch 204/204: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 204/204 [08:59<00:00,  2.65s/it, loss=868, v_num=1]

# %% [markdown]
# # Running on invading trophoblast after selecting them in notebook S5-4
#
#
# Subsetted by unbiased clusteing of the manifold with all trophoblast states

# %%
save_path = '/lustre/scratch117/cellgen/team292/aa22/adata_objects/202007_snRNA-seq_MFI/snRNA_seq_MFI_202007_adatas/202012_FINAL_reanalysis_with_souporcell_deconvolution_common_variants/donor_P13_all_samples_analysis_202110/'

# Loading object with raw counts, filtered cells and genes object
# before any doublet exclusion
adata = sc.read(save_path + 'adata_raw_filtered.h5ad')

# %%
# reading IDs of final cells to keep (after also excluding doublets by GEX, done in notebook M3)
nodoublet_cell_IDs = pd.read_csv(save_path + 'obs_table_nodoublets.csv', index_col=0)
nodoublet_cell_IDs
# Out:
#                                                     n_genes donor  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                     1253   P13
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                     1279   P13
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                      473   P13
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                     1360   P13
# AAACCCACATAACCCA-1_WSSS_PLA8764121                     1891   P13
# ...                                                     ...   ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...     2409   P13
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...     4129   P13
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...     3116   P13
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...     3696   P13
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...     2130   P13
#
#                                                    tissue_block      age  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACATAACCCA-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# ...                                                         ...      ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
#
#                                                                                          sample  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# ...                                                                                         ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
#
#                                                     percent_mito  n_counts  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                      0.000000    1820.0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                      0.000535    1868.0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                      0.000000     556.0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                      0.000473    2116.0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                      0.000305    3274.0
# ...                                                          ...       ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...      0.007270    5227.0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...      0.002532   17379.0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...      0.004499    7779.0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...      0.001992   20078.0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...      0.012930    5259.0
#
#                                                       dataset technique  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACATAACCCA-1_WSSS_PLA8764121                  snRNA-seq       10X
# ...                                                       ...       ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
#
#                                                     scrublet_score  ...  \
# barcode_sample                                                      ...
# AAACCCAAGATACATG-1_WSSS_PLA8764121                        0.191617  ...
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                        0.032895  ...
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                        0.091892  ...
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                        0.012335  ...
# AAACCCACATAACCCA-1_WSSS_PLA8764121                        0.073634  ...
# ...                                                            ...  ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...        0.013699  ...
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...        0.102190  ...
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...        0.036876  ...
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...        0.109137  ...
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...        0.109137  ...
#
#                                                                                               barcode  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                 AAACCCAAGATACATG-1_WSSS_PLA8764121
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                 AAACCCACAAATCCCA-1_WSSS_PLA8764121
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                 AAACCCACAACTGTGT-1_WSSS_PLA8764121
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                 AAACCCACAAGCTGCC-1_WSSS_PLA8764121
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                 AAACCCACATAACCCA-1_WSSS_PLA8764121
# ...                                                                                               ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_...
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_...
#
#                                                                             souporcell_assignment  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                              WSSS_PLA8764121_0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# ...                                                                                           ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
#
#                                                     inter_ind_doublet  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                  0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                  0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                  0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                  0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                  0
# ...                                                               ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...                  0
#
#                                                      S_score G2M_score phase  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                  0.053412  0.056947   G2M
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                 -0.120729 -0.113529    G1
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                  0.042173 -0.027934     S
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                 -0.121624  0.050396   G2M
# AAACCCACATAACCCA-1_WSSS_PLA8764121                 -0.125064 -0.066023    G1
# ...                                                      ...       ...   ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  0.033632 -0.079893     S
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P... -0.059688 -0.098701    G1
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  0.066281 -0.038885     S
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P... -0.031627 -0.068024    G1
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P... -0.110820 -0.058170    G1
#
#                                                    annotation_prev  louvain  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                          0_none       16
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                             dM2       10
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                          0_none       14
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                            dNK1       14
# AAACCCACATAACCCA-1_WSSS_PLA8764121                             dS1        8
# ...                                                            ...      ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...          0_none        7
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...          0_none        2
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...          0_none       30
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...          0_none        2
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...          0_none        2
#
#                                                     is_doublet_propagate  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                     0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                     0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                     0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                     0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                     0
# ...                                                                  ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...                     0
#
#                                                     origin_M_F
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                           F
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                           M
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                           M
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                           M
# AAACCCACATAACCCA-1_WSSS_PLA8764121                           M
# ...                                                        ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...           M
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...           F
#
# [74244 rows x 25 columns]

# %%
# subsetting the adata object to final cells
adata = adata[list(nodoublet_cell_IDs.index), :].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 74244 × 29058
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# adding metadata
for col in nodoublet_cell_IDs.columns:
    print(col)
    adata.obs[col] = nodoublet_cell_IDs.loc[adata.obs_names,col]
# Out:
# n_genes
# donor
# tissue_block
# age
# sample
# percent_mito
# n_counts
# dataset
# technique
# scrublet_score
# scrublet_cluster_score
# bh_pval
# batch
# is_doublet
# barcode_sample_copy
# barcode
# souporcell_assignment
# inter_ind_doublet
# S_score
# G2M_score
# phase
# annotation_prev
# louvain
# is_doublet_propagate
# origin_M_F

# %%
# subset to only selected trophoblast (after cleanup)
# read in obs table with louvain labels from notebook S3-1 and subset to only cleaned up troph
obs_table_with_labels = pd.read_csv(save_path + 'obs_table_adata_scvi_SN_and_multiome_with_inv_troph_labels_S3-4_notebook.csv', index_col=0)

adata.obs['inv_troph_labels'] = obs_table_with_labels.loc[list(set(adata.obs_names) & set(obs_table_with_labels.index)), 'inv_troph_labels']
adata = adata[adata.obs['inv_troph_labels'] == 'inv_troph'].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 6338 × 29058
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F', 'inv_troph_labels'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# read in CCGs recalc in notebook S3-1 and using X? PCs
cleaned_up_genes = pd.read_csv(save_path + 'genes_without_CC_assoc_genes_for_scVI_SN_and_multiome_invading_trophoblast_20211110.csv', 
                              index_col=0)
adata = adata[:,cleaned_up_genes.index].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 6338 × 28632
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F', 'inv_troph_labels'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# do some basic preprocessing
adata.layers["raw_counts"] = adata.X.copy() # preserve counts
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata.copy()

# %%
# here we subset to HVGs, accounting for donor batch
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    subset=True,
    #layer="raw_counts",
    flavor="seurat",
    batch_key="sample",
    #batch_key="donor"
)
# Out:
# ... storing 'donor' as categorical
# ... storing 'tissue_block' as categorical
# ... storing 'age' as categorical
# ... storing 'sample' as categorical
# ... storing 'dataset' as categorical
# ... storing 'technique' as categorical
# ... storing 'souporcell_assignment' as categorical
# ... storing 'phase' as categorical
# ... storing 'annotation_prev' as categorical
# ... storing 'origin_M_F' as categorical
# ... storing 'inv_troph_labels' as categorical
# /opt/conda/envs/scvi-singularity/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# #### Here you can specify your covariates you want to correct for (categorical or continuous)

# %%
scvi.data.setup_anndata(
    adata,
    layer="raw_counts",
    categorical_covariate_keys=["sample"],
    #continuous_covariate_keys=[""] # could try and regress n_genes in the future? not for now
)
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["raw_counts"]
# INFO     Computing library size prior per batch
# INFO     Successfully registered anndata object containing 6338 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 1 extra categorical covariates and 0 extra
#          continuous covariates.
# INFO     Please do not further modify adata until model is trained.

# %% [markdown]
# ### 10.11.2021 Running scVI on all trophoblast after:
#
# - removing cell cycle-associated genes (calculated in S3 notebook)
# - exclusion of all doublets (scrublet and souporcell, done in S2)

# %%
models = {}

# just a few values here, it was 18 PCs I used in the conventional analysis
n_latent_values = [9, 11]

for n_latent_value in n_latent_values:
    print('n_latent_value', n_latent_value)
    models[n_latent_value] = scvi.model.SCVI(adata, n_latent = n_latent_value)
# Out:
# n_latent_value 9
# n_latent_value 11

# %%
models[9]
# Out:
# SCVI Model with the following params:
# n_hidden: 128, n_latent: 9, n_layers: 1, dropout_rate: 0.1, dispersion: gene,
# gene_likelihood: zinb, latent_distribution: normal
# Training status: Trained
# To print summary of associated AnnData, use: scvi.data.view_anndata_setup(model.adata)

# %%
latent_representations = {}

for n_latent_value in n_latent_values:
    print('training model for n_latent_value:', n_latent_value)
    models[n_latent_value].train()
    
    # get latent representation as a dataframe
    latent_representations[n_latent_value] = models[n_latent_value].get_latent_representation()
    
    # add it to the adata object
    adata.obsm["X_scVI_n_latent_" + str(n_latent_value)] = latent_representations[n_latent_value]
    curr_df = pd.DataFrame(adata.obsm["X_scVI_n_latent_" + str(n_latent_value)])
    
    # save the latent representation
    curr_df.to_csv('./results/20211110_obsm_with_scVI_latent_representation_n_' + str(n_latent_value) + '_after_CCG_removal_and_all_doublet_exclusion_by_sample_donor_P13_SN_and_multiome_invading_trophoblast.csv')
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 9
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [02:54<00:00,  2.29it/s, loss=968, v_num=1]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 11
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [02:54<00:00,  2.30it/s, loss=968, v_num=1]

# %% [markdown]
# # Running on invading trophoblast after cleanup v1 in notebook S6-1
#
#
# Subsetted by unbiased clusteing of the manifold with invading trophoblast states

# %%
save_path = '/lustre/scratch117/cellgen/team292/aa22/adata_objects/202007_snRNA-seq_MFI/snRNA_seq_MFI_202007_adatas/202012_FINAL_reanalysis_with_souporcell_deconvolution_common_variants/donor_P13_all_samples_analysis_202110/'

# Loading object with raw counts, filtered cells and genes object
# before any doublet exclusion
adata = sc.read(save_path + 'adata_raw_filtered.h5ad')

# %%
# reading IDs of final cells to keep (after also excluding doublets by GEX, done in notebook M3)
nodoublet_cell_IDs = pd.read_csv(save_path + 'obs_table_nodoublets.csv', index_col=0)
nodoublet_cell_IDs
# Out:
#                                                     n_genes donor  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                     1253   P13
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                     1279   P13
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                      473   P13
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                     1360   P13
# AAACCCACATAACCCA-1_WSSS_PLA8764121                     1891   P13
# ...                                                     ...   ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...     2409   P13
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...     4129   P13
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...     3116   P13
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...     3696   P13
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...     2130   P13
#
#                                                    tissue_block      age  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACATAACCCA-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# ...                                                         ...      ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
#
#                                                                                          sample  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# ...                                                                                         ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
#
#                                                     percent_mito  n_counts  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                      0.000000    1820.0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                      0.000535    1868.0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                      0.000000     556.0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                      0.000473    2116.0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                      0.000305    3274.0
# ...                                                          ...       ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...      0.007270    5227.0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...      0.002532   17379.0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...      0.004499    7779.0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...      0.001992   20078.0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...      0.012930    5259.0
#
#                                                       dataset technique  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACATAACCCA-1_WSSS_PLA8764121                  snRNA-seq       10X
# ...                                                       ...       ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
#
#                                                     scrublet_score  ...  \
# barcode_sample                                                      ...
# AAACCCAAGATACATG-1_WSSS_PLA8764121                        0.191617  ...
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                        0.032895  ...
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                        0.091892  ...
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                        0.012335  ...
# AAACCCACATAACCCA-1_WSSS_PLA8764121                        0.073634  ...
# ...                                                            ...  ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...        0.013699  ...
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...        0.102190  ...
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...        0.036876  ...
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...        0.109137  ...
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...        0.109137  ...
#
#                                                                                               barcode  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                 AAACCCAAGATACATG-1_WSSS_PLA8764121
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                 AAACCCACAAATCCCA-1_WSSS_PLA8764121
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                 AAACCCACAACTGTGT-1_WSSS_PLA8764121
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                 AAACCCACAAGCTGCC-1_WSSS_PLA8764121
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                 AAACCCACATAACCCA-1_WSSS_PLA8764121
# ...                                                                                               ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_...
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_...
#
#                                                                             souporcell_assignment  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                              WSSS_PLA8764121_0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# ...                                                                                           ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
#
#                                                     inter_ind_doublet  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                  0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                  0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                  0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                  0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                  0
# ...                                                               ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...                  0
#
#                                                      S_score G2M_score phase  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                  0.053412  0.056947   G2M
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                 -0.120729 -0.113529    G1
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                  0.042173 -0.027934     S
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                 -0.121624  0.050396   G2M
# AAACCCACATAACCCA-1_WSSS_PLA8764121                 -0.125064 -0.066023    G1
# ...                                                      ...       ...   ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  0.033632 -0.079893     S
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P... -0.059688 -0.098701    G1
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  0.066281 -0.038885     S
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P... -0.031627 -0.068024    G1
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P... -0.110820 -0.058170    G1
#
#                                                    annotation_prev  louvain  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                          0_none       16
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                             dM2       10
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                          0_none       14
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                            dNK1       14
# AAACCCACATAACCCA-1_WSSS_PLA8764121                             dS1        8
# ...                                                            ...      ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...          0_none        7
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...          0_none        2
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...          0_none       30
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...          0_none        2
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...          0_none        2
#
#                                                     is_doublet_propagate  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                     0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                     0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                     0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                     0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                     0
# ...                                                                  ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...                     0
#
#                                                     origin_M_F
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                           F
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                           M
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                           M
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                           M
# AAACCCACATAACCCA-1_WSSS_PLA8764121                           M
# ...                                                        ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...           M
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...           F
#
# [74244 rows x 25 columns]

# %%
# subsetting the adata object to final cells
adata = adata[list(nodoublet_cell_IDs.index), :].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 74244 × 29058
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# adding metadata
for col in nodoublet_cell_IDs.columns:
    print(col)
    adata.obs[col] = nodoublet_cell_IDs.loc[adata.obs_names,col]
# Out:
# n_genes
# donor
# tissue_block
# age
# sample
# percent_mito
# n_counts
# dataset
# technique
# scrublet_score
# scrublet_cluster_score
# bh_pval
# batch
# is_doublet
# barcode_sample_copy
# barcode
# souporcell_assignment
# inter_ind_doublet
# S_score
# G2M_score
# phase
# annotation_prev
# louvain
# is_doublet_propagate
# origin_M_F

# %%
# subset to only selected trophoblast (after cleanup)
# read in obs table with louvain labels from notebook S3-1 and subset to only cleaned up troph
obs_table_with_labels = pd.read_csv(save_path + 'obs_table_adata_scvi_SN_and_multiome_with_inv_troph_cleanup_v1.csv', index_col=0)

adata.obs['inv_troph_cleanup_v1'] = obs_table_with_labels.loc[list(set(adata.obs_names) & set(obs_table_with_labels.index)), 'inv_troph_cleanup_v1']
adata = adata[adata.obs['inv_troph_cleanup_v1'] == 'keeping'].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 4848 × 29058
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F', 'inv_troph_cleanup_v1'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# read in CCGs recalc in notebook S4-1 and using X? PCs
cleaned_up_genes = pd.read_csv(save_path + 'genes_without_CC_assoc_genes_for_scVI_SN_and_multiome_invading_trophoblast_cleanup_v1_20211110.csv', 
                              index_col=0)
adata = adata[:,cleaned_up_genes.index].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 4848 × 28577
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F', 'inv_troph_cleanup_v1'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# do some basic preprocessing
adata.layers["raw_counts"] = adata.X.copy() # preserve counts
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata.copy()

# %%
# here we subset to HVGs, accounting for donor batch
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    subset=True,
    #layer="raw_counts",
    flavor="seurat",
    batch_key="sample",
    #batch_key="donor"
)
# Out:
# ... storing 'donor' as categorical
# ... storing 'tissue_block' as categorical
# ... storing 'age' as categorical
# ... storing 'sample' as categorical
# ... storing 'dataset' as categorical
# ... storing 'technique' as categorical
# ... storing 'souporcell_assignment' as categorical
# ... storing 'phase' as categorical
# ... storing 'annotation_prev' as categorical
# ... storing 'origin_M_F' as categorical
# ... storing 'inv_troph_cleanup_v1' as categorical
# /opt/conda/envs/scvi-singularity/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# #### Here you can specify your covariates you want to correct for (categorical or continuous)

# %%
scvi.data.setup_anndata(
    adata,
    layer="raw_counts",
    categorical_covariate_keys=["sample"],
    #continuous_covariate_keys=[""] # could try and regress n_genes in the future? not for now
)
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["raw_counts"]
# INFO     Computing library size prior per batch
# INFO     Successfully registered anndata object containing 4848 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 1 extra categorical covariates and 0 extra
#          continuous covariates.
# INFO     Please do not further modify adata until model is trained.

# %% [markdown]
# ### 10.11.2021 Running scVI on all trophoblast after:
#
# - removing cell cycle-associated genes (calculated in S3-1 notebook)
# - exclusion of all doublets (scrublet and souporcell)

# %%
models = {}

# just a few values here, it was 18 PCs I used in the conventional analysis
n_latent_values = [8,20]

for n_latent_value in n_latent_values:
    print('n_latent_value', n_latent_value)
    models[n_latent_value] = scvi.model.SCVI(adata, n_latent = n_latent_value)
# Out:
# n_latent_value 8
# n_latent_value 20

# %%
models[8]
# Out:
# SCVI Model with the following params:
# n_hidden: 128, n_latent: 8, n_layers: 1, dropout_rate: 0.1, dispersion: gene,
# gene_likelihood: zinb, latent_distribution: normal
# Training status: Not Trained
# To print summary of associated AnnData, use: scvi.data.view_anndata_setup(model.adata)

# %%
latent_representations = {}

for n_latent_value in n_latent_values:
    print('training model for n_latent_value:', n_latent_value)
    models[n_latent_value].train()
    
    # get latent representation as a dataframe
    latent_representations[n_latent_value] = models[n_latent_value].get_latent_representation()
    
    # add it to the adata object
    adata.obsm["X_scVI_n_latent_" + str(n_latent_value)] = latent_representations[n_latent_value]
    curr_df = pd.DataFrame(adata.obsm["X_scVI_n_latent_" + str(n_latent_value)])
    
    # save the latent representation
    curr_df.to_csv('./results/20211110_obsm_with_scVI_latent_representation_n_' + str(n_latent_value) + '_after_CCG_removal_and_all_doublet_exclusion_by_sample_donor_P13_SN_and_multiome_invading_trophoblast_cleanup_v1.csv')
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 8
# Epoch 400/400: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [02:15<00:00,  2.94it/s, loss=1.03e+03, v_num=1]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 20
# Epoch 400/400: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [02:16<00:00,  2.92it/s, loss=1.04e+03, v_num=1]

# %% [markdown]
# # Running on invading trophoblast after cleanup v2 in notebook S6-2
#
#
# Subsetted by unbiased clusteing of the manifold with invading trophoblast states

# %%
save_path = '/lustre/scratch117/cellgen/team292/aa22/adata_objects/202007_snRNA-seq_MFI/snRNA_seq_MFI_202007_adatas/202012_FINAL_reanalysis_with_souporcell_deconvolution_common_variants/donor_P13_all_samples_analysis_202110/'

# Loading object with raw counts, filtered cells and genes object
# before any doublet exclusion
adata = sc.read(save_path + 'adata_raw_filtered.h5ad')

# %%
# reading IDs of final cells to keep (after also excluding doublets by GEX, done in notebook M3)
nodoublet_cell_IDs = pd.read_csv(save_path + 'obs_table_nodoublets.csv', index_col=0)
nodoublet_cell_IDs
# Out:
#                                                     n_genes donor  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                     1253   P13
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                     1279   P13
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                      473   P13
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                     1360   P13
# AAACCCACATAACCCA-1_WSSS_PLA8764121                     1891   P13
# ...                                                     ...   ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...     2409   P13
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...     4129   P13
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...     3116   P13
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...     3696   P13
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...     2130   P13
#
#                                                    tissue_block      age  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# AAACCCACATAACCCA-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
# ...                                                         ...      ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
#
#                                                                                          sample  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121
# ...                                                                                         ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
#
#                                                     percent_mito  n_counts  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                      0.000000    1820.0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                      0.000535    1868.0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                      0.000000     556.0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                      0.000473    2116.0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                      0.000305    3274.0
# ...                                                          ...       ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...      0.007270    5227.0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...      0.002532   17379.0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...      0.004499    7779.0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...      0.001992   20078.0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...      0.012930    5259.0
#
#                                                       dataset technique  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                  snRNA-seq       10X
# AAACCCACATAACCCA-1_WSSS_PLA8764121                  snRNA-seq       10X
# ...                                                       ...       ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
#
#                                                     scrublet_score  ...  \
# barcode_sample                                                      ...
# AAACCCAAGATACATG-1_WSSS_PLA8764121                        0.191617  ...
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                        0.032895  ...
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                        0.091892  ...
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                        0.012335  ...
# AAACCCACATAACCCA-1_WSSS_PLA8764121                        0.073634  ...
# ...                                                            ...  ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...        0.013699  ...
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...        0.102190  ...
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...        0.036876  ...
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...        0.109137  ...
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...        0.109137  ...
#
#                                                                                               barcode  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                 AAACCCAAGATACATG-1_WSSS_PLA8764121
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                 AAACCCACAAATCCCA-1_WSSS_PLA8764121
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                 AAACCCACAACTGTGT-1_WSSS_PLA8764121
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                 AAACCCACAAGCTGCC-1_WSSS_PLA8764121
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                 AAACCCACATAACCCA-1_WSSS_PLA8764121
# ...                                                                                               ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_...
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_...
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_...
#
#                                                                             souporcell_assignment  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                              WSSS_PLA8764121_0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                              WSSS_PLA8764121_1
# ...                                                                                           ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916_1
#
#                                                     inter_ind_doublet  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                  0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                  0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                  0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                  0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                  0
# ...                                                               ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...                  0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...                  0
#
#                                                      S_score G2M_score phase  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                  0.053412  0.056947   G2M
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                 -0.120729 -0.113529    G1
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                  0.042173 -0.027934     S
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                 -0.121624  0.050396   G2M
# AAACCCACATAACCCA-1_WSSS_PLA8764121                 -0.125064 -0.066023    G1
# ...                                                      ...       ...   ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...  0.033632 -0.079893     S
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P... -0.059688 -0.098701    G1
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...  0.066281 -0.038885     S
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P... -0.031627 -0.068024    G1
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P... -0.110820 -0.058170    G1
#
#                                                    annotation_prev  louvain  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                          0_none       16
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                             dM2       10
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                          0_none       14
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                            dNK1       14
# AAACCCACATAACCCA-1_WSSS_PLA8764121                             dS1        8
# ...                                                            ...      ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...          0_none        7
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...          0_none        2
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...          0_none       30
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...          0_none        2
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...          0_none        2
#
#                                                     is_doublet_propagate  \
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                                     0
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                                     0
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                                     0
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                                     0
# AAACCCACATAACCCA-1_WSSS_PLA8764121                                     0
# ...                                                                  ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...                     0
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...                     0
#
#                                                     origin_M_F
# barcode_sample
# AAACCCAAGATACATG-1_WSSS_PLA8764121                           F
# AAACCCACAAATCCCA-1_WSSS_PLA8764121                           M
# AAACCCACAACTGTGT-1_WSSS_PLA8764121                           M
# AAACCCACAAGCTGCC-1_WSSS_PLA8764121                           M
# AAACCCACATAACCCA-1_WSSS_PLA8764121                           M
# ...                                                        ...
# TTTGTGTTCGTCAAGT-1_Pla_Camb10714920_and_40110_P...           M
# TTTGTGTTCTTAGTCT-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTCACAGCG-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTTTACTTG-1_Pla_Camb10714920_and_40110_P...           F
# TTTGTTGGTTTGAGCA-1_Pla_Camb10714920_and_40110_P...           F
#
# [74244 rows x 25 columns]

# %%
# subsetting the adata object to final cells
adata = adata[list(nodoublet_cell_IDs.index), :].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 74244 × 29058
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# adding metadata
for col in nodoublet_cell_IDs.columns:
    print(col)
    adata.obs[col] = nodoublet_cell_IDs.loc[adata.obs_names,col]
# Out:
# n_genes
# donor
# tissue_block
# age
# sample
# percent_mito
# n_counts
# dataset
# technique
# scrublet_score
# scrublet_cluster_score
# bh_pval
# batch
# is_doublet
# barcode_sample_copy
# barcode
# souporcell_assignment
# inter_ind_doublet
# S_score
# G2M_score
# phase
# annotation_prev
# louvain
# is_doublet_propagate
# origin_M_F

# %%
# subset to only selected trophoblast (after cleanup)
# read in obs table with louvain labels from notebook S3-1 and subset to only cleaned up troph
obs_table_with_labels = pd.read_csv(save_path + 'obs_table_adata_scvi_SN_and_multiome_with_inv_troph_cleanup_v2.csv', index_col=0)

adata.obs['inv_troph_cleanup_v2'] = obs_table_with_labels.loc[list(set(adata.obs_names) & set(obs_table_with_labels.index)), 'inv_troph_cleanup_v2']
adata = adata[adata.obs['inv_troph_cleanup_v2'] == 'keeping'].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 4715 × 29058
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F', 'inv_troph_cleanup_v2'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# read in CCGs recalc in notebook S4-2 and using 8 and 20 PCs
cleaned_up_genes = pd.read_csv(save_path + 'genes_without_CC_assoc_genes_for_scVI_SN_and_multiome_invading_trophoblast_cleanup_v2_20211110.csv', 
                              index_col=0)
adata = adata[:,cleaned_up_genes.index].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 4715 × 26535
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet', 'barcode_sample_copy', 'barcode', 'souporcell_assignment', 'inter_ind_doublet', 'S_score', 'G2M_score', 'phase', 'annotation_prev', 'louvain', 'is_doublet_propagate', 'origin_M_F', 'inv_troph_cleanup_v2'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# do some basic preprocessing
adata.layers["raw_counts"] = adata.X.copy() # preserve counts
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata.copy()

# %%
# here we subset to HVGs, accounting for donor batch
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    subset=True,
    #layer="raw_counts",
    flavor="seurat",
    batch_key="sample",
    #batch_key="donor"
)
# Out:
# ... storing 'donor' as categorical
# ... storing 'tissue_block' as categorical
# ... storing 'age' as categorical
# ... storing 'sample' as categorical
# ... storing 'dataset' as categorical
# ... storing 'technique' as categorical
# ... storing 'souporcell_assignment' as categorical
# ... storing 'phase' as categorical
# ... storing 'annotation_prev' as categorical
# ... storing 'origin_M_F' as categorical
# ... storing 'inv_troph_cleanup_v2' as categorical
# /opt/conda/envs/scvi-singularity/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# #### Here you can specify your covariates you want to correct for (categorical or continuous)

# %%
scvi.data.setup_anndata(
    adata,
    layer="raw_counts",
    categorical_covariate_keys=["sample"],
    #continuous_covariate_keys=[""] # could try and regress n_genes in the future? not for now
)
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["raw_counts"]
# INFO     Computing library size prior per batch
# INFO     Successfully registered anndata object containing 4715 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 1 extra categorical covariates and 0 extra
#          continuous covariates.
# INFO     Please do not further modify adata until model is trained.

# %% [markdown]
# ### 10.11.2021 Running scVI on all trophoblast after:
#
# - removing cell cycle-associated genes (calculated in S3-1 notebook)
# - exclusion of all doublets (scrublet and souporcell)

# %%
models = {}

# just a few values here, it was 18 PCs I used in the conventional analysis
n_latent_values = [8,20,30]

for n_latent_value in n_latent_values:
    print('n_latent_value', n_latent_value)
    models[n_latent_value] = scvi.model.SCVI(adata, n_latent = n_latent_value)
# Out:
# n_latent_value 8
# n_latent_value 20
# n_latent_value 30

# %%
models[30]
# Out:
# SCVI Model with the following params:
# n_hidden: 128, n_latent: 30, n_layers: 1, dropout_rate: 0.1, dispersion: gene,
# gene_likelihood: zinb, latent_distribution: normal
# Training status: Not Trained
# To print summary of associated AnnData, use: scvi.data.view_anndata_setup(model.adata)

# %%
latent_representations = {}

for n_latent_value in n_latent_values:
    print('training model for n_latent_value:', n_latent_value)
    models[n_latent_value].train()
    
    # get latent representation as a dataframe
    latent_representations[n_latent_value] = models[n_latent_value].get_latent_representation()
    
    # add it to the adata object
    adata.obsm["X_scVI_n_latent_" + str(n_latent_value)] = latent_representations[n_latent_value]
    curr_df = pd.DataFrame(adata.obsm["X_scVI_n_latent_" + str(n_latent_value)])
    
    # save the latent representation
    curr_df.to_csv('./results/20211110_obsm_with_scVI_latent_representation_n_' + str(n_latent_value) + '_after_CCG_removal_and_all_doublet_exclusion_by_sample_donor_P13_SN_and_multiome_invading_trophoblast_cleanup_v2.csv')
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 8
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [02:12<00:00,  3.02it/s, loss=977, v_num=1]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 20
# Epoch 400/400: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [02:13<00:00,  3.00it/s, loss=972, v_num=1]

# %%
# doing for 30 in addition
latent_representations = {}

for n_latent_value in [30]:
    print('training model for n_latent_value:', n_latent_value)
    models[n_latent_value].train()
    
    # get latent representation as a dataframe
    latent_representations[n_latent_value] = models[n_latent_value].get_latent_representation()
    
    # add it to the adata object
    adata.obsm["X_scVI_n_latent_" + str(n_latent_value)] = latent_representations[n_latent_value]
    curr_df = pd.DataFrame(adata.obsm["X_scVI_n_latent_" + str(n_latent_value)])
    
    # save the latent representation
    curr_df.to_csv('./results/20211110_obsm_with_scVI_latent_representation_n_' + str(n_latent_value) + '_after_CCG_removal_and_all_doublet_exclusion_by_sample_donor_P13_SN_and_multiome_invading_trophoblast_cleanup_v2.csv')
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 30
# Epoch 400/400: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 400/400 [01:44<00:00,  3.84it/s, loss=991, v_num=1]

# %% [markdown]
# # Running on all trophoblast after final cleanup of the indaving compartment in notebook S6-3

# %%
save_path = '/lustre/scratch117/cellgen/team292/aa22/adata_objects/202007_snRNA-seq_MFI/snRNA_seq_MFI_202007_adatas/202012_FINAL_reanalysis_with_souporcell_deconvolution_common_variants/donor_P13_all_samples_analysis_202110/'

# Loading object with raw counts, filtered cells and genes object
# before any doublet exclusion
adata = sc.read(save_path + 'adata_raw_filtered.h5ad')

# %%
# reading IDs of final cells to keep
obs_to_keep = pd.read_csv(save_path + 'obs_table_for_scVI_SN_and_multiome_all_trophoblast_cleanup_v5_final_20211110.csv', index_col=0)
obs_to_keep
# Out:
#                                                     n_genes donor  \
# barcode_sample
# ACCTGAAAGGATGGCT-1_Pla_Camb10691970                    2595   P13
# CTACAGAAGAGGCTGT-1_WSSS_PLA8810751                     3291   P13
# ATTTACCCATGGAACG-1_WSSS_PLA8810750                     2387   P13
# ACCATTTGTGTCTTCC-1_Pla_Camb10691970                    1862   P13
# TCATTTGGTCCAGTTA-1_WSSS_PLA8810750                     2518   P13
# ...                                                     ...   ...
# GTGCTTCTCCCGTAAA-1_WSSS_PLA8810751                     2391   P13
# CGATGCGCAATTGCCA-1_WSSS_PLA8810751                     3525   P13
# TTACAGCAGGAAACTG-1_Pla_Camb10714920_and_40110_P...     4764   P13
# AGCATCACATATGAAG-1_WSSS_PLA8810750                     2431   P13
# GTCGAATGTTAAGAAC-1_WSSS_PLA8764121                     2434   P13
#
#                                                    tissue_block      age  \
# barcode_sample
# ACCTGAAAGGATGGCT-1_Pla_Camb10691970                     unknown  8-9_PCW
# CTACAGAAGAGGCTGT-1_WSSS_PLA8810751                     PU8-9_B2  8-9_PCW
# ATTTACCCATGGAACG-1_WSSS_PLA8810750                     PU8-9_B2  8-9_PCW
# ACCATTTGTGTCTTCC-1_Pla_Camb10691970                     unknown  8-9_PCW
# TCATTTGGTCCAGTTA-1_WSSS_PLA8810750                     PU8-9_B2  8-9_PCW
# ...                                                         ...      ...
# GTGCTTCTCCCGTAAA-1_WSSS_PLA8810751                     PU8-9_B2  8-9_PCW
# CGATGCGCAATTGCCA-1_WSSS_PLA8810751                     PU8-9_B2  8-9_PCW
# TTACAGCAGGAAACTG-1_Pla_Camb10714920_and_40110_P...      unknown  8-9_PCW
# AGCATCACATATGAAG-1_WSSS_PLA8810750                     PU8-9_B2  8-9_PCW
# GTCGAATGTTAAGAAC-1_WSSS_PLA8764121                     PU8-9_B5  8-9_PCW
#
#                                                                                          sample  \
# barcode_sample
# ACCTGAAAGGATGGCT-1_Pla_Camb10691970                                            Pla_Camb10691970
# CTACAGAAGAGGCTGT-1_WSSS_PLA8810751                                              WSSS_PLA8810751
# ATTTACCCATGGAACG-1_WSSS_PLA8810750                                              WSSS_PLA8810750
# ACCATTTGTGTCTTCC-1_Pla_Camb10691970                                            Pla_Camb10691970
# TCATTTGGTCCAGTTA-1_WSSS_PLA8810750                                              WSSS_PLA8810750
# ...                                                                                         ...
# GTGCTTCTCCCGTAAA-1_WSSS_PLA8810751                                              WSSS_PLA8810751
# CGATGCGCAATTGCCA-1_WSSS_PLA8810751                                              WSSS_PLA8810751
# TTACAGCAGGAAACTG-1_Pla_Camb10714920_and_40110_P...  Pla_Camb10714920_and_40110_Pla_Camb10687916
# AGCATCACATATGAAG-1_WSSS_PLA8810750                                              WSSS_PLA8810750
# GTCGAATGTTAAGAAC-1_WSSS_PLA8764121                                              WSSS_PLA8764121
#
#                                                     percent_mito   n_counts  \
# barcode_sample
# ACCTGAAAGGATGGCT-1_Pla_Camb10691970                     0.002652  3433.4832
# CTACAGAAGAGGCTGT-1_WSSS_PLA8810751                      0.000409  3979.8735
# ATTTACCCATGGAACG-1_WSSS_PLA8810750                      0.000000  3165.4448
# ACCATTTGTGTCTTCC-1_Pla_Camb10691970                     0.001475  2897.3274
# TCATTTGGTCCAGTTA-1_WSSS_PLA8810750                      0.000900  3417.3792
# ...                                                          ...        ...
# GTGCTTCTCCCGTAAA-1_WSSS_PLA8810751                      0.000997  3568.1180
# CGATGCGCAATTGCCA-1_WSSS_PLA8810751                      0.001118  4057.3357
# TTACAGCAGGAAACTG-1_Pla_Camb10714920_and_40110_P...      0.035067  3999.3276
# AGCATCACATATGAAG-1_WSSS_PLA8810750                      0.001215  3604.9640
# GTCGAATGTTAAGAAC-1_WSSS_PLA8764121                      0.000000  3126.1738
#
#                                                       dataset technique  \
# barcode_sample
# ACCTGAAAGGATGGCT-1_Pla_Camb10691970                 snRNA-seq       10X
# CTACAGAAGAGGCTGT-1_WSSS_PLA8810751                  snRNA-seq       10X
# ATTTACCCATGGAACG-1_WSSS_PLA8810750                  snRNA-seq       10X
# ACCATTTGTGTCTTCC-1_Pla_Camb10691970                 snRNA-seq       10X
# TCATTTGGTCCAGTTA-1_WSSS_PLA8810750                  snRNA-seq       10X
# ...                                                       ...       ...
# GTGCTTCTCCCGTAAA-1_WSSS_PLA8810751                  snRNA-seq       10X
# CGATGCGCAATTGCCA-1_WSSS_PLA8810751                  snRNA-seq       10X
# TTACAGCAGGAAACTG-1_Pla_Camb10714920_and_40110_P...  snRNA-seq       10X
# AGCATCACATATGAAG-1_WSSS_PLA8810750                  snRNA-seq       10X
# GTCGAATGTTAAGAAC-1_WSSS_PLA8764121                  snRNA-seq       10X
#
#                                                     scrublet_score  ...  \
# barcode_sample                                                      ...
# ACCTGAAAGGATGGCT-1_Pla_Camb10691970                       0.118000  ...
# CTACAGAAGAGGCTGT-1_WSSS_PLA8810751                        0.030408  ...
# ATTTACCCATGGAACG-1_WSSS_PLA8810750                        0.091914  ...
# ACCATTTGTGTCTTCC-1_Pla_Camb10691970                       0.074830  ...
# TCATTTGGTCCAGTTA-1_WSSS_PLA8810750                        0.047110  ...
# ...                                                            ...  ...
# GTGCTTCTCCCGTAAA-1_WSSS_PLA8810751                        0.232955  ...
# CGATGCGCAATTGCCA-1_WSSS_PLA8810751                        0.025431  ...
# TTACAGCAGGAAACTG-1_Pla_Camb10714920_and_40110_P...        0.050289  ...
# AGCATCACATATGAAG-1_WSSS_PLA8810750                        0.058760  ...
# GTCGAATGTTAAGAAC-1_WSSS_PLA8764121                        0.034637  ...
#
#                                                     inter_ind_doublet  \
# barcode_sample
# ACCTGAAAGGATGGCT-1_Pla_Camb10691970                                 0
# CTACAGAAGAGGCTGT-1_WSSS_PLA8810751                                  0
# ATTTACCCATGGAACG-1_WSSS_PLA8810750                                  0
# ACCATTTGTGTCTTCC-1_Pla_Camb10691970                                 0
# TCATTTGGTCCAGTTA-1_WSSS_PLA8810750                                  0
# ...                                                               ...
# GTGCTTCTCCCGTAAA-1_WSSS_PLA8810751                                  0
# CGATGCGCAATTGCCA-1_WSSS_PLA8810751                                  0
# TTACAGCAGGAAACTG-1_Pla_Camb10714920_and_40110_P...                  0
# AGCATCACATATGAAG-1_WSSS_PLA8810750                                  0
# GTCGAATGTTAAGAAC-1_WSSS_PLA8764121                                  0
#
#                                                      S_score  G2M_score  \
# barcode_sample
# ACCTGAAAGGATGGCT-1_Pla_Camb10691970                -0.155819   0.002528
# CTACAGAAGAGGCTGT-1_WSSS_PLA8810751                 -0.070639  -0.061709
# ATTTACCCATGGAACG-1_WSSS_PLA8810750                 -0.017344  -0.001856
# ACCATTTGTGTCTTCC-1_Pla_Camb10691970                -0.073606  -0.074652
# TCATTTGGTCCAGTTA-1_WSSS_PLA8810750                 -0.053986  -0.041936
# ...                                                      ...        ...
# GTGCTTCTCCCGTAAA-1_WSSS_PLA8810751                  0.085361   0.077971
# CGATGCGCAATTGCCA-1_WSSS_PLA8810751                 -0.116954  -0.147250
# TTACAGCAGGAAACTG-1_Pla_Camb10714920_and_40110_P... -0.181669  -0.209082
# AGCATCACATATGAAG-1_WSSS_PLA8810750                  0.073197   0.476664
# GTCGAATGTTAAGAAC-1_WSSS_PLA8764121                 -0.008144  -0.006645
#
#                                                     phase annotation_prev  \
# barcode_sample
# ACCTGAAAGGATGGCT-1_Pla_Camb10691970                   G2M          0_none
# CTACAGAAGAGGCTGT-1_WSSS_PLA8810751                     G1           VCT_p
# ATTTACCCATGGAACG-1_WSSS_PLA8810750                     G1             SCT
# ACCATTTGTGTCTTCC-1_Pla_Camb10691970                    G1          0_none
# TCATTTGGTCCAGTTA-1_WSSS_PLA8810750                     G1            iEVT
# ...                                                   ...             ...
# GTGCTTCTCCCGTAAA-1_WSSS_PLA8810751                      S          0_none
# CGATGCGCAATTGCCA-1_WSSS_PLA8810751                     G1             VCT
# TTACAGCAGGAAACTG-1_Pla_Camb10714920_and_40110_P...     G1          0_none
# AGCATCACATATGAAG-1_WSSS_PLA8810750                    G2M           EVT_1
# GTCGAATGTTAAGAAC-1_WSSS_PLA8764121                     G1             SCT
#
#                                                    louvain  \
# barcode_sample
# ACCTGAAAGGATGGCT-1_Pla_Camb10691970                      1
# CTACAGAAGAGGCTGT-1_WSSS_PLA8810751                       5
# ATTTACCCATGGAACG-1_WSSS_PLA8810750                       0
# ACCATTTGTGTCTTCC-1_Pla_Camb10691970                      1
# TCATTTGGTCCAGTTA-1_WSSS_PLA8810750                       4
# ...                                                    ...
# GTGCTTCTCCCGTAAA-1_WSSS_PLA8810751                       1
# CGATGCGCAATTGCCA-1_WSSS_PLA8810751                       5
# TTACAGCAGGAAACTG-1_Pla_Camb10714920_and_40110_P...      23
# AGCATCACATATGAAG-1_WSSS_PLA8810750                       4
# GTCGAATGTTAAGAAC-1_WSSS_PLA8764121                       9
#
#                                                    is_doublet_propagate  \
# barcode_sample
# ACCTGAAAGGATGGCT-1_Pla_Camb10691970                                   0
# CTACAGAAGAGGCTGT-1_WSSS_PLA8810751                                    0
# ATTTACCCATGGAACG-1_WSSS_PLA8810750                                    0
# ACCATTTGTGTCTTCC-1_Pla_Camb10691970                                   0
# TCATTTGGTCCAGTTA-1_WSSS_PLA8810750                                    0
# ...                                                                 ...
# GTGCTTCTCCCGTAAA-1_WSSS_PLA8810751                                    0
# CGATGCGCAATTGCCA-1_WSSS_PLA8810751                                    0
# TTACAGCAGGAAACTG-1_Pla_Camb10714920_and_40110_P...                    0
# AGCATCACATATGAAG-1_WSSS_PLA8810750                                    0
# GTCGAATGTTAAGAAC-1_WSSS_PLA8764121                                    0
#
#                                                     origin_M_F  \
# barcode_sample
# ACCTGAAAGGATGGCT-1_Pla_Camb10691970                          F
# CTACAGAAGAGGCTGT-1_WSSS_PLA8810751                           F
# ATTTACCCATGGAACG-1_WSSS_PLA8810750                           F
# ACCATTTGTGTCTTCC-1_Pla_Camb10691970                          F
# TCATTTGGTCCAGTTA-1_WSSS_PLA8810750                           F
# ...                                                        ...
# GTGCTTCTCCCGTAAA-1_WSSS_PLA8810751                           F
# CGATGCGCAATTGCCA-1_WSSS_PLA8810751                           F
# TTACAGCAGGAAACTG-1_Pla_Camb10714920_and_40110_P...           F
# AGCATCACATATGAAG-1_WSSS_PLA8810750                           F
# GTCGAATGTTAAGAAC-1_WSSS_PLA8764121                           F
#
#                                                     annotation_prev_or_removed  \
# barcode_sample
# ACCTGAAAGGATGGCT-1_Pla_Camb10691970                                     0_none
# CTACAGAAGAGGCTGT-1_WSSS_PLA8810751                                       VCT_p
# ATTTACCCATGGAACG-1_WSSS_PLA8810750                                         SCT
# ACCATTTGTGTCTTCC-1_Pla_Camb10691970                                     0_none
# TCATTTGGTCCAGTTA-1_WSSS_PLA8810750                                        iEVT
# ...                                                                        ...
# GTGCTTCTCCCGTAAA-1_WSSS_PLA8810751                                     removed
# CGATGCGCAATTGCCA-1_WSSS_PLA8810751                                         VCT
# TTACAGCAGGAAACTG-1_Pla_Camb10714920_and_40110_P...                      0_none
# AGCATCACATATGAAG-1_WSSS_PLA8810750                                       EVT_1
# GTCGAATGTTAAGAAC-1_WSSS_PLA8764121                                         SCT
#
#                                                     inv_troph_labels_initial
# barcode_sample
# ACCTGAAAGGATGGCT-1_Pla_Camb10691970                                   others
# CTACAGAAGAGGCTGT-1_WSSS_PLA8810751                                    others
# ATTTACCCATGGAACG-1_WSSS_PLA8810750                                    others
# ACCATTTGTGTCTTCC-1_Pla_Camb10691970                                   others
# TCATTTGGTCCAGTTA-1_WSSS_PLA8810750                                 inv_troph
# ...                                                                      ...
# GTGCTTCTCCCGTAAA-1_WSSS_PLA8810751                                    others
# CGATGCGCAATTGCCA-1_WSSS_PLA8810751                                    others
# TTACAGCAGGAAACTG-1_Pla_Camb10714920_and_40110_P...                 inv_troph
# AGCATCACATATGAAG-1_WSSS_PLA8810750                                 inv_troph
# GTCGAATGTTAAGAAC-1_WSSS_PLA8764121                                    others
#
# [37675 rows x 27 columns]

# %%
# subsetting the adata object to final cells
adata = adata[list(obs_to_keep.index), :].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 37675 × 29058
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# read in CCGs recalc in notebook S4-2 and using 8 and 20 PCs
cleaned_up_genes = pd.read_csv(save_path + 'genes_without_CC_assoc_genes_for_scVI_SN_and_multiome_all_trophoblast_cleanup_v5_final_20211110.csv', 
                              index_col=0)
adata = adata[:,cleaned_up_genes.index].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 37675 × 28465
#     obs: 'n_genes', 'donor', 'tissue_block', 'age', 'sample', 'percent_mito', 'n_counts', 'dataset', 'technique', 'scrublet_score', 'scrublet_cluster_score', 'bh_pval', 'batch', 'is_doublet'
#     var: 'gene_ids-0', 'feature_types-0', 'genome-0', 'n_cells-0', 'gene_ids-1', 'feature_types-1', 'genome-1', 'n_cells-1', 'gene_ids-2', 'feature_types-2', 'genome-2', 'n_cells-2', 'gene_ids-3', 'feature_types-3', 'genome-3', 'n_cells-3', 'gene_ids-4', 'feature_types-4', 'genome-4', 'n_cells-4', 'gene_ids-5', 'feature_types-5', 'genome-5', 'n_cells-5', 'gene_ids-6', 'feature_types-6', 'genome-6', 'n_cells-6', 'gene_ids-7', 'feature_types-7', 'genome-7', 'n_cells-7'

# %%
# do some basic preprocessing
adata.layers["raw_counts"] = adata.X.copy() # preserve counts
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata.copy()

# %%
# here we subset to HVGs, accounting for donor batch
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    subset=True,
    #layer="raw_counts",
    flavor="seurat",
    batch_key="sample",
    #batch_key="donor"
)
# Out:
# /opt/conda/envs/scvi-singularity/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# #### Here you can specify your covariates you want to correct for (categorical or continuous)

# %%
scvi.data.setup_anndata(
    adata,
    layer="raw_counts",
    categorical_covariate_keys=["sample"],
    #continuous_covariate_keys=[""] # could try and regress n_genes in the future? not for now
)
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["raw_counts"]
# INFO     Computing library size prior per batch
# INFO     Successfully registered anndata object containing 37675 cells, 2000 vars, 1 batches,
#          1 labels, and 0 proteins. Also registered 1 extra categorical covariates and 0 extra
#          continuous covariates.
# INFO     Please do not further modify adata until model is trained.

# %% [markdown]
# ### 10.11.2021 Running scVI on all trophoblast after:
#
# - removing cell cycle-associated genes (calculated in S5-1 notebook)
# - exclusion of all doublets (scrublet and souporcell, done in S2 notebook)

# %%
models = {}

n_latent_values = [8,12,17]

for n_latent_value in n_latent_values:
    print('n_latent_value', n_latent_value)
    models[n_latent_value] = scvi.model.SCVI(adata, n_latent = n_latent_value)
# Out:
# n_latent_value 8
# n_latent_value 12
# n_latent_value 17

# %%
models[8]
# Out:
# SCVI Model with the following params:
# n_hidden: 128, n_latent: 8, n_layers: 1, dropout_rate: 0.1, dispersion: gene,
# gene_likelihood: zinb, latent_distribution: normal
# Training status: Not Trained
# To print summary of associated AnnData, use: scvi.data.view_anndata_setup(model.adata)

# %%
latent_representations = {}

for n_latent_value in n_latent_values:
    print('training model for n_latent_value:', n_latent_value)
    models[n_latent_value].train()
    
    # get latent representation as a dataframe
    latent_representations[n_latent_value] = models[n_latent_value].get_latent_representation()
    
    # add it to the adata object
    adata.obsm["X_scVI_n_latent_" + str(n_latent_value)] = latent_representations[n_latent_value]
    curr_df = pd.DataFrame(adata.obsm["X_scVI_n_latent_" + str(n_latent_value)])
    
    # save the latent representation
    curr_df.to_csv('./results/20211110_obsm_with_scVI_latent_representation_n_' + str(n_latent_value) + '_after_CCG_removal_and_all_doublet_exclusion_by_sample_donor_P13_SN_and_multiome_all_trophoblast_cleanup_v5_final.csv')
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 8
# Epoch 212/212: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 212/212 [08:58<00:00,  2.54s/it, loss=918, v_num=1]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 12
# Epoch 212/212: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 212/212 [08:58<00:00,  2.54s/it, loss=906, v_num=1]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# training model for n_latent_value: 17
# Epoch 212/212: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 212/212 [08:58<00:00,  2.54s/it, loss=913, v_num=1]
